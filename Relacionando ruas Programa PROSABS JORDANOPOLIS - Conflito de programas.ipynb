# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/JORDANOPOLIS EIXOS VIA - Conflito de Programas.dxf', encoding='ANSI_1252')

# %%
bairro = 'JORDANOPOLIS'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0     RUA MARIO JÃLIO RODRIGUES - 05_01_2021 - JOR19       None
# 1             RUA CARLOS RIZZINI - 05_01_2021 - JOR17       None
# 2            RUA ADOLFO MONTEIRO - 05_01_2021 - JOR18       None
# 3              RUA EDNO ZENORINI - 05_01_2021 - JOR37       None
# 4            RUA ALFREDO ANGELINI - 05_01_2021 - JOR8       None
# 5            RUA NOVAIS TEIXEIRA - 05_01_2021 - JOR25       None
# 6             RUA GÃIS MONTEIRO - 05_01_2021 - JOR26       None
# 7        RUA LUÃS ALONSO PÃREZ - 05_01_2021 - JOR42       None
# 8   RUA CLEONICE CÃNDIDA FANANI - 05_01_2021 - JOR36       None
# 9   RUA CLEONICE CÃNDIDA FANANI - 05_01_2021 - JOR36       None
# 10             RUA HERBERT MOSES - 05_01_2021 - JOR35       None
# 11         RUA DALVA DE OLIVEIRA - 05_01_2021 - JOR20       None
# 12           RUA PAGANO SOBRINHO - 05_01_2021 - JOR30       None
# 13            RUA ODUVALDO VIANA - 05_01_2021 - JOR12       None
# 14             RUA HENRIQUE DIAS - 05_01_2021 - JOR40       None
# 15            RUA MILTON RIBEIRO - 05_01_2021 - JOR33       None
# 16              RUA SOUZA DANTAS - 05_01_2021 - JOR32       None
# 17                 RUA PERCY LAU - 05_01_2021 - JOR15       None
# 18              RUA MILTON CAMPOS - 05_01_2021 - JOR3       None
# 19         RUA ARNALDO MARGONARI - 05_01_2021 - JOR10       None
# 20         RUA ARNALDO MARGONARI - 05_01_2021 - JOR10       None
# 21         RUA ARNALDO MARGONARI - 05_01_2021 - JOR10       None
# 22    RUA CÃLSO TADEU DOS SANTOS - 05_01_2021 - JOR9       None
# 23  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES - 05_...       None
# 24  RUA CLEONICE CÃNDIDA FANANI - 05_01_2021 - JOR36       None
# 25            RUA MOACIR PADILHA - 05_01_2021 - JOR31       None
# 26         RUA OSWALD DE ANDRADE - 05_01_2021 - JOR16       None
# 27             RUA ARTUR PONTUAL - 05_01_2021 - JOR38       None
# 28       RUA QUINTANILHA RIBEIRO - 05_01_2021 - JOR29       None
# 29         RUA RODRIGUES DO VALE - 05_01_2021 - JOR43       None
# 30        RUA EGÃDIO MICHAELSEN - 05_01_2021 - JOR28       None
# 31          RUA PAULO MAGALHÃES - 05_01_2021 - JOR21       None
# 32        RUA RANGEL DE CARVALHO - 05_01_2021 - JOR41       None
# 33        RUA PATRÃCIO TEIXEIRA - 05_01_2021 - JOR27       None
# 34           RUA ÃDSON CARNEIRO - 05_01_2021 - JOR24       None
# 35          RUA SILAS DE OLIVEIRA - 05_01_2021 - JOR5       None
# 36     RUA EDMUNDO BARRETO PINTO - 05_01_2021 - JOR14       None
# 37            RUA EUGÃNIO GOMES - 05_01_2021 - JOR34       None
# 38             RUA MIGUEL GUSTAVO - 05_01_2021 - JOR6       None
# 39           RUA MARTIM SILVEIRA - 05_01_2021 - JOR39       None
#
#                        SubClasses Linetype EntityHandle  Text  \
# 0       AcDbEntity:AcDb2dPolyline     None           6F  None
# 1       AcDbEntity:AcDb2dPolyline     None           74  None
# 2       AcDbEntity:AcDb2dPolyline     None           79  None
# 3       AcDbEntity:AcDb2dPolyline     None           84  None
# 4       AcDbEntity:AcDb2dPolyline     None           89  None
# 5       AcDbEntity:AcDb2dPolyline     None           8E  None
# 6       AcDbEntity:AcDb2dPolyline     None           93  None
# 7       AcDbEntity:AcDb2dPolyline     None           98  None
# 8             AcDbEntity:AcDbLine     None           9D  None
# 9             AcDbEntity:AcDbLine     None           9E  None
# 10            AcDbEntity:AcDbLine     None           A0  None
# 11      AcDbEntity:AcDb2dPolyline     None           A2  None
# 12      AcDbEntity:AcDb2dPolyline     None           A7  None
# 13      AcDbEntity:AcDb2dPolyline     None           AC  None
# 14      AcDbEntity:AcDb2dPolyline     None           B1  None
# 15      AcDbEntity:AcDb2dPolyline     None           B6  None
# 16      AcDbEntity:AcDb2dPolyline     None           BB  None
# 17      AcDbEntity:AcDb2dPolyline     None           C0  None
# 18      AcDbEntity:AcDb2dPolyline     None           C7  None
# 19            AcDbEntity:AcDbLine     None           CD  None
# 20  AcDbEntity:AcDbCircle:AcDbArc     None           CE  None
# 21            AcDbEntity:AcDbLine     None           CF  None
# 22      AcDbEntity:AcDb2dPolyline     None           D1  None
# 23      AcDbEntity:AcDb2dPolyline     None           D6  None
# 24      AcDbEntity:AcDb2dPolyline     None           E1  None
# 25      AcDbEntity:AcDb2dPolyline     None           E7  None
# 26      AcDbEntity:AcDb2dPolyline     None           EC  None
# 27      AcDbEntity:AcDb2dPolyline     None           F5  None
# 28      AcDbEntity:AcDb2dPolyline     None           FA  None
# 29      AcDbEntity:AcDb2dPolyline     None           FF  None
# 30      AcDbEntity:AcDb2dPolyline     None          104  None
# 31      AcDbEntity:AcDb2dPolyline     None          109  None
# 32      AcDbEntity:AcDb2dPolyline     None          10E  None
# 33      AcDbEntity:AcDb2dPolyline     None          113  None
# 34      AcDbEntity:AcDb2dPolyline     None          118  None
# 35      AcDbEntity:AcDb2dPolyline     None          11D  None
# 36      AcDbEntity:AcDb2dPolyline     None          122  None
# 37      AcDbEntity:AcDb2dPolyline     None          127  None
# 38      AcDbEntity:AcDb2dPolyline     None          12C  None
# 39      AcDbEntity:AcDb2dPolyline     None          131  None
#
#                                              geometry
# 0   LINESTRING Z (338950.604 7380710.573 0.000, 33...
# 1   LINESTRING Z (338904.211 7380723.301 0.000, 33...
# 2   LINESTRING Z (338826.162 7380632.174 0.000, 33...
# 3   LINESTRING Z (339285.680 7380860.317 0.000, 33...
# 4   LINESTRING Z (339038.423 7380797.758 0.000, 33...
# 5   LINESTRING Z (339555.874 7380630.417 0.000, 33...
# 6   LINESTRING Z (339453.927 7380482.390 0.000, 33...
# 7   LINESTRING Z (339145.316 7380788.276 0.000, 33...
# 8   LINESTRING Z (339347.025 7380832.388 0.000, 33...
# 9   LINESTRING Z (339330.765 7380778.903 0.000, 33...
# 10  LINESTRING Z (339321.300 7380763.046 0.000, 33...
# 11  LINESTRING Z (338991.844 7380630.689 0.000, 33...
# 12  LINESTRING Z (339413.136 7380676.275 0.000, 33...
# 13  LINESTRING Z (339055.127 7380505.278 0.000, 33...
# 14  LINESTRING Z (339103.977 7380489.345 0.000, 33...
# 15  LINESTRING Z (339345.338 7380462.309 0.000, 33...
# 16  LINESTRING Z (339237.619 7380344.119 0.000, 33...
# 17  LINESTRING Z (339376.602 7380400.262 0.000, 33...
# 18  LINESTRING Z (339392.016 7380285.122 0.000, 33...
# 19  LINESTRING Z (339535.192 7380817.867 0.000, 33...
# 20  LINESTRING Z (339414.326 7380805.487 0.000, 33...
# 21  LINESTRING Z (339414.326 7380805.487 0.000, 33...
# 22  LINESTRING Z (339478.841 7380817.526 0.000, 33...
# 23  LINESTRING Z (339202.172 7380801.233 0.000, 33...
# 24  LINESTRING Z (339235.468 7380877.194 0.000, 33...
# 25  LINESTRING Z (339331.823 7380261.576 0.000, 33...
# 26  LINESTRING Z (339569.797 7380314.991 0.000, 33...
# 27  LINESTRING Z (339254.982 7380727.724 0.000, 33...
# 28  LINESTRING Z (339335.664 7380647.718 0.000, 33...
# 29  LINESTRING Z (339088.768 7380781.477 0.000, 33...
# 30  LINESTRING Z (339122.680 7380717.247 0.000, 33...
# 31  LINESTRING Z (339300.410 7380531.428 0.000, 33...
# 32  LINESTRING Z (339194.764 7380693.515 0.000, 33...
# 33  LINESTRING Z (339292.274 7380664.124 0.000, 33...
# 34  LINESTRING Z (339473.671 7380542.991 0.000, 33...
# 35  LINESTRING Z (339072.678 7380393.349 0.000, 33...
# 36  LINESTRING Z (339220.694 7380451.475 0.000, 33...
# 37  LINESTRING Z (339267.298 7380435.950 0.000, 33...
# 38  LINESTRING Z (339424.736 7380385.081 0.000, 33...
# 39  LINESTRING Z (339183.391 7380515.296 0.000, 33...

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
# gdf_dxf.Layer.to_list()

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('!', '1')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('JOR[0-9]{1,4}')

# %%
gdf_dxf.DJI
# Out:
# 0     [JOR19]
# 1     [JOR17]
# 2     [JOR18]
# 3     [JOR37]
# 4      [JOR8]
# 5     [JOR25]
# 6     [JOR26]
# 7     [JOR42]
# 8     [JOR36]
# 9     [JOR36]
# 10    [JOR35]
# 11    [JOR20]
# 12    [JOR30]
# 13    [JOR12]
# 14    [JOR40]
# 15    [JOR33]
# 16    [JOR32]
# 17    [JOR15]
# 18     [JOR3]
# 19    [JOR10]
# 20    [JOR10]
# 21    [JOR10]
# 22     [JOR9]
# 23    [JOR11]
# 24    [JOR36]
# 25    [JOR31]
# 26    [JOR16]
# 27    [JOR38]
# 28    [JOR29]
# 29    [JOR43]
# 30    [JOR28]
# 31    [JOR21]
# 32    [JOR41]
# 33    [JOR27]
# 34    [JOR24]
# 35     [JOR5]
# 36    [JOR14]
# 37    [JOR34]
# 38     [JOR6]
# 39    [JOR39]
# Name: DJI, dtype: object

# %%
# gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer'].to_list()
# Out:
# []

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(JOR[0-9]{1,4})', expand=True)
# Out:
#                                               0         1     2      3     4  \
# 0                  RUA MARIO JÚLIO RODRIGUES -   05_01_20  None  21 -   None
# 1                         RUA CARLOS RIZZINI -   05_01_20  None  21 -   None
# 2                        RUA ADOLFO MONTEIRO -   05_01_20  None  21 -   None
# 3                          RUA EDNO ZENORINI -   05_01_20  None  21 -   None
# 4                       RUA ALFREDO ANGELINI -   05_01_20  None  21 -   None
# 5                        RUA NOVAIS TEIXEIRA -   05_01_20  None  21 -   None
# 6                          RUA GÓIS MONTEIRO -   05_01_20  None  21 -   None
# 7                      RUA LUÍS ALONSO PÉREZ -   05_01_20  None  21 -   None
# 8                RUA CLEONICE CÂNDIDA FANANI -   05_01_20  None  21 -   None
# 9                RUA CLEONICE CÂNDIDA FANANI -   05_01_20  None  21 -   None
# 10                         RUA HERBERT MOSES -   05_01_20  None  21 -   None
# 11                     RUA DALVA DE OLIVEIRA -   05_01_20  None  21 -   None
# 12                       RUA PAGANO SOBRINHO -   05_01_20  None  21 -   None
# 13                        RUA ODUVALDO VIANA -   05_01_20  None  21 -   None
# 14                         RUA HENRIQUE DIAS -   05_01_20  None  21 -   None
# 15                        RUA MILTON RIBEIRO -   05_01_20  None  21 -   None
# 16                          RUA SOUZA DANTAS -   05_01_20  None  21 -   None
# 17                             RUA PERCY LAU -   05_01_20  None  21 -   None
# 18                         RUA MILTON CAMPOS -   05_01_20  None  21 -   None
# 19                     RUA ARNALDO MARGONARI -   05_01_20  None  21 -   None
# 20                     RUA ARNALDO MARGONARI -   05_01_20  None  21 -   None
# 21                     RUA ARNALDO MARGONARI -   05_01_20  None  21 -   None
# 22                RUA CÉLSO TADEU DOS SANTOS -   05_01_20  None  21 -   None
# 23  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES -   05_01_20  None  21 -   None
# 24               RUA CLEONICE CÂNDIDA FANANI -   05_01_20  None  21 -   None
# 25                        RUA MOACIR PADILHA -   05_01_20  None  21 -   None
# 26                     RUA OSWALD DE ANDRADE -   05_01_20  None  21 -   None
# 27                         RUA ARTUR PONTUAL -   05_01_20  None  21 -   None
# 28                   RUA QUINTANILHA RIBEIRO -   05_01_20  None  21 -   None
# 29                     RUA RODRIGUES DO VALE -   05_01_20  None  21 -   None
# 30                     RUA EGÍDIO MICHAELSEN -   05_01_20  None  21 -   None
# 31                       RUA PAULO MAGALHÃES -   05_01_20  None  21 -   None
# 32                    RUA RANGEL DE CARVALHO -   05_01_20  None  21 -   None
# 33                     RUA PATRÍCIO TEIXEIRA -   05_01_20  None  21 -   None
# 34                        RUA ÉDSON CARNEIRO -   05_01_20  None  21 -   None
# 35                     RUA SILAS DE OLIVEIRA -   05_01_20  None  21 -   None
# 36                 RUA EDMUNDO BARRETO PINTO -   05_01_20  None  21 -   None
# 37                         RUA EUGÊNIO GOMES -   05_01_20  None  21 -   None
# 38                        RUA MIGUEL GUSTAVO -   05_01_20  None  21 -   None
# 39                       RUA MARTIM SILVEIRA -   05_01_20  None  21 -   None
#
#         5 6
# 0   JOR19
# 1   JOR17
# 2   JOR18
# 3   JOR37
# 4    JOR8
# 5   JOR25
# 6   JOR26
# 7   JOR42
# 8   JOR36
# 9   JOR36
# 10  JOR35
# 11  JOR20
# 12  JOR30
# 13  JOR12
# 14  JOR40
# 15  JOR33
# 16  JOR32
# 17  JOR15
# 18   JOR3
# 19  JOR10
# 20  JOR10
# 21  JOR10
# 22   JOR9
# 23  JOR11
# 24  JOR36
# 25  JOR31
# 26  JOR16
# 27  JOR38
# 28  JOR29
# 29  JOR43
# 30  JOR28
# 31  JOR21
# 32  JOR41
# 33  JOR27
# 34  JOR24
# 35   JOR5
# 36  JOR14
# 37  JOR34
# 38   JOR6
# 39  JOR39

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(JOR[0-9]{1,4})', expand=True)[3].unique().tolist()
# Out:
# ['21 - ']

# %%
etapas = {
     '21 - ':'etapa_00', 
    '21 -':'etapa_00',
    '':'etapa_00',
    '21- ':'etapa_00'
}

# %%
len(etapas)
# Out:
# 4

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(JOR[0-9]{1,4})', expand=True)[3].map(etapas)
# Out:
# 0     etapa_00
# 1     etapa_00
# 2     etapa_00
# 3     etapa_00
# 4     etapa_00
# 5     etapa_00
# 6     etapa_00
# 7     etapa_00
# 8     etapa_00
# 9     etapa_00
# 10    etapa_00
# 11    etapa_00
# 12    etapa_00
# 13    etapa_00
# 14    etapa_00
# 15    etapa_00
# 16    etapa_00
# 17    etapa_00
# 18    etapa_00
# 19    etapa_00
# 20    etapa_00
# 21    etapa_00
# 22    etapa_00
# 23    etapa_00
# 24    etapa_00
# 25    etapa_00
# 26    etapa_00
# 27    etapa_00
# 28    etapa_00
# 29    etapa_00
# 30    etapa_00
# 31    etapa_00
# 32    etapa_00
# 33    etapa_00
# 34    etapa_00
# 35    etapa_00
# 36    etapa_00
# 37    etapa_00
# 38    etapa_00
# 39    etapa_00
# Name: 3, dtype: object

# %%
gdf_dxf.loc[:, 'etapa'] = gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(JOR[0-9]{1,4})', expand=True)[3].map(etapas)

# %%
gdf_dxf.loc[:, 'etapa']
# Out:
# 0     etapa_00
# 1     etapa_00
# 2     etapa_00
# 3     etapa_00
# 4     etapa_00
# 5     etapa_00
# 6     etapa_00
# 7     etapa_00
# 8     etapa_00
# 9     etapa_00
# 10    etapa_00
# 11    etapa_00
# 12    etapa_00
# 13    etapa_00
# 14    etapa_00
# 15    etapa_00
# 16    etapa_00
# 17    etapa_00
# 18    etapa_00
# 19    etapa_00
# 20    etapa_00
# 21    etapa_00
# 22    etapa_00
# 23    etapa_00
# 24    etapa_00
# 25    etapa_00
# 26    etapa_00
# 27    etapa_00
# 28    etapa_00
# 29    etapa_00
# 30    etapa_00
# 31    etapa_00
# 32    etapa_00
# 33    etapa_00
# 34    etapa_00
# 35    etapa_00
# 36    etapa_00
# 37    etapa_00
# 38    etapa_00
# 39    etapa_00
# Name: etapa, dtype: object

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0      RUA MARIO JÚLIO RODRIGUES - 05_01_2021 - JOR19       None
# 1             RUA CARLOS RIZZINI - 05_01_2021 - JOR17       None
# 2            RUA ADOLFO MONTEIRO - 05_01_2021 - JOR18       None
# 3              RUA EDNO ZENORINI - 05_01_2021 - JOR37       None
# 4            RUA ALFREDO ANGELINI - 05_01_2021 - JOR8       None
# 5            RUA NOVAIS TEIXEIRA - 05_01_2021 - JOR25       None
# 6              RUA GÓIS MONTEIRO - 05_01_2021 - JOR26       None
# 7          RUA LUÍS ALONSO PÉREZ - 05_01_2021 - JOR42       None
# 8    RUA CLEONICE CÂNDIDA FANANI - 05_01_2021 - JOR36       None
# 9    RUA CLEONICE CÂNDIDA FANANI - 05_01_2021 - JOR36       None
# 10             RUA HERBERT MOSES - 05_01_2021 - JOR35       None
# 11         RUA DALVA DE OLIVEIRA - 05_01_2021 - JOR20       None
# 12           RUA PAGANO SOBRINHO - 05_01_2021 - JOR30       None
# 13            RUA ODUVALDO VIANA - 05_01_2021 - JOR12       None
# 14             RUA HENRIQUE DIAS - 05_01_2021 - JOR40       None
# 15            RUA MILTON RIBEIRO - 05_01_2021 - JOR33       None
# 16              RUA SOUZA DANTAS - 05_01_2021 - JOR32       None
# 17                 RUA PERCY LAU - 05_01_2021 - JOR15       None
# 18              RUA MILTON CAMPOS - 05_01_2021 - JOR3       None
# 19         RUA ARNALDO MARGONARI - 05_01_2021 - JOR10       None
# 20         RUA ARNALDO MARGONARI - 05_01_2021 - JOR10       None
# 21         RUA ARNALDO MARGONARI - 05_01_2021 - JOR10       None
# 22     RUA CÉLSO TADEU DOS SANTOS - 05_01_2021 - JOR9       None
# 23  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES - 05_...       None
# 24   RUA CLEONICE CÂNDIDA FANANI - 05_01_2021 - JOR36       None
# 25            RUA MOACIR PADILHA - 05_01_2021 - JOR31       None
# 26         RUA OSWALD DE ANDRADE - 05_01_2021 - JOR16       None
# 27             RUA ARTUR PONTUAL - 05_01_2021 - JOR38       None
# 28       RUA QUINTANILHA RIBEIRO - 05_01_2021 - JOR29       None
# 29         RUA RODRIGUES DO VALE - 05_01_2021 - JOR43       None
# 30         RUA EGÍDIO MICHAELSEN - 05_01_2021 - JOR28       None
# 31           RUA PAULO MAGALHÃES - 05_01_2021 - JOR21       None
# 32        RUA RANGEL DE CARVALHO - 05_01_2021 - JOR41       None
# 33         RUA PATRÍCIO TEIXEIRA - 05_01_2021 - JOR27       None
# 34            RUA ÉDSON CARNEIRO - 05_01_2021 - JOR24       None
# 35          RUA SILAS DE OLIVEIRA - 05_01_2021 - JOR5       None
# 36     RUA EDMUNDO BARRETO PINTO - 05_01_2021 - JOR14       None
# 37             RUA EUGÊNIO GOMES - 05_01_2021 - JOR34       None
# 38             RUA MIGUEL GUSTAVO - 05_01_2021 - JOR6       None
# 39           RUA MARTIM SILVEIRA - 05_01_2021 - JOR39       None
#
#                        SubClasses Linetype EntityHandle  Text  \
# 0       AcDbEntity:AcDb2dPolyline     None           6F  None
# 1       AcDbEntity:AcDb2dPolyline     None           74  None
# 2       AcDbEntity:AcDb2dPolyline     None           79  None
# 3       AcDbEntity:AcDb2dPolyline     None           84  None
# 4       AcDbEntity:AcDb2dPolyline     None           89  None
# 5       AcDbEntity:AcDb2dPolyline     None           8E  None
# 6       AcDbEntity:AcDb2dPolyline     None           93  None
# 7       AcDbEntity:AcDb2dPolyline     None           98  None
# 8             AcDbEntity:AcDbLine     None           9D  None
# 9             AcDbEntity:AcDbLine     None           9E  None
# 10            AcDbEntity:AcDbLine     None           A0  None
# 11      AcDbEntity:AcDb2dPolyline     None           A2  None
# 12      AcDbEntity:AcDb2dPolyline     None           A7  None
# 13      AcDbEntity:AcDb2dPolyline     None           AC  None
# 14      AcDbEntity:AcDb2dPolyline     None           B1  None
# 15      AcDbEntity:AcDb2dPolyline     None           B6  None
# 16      AcDbEntity:AcDb2dPolyline     None           BB  None
# 17      AcDbEntity:AcDb2dPolyline     None           C0  None
# 18      AcDbEntity:AcDb2dPolyline     None           C7  None
# 19            AcDbEntity:AcDbLine     None           CD  None
# 20  AcDbEntity:AcDbCircle:AcDbArc     None           CE  None
# 21            AcDbEntity:AcDbLine     None           CF  None
# 22      AcDbEntity:AcDb2dPolyline     None           D1  None
# 23      AcDbEntity:AcDb2dPolyline     None           D6  None
# 24      AcDbEntity:AcDb2dPolyline     None           E1  None
# 25      AcDbEntity:AcDb2dPolyline     None           E7  None
# 26      AcDbEntity:AcDb2dPolyline     None           EC  None
# 27      AcDbEntity:AcDb2dPolyline     None           F5  None
# 28      AcDbEntity:AcDb2dPolyline     None           FA  None
# 29      AcDbEntity:AcDb2dPolyline     None           FF  None
# 30      AcDbEntity:AcDb2dPolyline     None          104  None
# 31      AcDbEntity:AcDb2dPolyline     None          109  None
# 32      AcDbEntity:AcDb2dPolyline     None          10E  None
# 33      AcDbEntity:AcDb2dPolyline     None          113  None
# 34      AcDbEntity:AcDb2dPolyline     None          118  None
# 35      AcDbEntity:AcDb2dPolyline     None          11D  None
# 36      AcDbEntity:AcDb2dPolyline     None          122  None
# 37      AcDbEntity:AcDb2dPolyline     None          127  None
# 38      AcDbEntity:AcDb2dPolyline     None          12C  None
# 39      AcDbEntity:AcDb2dPolyline     None          131  None
#
#                                              geometry  \
# 0   LINESTRING Z (338950.604 7380710.573 0.000, 33...
# 1   LINESTRING Z (338904.211 7380723.301 0.000, 33...
# 2   LINESTRING Z (338826.162 7380632.174 0.000, 33...
# 3   LINESTRING Z (339285.680 7380860.317 0.000, 33...
# 4   LINESTRING Z (339038.423 7380797.758 0.000, 33...
# 5   LINESTRING Z (339555.874 7380630.417 0.000, 33...
# 6   LINESTRING Z (339453.927 7380482.390 0.000, 33...
# 7   LINESTRING Z (339145.316 7380788.276 0.000, 33...
# 8   LINESTRING Z (339347.025 7380832.388 0.000, 33...
# 9   LINESTRING Z (339330.765 7380778.903 0.000, 33...
# 10  LINESTRING Z (339321.300 7380763.046 0.000, 33...
# 11  LINESTRING Z (338991.844 7380630.689 0.000, 33...
# 12  LINESTRING Z (339413.136 7380676.275 0.000, 33...
# 13  LINESTRING Z (339055.127 7380505.278 0.000, 33...
# 14  LINESTRING Z (339103.977 7380489.345 0.000, 33...
# 15  LINESTRING Z (339345.338 7380462.309 0.000, 33...
# 16  LINESTRING Z (339237.619 7380344.119 0.000, 33...
# 17  LINESTRING Z (339376.602 7380400.262 0.000, 33...
# 18  LINESTRING Z (339392.016 7380285.122 0.000, 33...
# 19  LINESTRING Z (339535.192 7380817.867 0.000, 33...
# 20  LINESTRING Z (339414.326 7380805.487 0.000, 33...
# 21  LINESTRING Z (339414.326 7380805.487 0.000, 33...
# 22  LINESTRING Z (339478.841 7380817.526 0.000, 33...
# 23  LINESTRING Z (339202.172 7380801.233 0.000, 33...
# 24  LINESTRING Z (339235.468 7380877.194 0.000, 33...
# 25  LINESTRING Z (339331.823 7380261.576 0.000, 33...
# 26  LINESTRING Z (339569.797 7380314.991 0.000, 33...
# 27  LINESTRING Z (339254.982 7380727.724 0.000, 33...
# 28  LINESTRING Z (339335.664 7380647.718 0.000, 33...
# 29  LINESTRING Z (339088.768 7380781.477 0.000, 33...
# 30  LINESTRING Z (339122.680 7380717.247 0.000, 33...
# 31  LINESTRING Z (339300.410 7380531.428 0.000, 33...
# 32  LINESTRING Z (339194.764 7380693.515 0.000, 33...
# 33  LINESTRING Z (339292.274 7380664.124 0.000, 33...
# 34  LINESTRING Z (339473.671 7380542.991 0.000, 33...
# 35  LINESTRING Z (339072.678 7380393.349 0.000, 33...
# 36  LINESTRING Z (339220.694 7380451.475 0.000, 33...
# 37  LINESTRING Z (339267.298 7380435.950 0.000, 33...
# 38  LINESTRING Z (339424.736 7380385.081 0.000, 33...
# 39  LINESTRING Z (339183.391 7380515.296 0.000, 33...
#
#                                                 lista      DJI  data_voo  \
# 0      [RUA MARIO JÚLIO RODRIGUES, 05_01_2021, JOR19]  [JOR19]  05_01_20
# 1             [RUA CARLOS RIZZINI, 05_01_2021, JOR17]  [JOR17]  05_01_20
# 2            [RUA ADOLFO MONTEIRO, 05_01_2021, JOR18]  [JOR18]  05_01_20
# 3              [RUA EDNO ZENORINI, 05_01_2021, JOR37]  [JOR37]  05_01_20
# 4            [RUA ALFREDO ANGELINI, 05_01_2021, JOR8]   [JOR8]  05_01_20
# 5            [RUA NOVAIS TEIXEIRA, 05_01_2021, JOR25]  [JOR25]  05_01_20
# 6              [RUA GÓIS MONTEIRO, 05_01_2021, JOR26]  [JOR26]  05_01_20
# 7          [RUA LUÍS ALONSO PÉREZ, 05_01_2021, JOR42]  [JOR42]  05_01_20
# 8    [RUA CLEONICE CÂNDIDA FANANI, 05_01_2021, JOR36]  [JOR36]  05_01_20
# 9    [RUA CLEONICE CÂNDIDA FANANI, 05_01_2021, JOR36]  [JOR36]  05_01_20
# 10             [RUA HERBERT MOSES, 05_01_2021, JOR35]  [JOR35]  05_01_20
# 11         [RUA DALVA DE OLIVEIRA, 05_01_2021, JOR20]  [JOR20]  05_01_20
# 12           [RUA PAGANO SOBRINHO, 05_01_2021, JOR30]  [JOR30]  05_01_20
# 13            [RUA ODUVALDO VIANA, 05_01_2021, JOR12]  [JOR12]  05_01_20
# 14             [RUA HENRIQUE DIAS, 05_01_2021, JOR40]  [JOR40]  05_01_20
# 15            [RUA MILTON RIBEIRO, 05_01_2021, JOR33]  [JOR33]  05_01_20
# 16              [RUA SOUZA DANTAS, 05_01_2021, JOR32]  [JOR32]  05_01_20
# 17                 [RUA PERCY LAU, 05_01_2021, JOR15]  [JOR15]  05_01_20
# 18              [RUA MILTON CAMPOS, 05_01_2021, JOR3]   [JOR3]  05_01_20
# 19         [RUA ARNALDO MARGONARI, 05_01_2021, JOR10]  [JOR10]  05_01_20
# 20         [RUA ARNALDO MARGONARI, 05_01_2021, JOR10]  [JOR10]  05_01_20
# 21         [RUA ARNALDO MARGONARI, 05_01_2021, JOR10]  [JOR10]  05_01_20
# 22     [RUA CÉLSO TADEU DOS SANTOS, 05_01_2021, JOR9]   [JOR9]  05_01_20
# 23  [RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES, 05_...  [JOR11]  05_01_20
# 24   [RUA CLEONICE CÂNDIDA FANANI, 05_01_2021, JOR36]  [JOR36]  05_01_20
# 25            [RUA MOACIR PADILHA, 05_01_2021, JOR31]  [JOR31]  05_01_20
# 26         [RUA OSWALD DE ANDRADE, 05_01_2021, JOR16]  [JOR16]  05_01_20
# 27             [RUA ARTUR PONTUAL, 05_01_2021, JOR38]  [JOR38]  05_01_20
# 28       [RUA QUINTANILHA RIBEIRO, 05_01_2021, JOR29]  [JOR29]  05_01_20
# 29         [RUA RODRIGUES DO VALE, 05_01_2021, JOR43]  [JOR43]  05_01_20
# 30         [RUA EGÍDIO MICHAELSEN, 05_01_2021, JOR28]  [JOR28]  05_01_20
# 31           [RUA PAULO MAGALHÃES, 05_01_2021, JOR21]  [JOR21]  05_01_20
# 32        [RUA RANGEL DE CARVALHO, 05_01_2021, JOR41]  [JOR41]  05_01_20
# 33         [RUA PATRÍCIO TEIXEIRA, 05_01_2021, JOR27]  [JOR27]  05_01_20
# 34            [RUA ÉDSON CARNEIRO, 05_01_2021, JOR24]  [JOR24]  05_01_20
# 35          [RUA SILAS DE OLIVEIRA, 05_01_2021, JOR5]   [JOR5]  05_01_20
# 36     [RUA EDMUNDO BARRETO PINTO, 05_01_2021, JOR14]  [JOR14]  05_01_20
# 37             [RUA EUGÊNIO GOMES, 05_01_2021, JOR34]  [JOR34]  05_01_20
# 38             [RUA MIGUEL GUSTAVO, 05_01_2021, JOR6]   [JOR6]  05_01_20
# 39           [RUA MARTIM SILVEIRA, 05_01_2021, JOR39]  [JOR39]  05_01_20
#
#                                   logradouro     etapa
# 0                  RUA MARIO JÚLIO RODRIGUES  etapa_00
# 1                         RUA CARLOS RIZZINI  etapa_00
# 2                        RUA ADOLFO MONTEIRO  etapa_00
# 3                          RUA EDNO ZENORINI  etapa_00
# 4                       RUA ALFREDO ANGELINI  etapa_00
# 5                        RUA NOVAIS TEIXEIRA  etapa_00
# 6                          RUA GÓIS MONTEIRO  etapa_00
# 7                      RUA LUÍS ALONSO PÉREZ  etapa_00
# 8                RUA CLEONICE CÂNDIDA FANANI  etapa_00
# 9                RUA CLEONICE CÂNDIDA FANANI  etapa_00
# 10                         RUA HERBERT MOSES  etapa_00
# 11                     RUA DALVA DE OLIVEIRA  etapa_00
# 12                       RUA PAGANO SOBRINHO  etapa_00
# 13                        RUA ODUVALDO VIANA  etapa_00
# 14                         RUA HENRIQUE DIAS  etapa_00
# 15                        RUA MILTON RIBEIRO  etapa_00
# 16                          RUA SOUZA DANTAS  etapa_00
# 17                             RUA PERCY LAU  etapa_00
# 18                         RUA MILTON CAMPOS  etapa_00
# 19                     RUA ARNALDO MARGONARI  etapa_00
# 20                     RUA ARNALDO MARGONARI  etapa_00
# 21                     RUA ARNALDO MARGONARI  etapa_00
# 22                RUA CÉLSO TADEU DOS SANTOS  etapa_00
# 23  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES  etapa_00
# 24               RUA CLEONICE CÂNDIDA FANANI  etapa_00
# 25                        RUA MOACIR PADILHA  etapa_00
# 26                     RUA OSWALD DE ANDRADE  etapa_00
# 27                         RUA ARTUR PONTUAL  etapa_00
# 28                   RUA QUINTANILHA RIBEIRO  etapa_00
# 29                     RUA RODRIGUES DO VALE  etapa_00
# 30                     RUA EGÍDIO MICHAELSEN  etapa_00
# 31                       RUA PAULO MAGALHÃES  etapa_00
# 32                    RUA RANGEL DE CARVALHO  etapa_00
# 33                     RUA PATRÍCIO TEIXEIRA  etapa_00
# 34                        RUA ÉDSON CARNEIRO  etapa_00
# 35                     RUA SILAS DE OLIVEIRA  etapa_00
# 36                 RUA EDMUNDO BARRETO PINTO  etapa_00
# 37                         RUA EUGÊNIO GOMES  etapa_00
# 38                        RUA MIGUEL GUSTAVO  etapa_00
# 39                       RUA MARTIM SILVEIRA  etapa_00

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#       Video_0
# 0   JOR19.MOV
# 1   JOR17.MOV
# 2   JOR18.MOV
# 3   JOR37.MOV
# 4    JOR8.MOV
# 5   JOR25.MOV
# 6   JOR26.MOV
# 7   JOR42.MOV
# 8   JOR36.MOV
# 9   JOR36.MOV
# 10  JOR35.MOV
# 11  JOR20.MOV
# 12  JOR30.MOV
# 13  JOR12.MOV
# 14  JOR40.MOV
# 15  JOR33.MOV
# 16  JOR32.MOV
# 17  JOR15.MOV
# 18   JOR3.MOV
# 19  JOR10.MOV
# 20  JOR10.MOV
# 21  JOR10.MOV
# 22   JOR9.MOV
# 23  JOR11.MOV
# 24  JOR36.MOV
# 25  JOR31.MOV
# 26  JOR16.MOV
# 27  JOR38.MOV
# 28  JOR29.MOV
# 29  JOR43.MOV
# 30  JOR28.MOV
# 31  JOR21.MOV
# 32  JOR41.MOV
# 33  JOR27.MOV
# 34  JOR24.MOV
# 35   JOR5.MOV
# 36  JOR14.MOV
# 37  JOR34.MOV
# 38   JOR6.MOV
# 39  JOR39.MOV

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'data_voo', 'logradouro', 'etapa',
#        'Video_0'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + bairro.lower().replace('-', '_') + '/' + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                                 Layer  \
# 0            RUA ADOLFO MONTEIRO - 05_01_2021 - JOR18
# 1            RUA ALFREDO ANGELINI - 05_01_2021 - JOR8
# 2          RUA ARNALDO MARGONARI - 05_01_2021 - JOR10
# 3              RUA ARTUR PONTUAL - 05_01_2021 - JOR38
# 4             RUA CARLOS RIZZINI - 05_01_2021 - JOR17
# 5    RUA CLEONICE CÂNDIDA FANANI - 05_01_2021 - JOR36
# 6      RUA CÉLSO TADEU DOS SANTOS - 05_01_2021 - JOR9
# 7          RUA DALVA DE OLIVEIRA - 05_01_2021 - JOR20
# 8      RUA EDMUNDO BARRETO PINTO - 05_01_2021 - JOR14
# 9              RUA EDNO ZENORINI - 05_01_2021 - JOR37
# 10         RUA EGÍDIO MICHAELSEN - 05_01_2021 - JOR28
# 11             RUA EUGÊNIO GOMES - 05_01_2021 - JOR34
# 12             RUA GÓIS MONTEIRO - 05_01_2021 - JOR26
# 13             RUA HENRIQUE DIAS - 05_01_2021 - JOR40
# 14             RUA HERBERT MOSES - 05_01_2021 - JOR35
# 15         RUA LUÍS ALONSO PÉREZ - 05_01_2021 - JOR42
# 16     RUA MARIO JÚLIO RODRIGUES - 05_01_2021 - JOR19
# 17           RUA MARTIM SILVEIRA - 05_01_2021 - JOR39
# 18  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES - 05_...
# 19             RUA MIGUEL GUSTAVO - 05_01_2021 - JOR6
# 20              RUA MILTON CAMPOS - 05_01_2021 - JOR3
# 21            RUA MILTON RIBEIRO - 05_01_2021 - JOR33
# 22            RUA MOACIR PADILHA - 05_01_2021 - JOR31
# 23           RUA NOVAIS TEIXEIRA - 05_01_2021 - JOR25
# 24            RUA ODUVALDO VIANA - 05_01_2021 - JOR12
# 25         RUA OSWALD DE ANDRADE - 05_01_2021 - JOR16
# 26           RUA PAGANO SOBRINHO - 05_01_2021 - JOR30
# 27         RUA PATRÍCIO TEIXEIRA - 05_01_2021 - JOR27
# 28           RUA PAULO MAGALHÃES - 05_01_2021 - JOR21
# 29                 RUA PERCY LAU - 05_01_2021 - JOR15
# 30       RUA QUINTANILHA RIBEIRO - 05_01_2021 - JOR29
# 31        RUA RANGEL DE CARVALHO - 05_01_2021 - JOR41
# 32         RUA RODRIGUES DO VALE - 05_01_2021 - JOR43
# 33          RUA SILAS DE OLIVEIRA - 05_01_2021 - JOR5
# 34              RUA SOUZA DANTAS - 05_01_2021 - JOR32
# 35            RUA ÉDSON CARNEIRO - 05_01_2021 - JOR24
#
#                                              geometry PaperSpace  \
# 0   LINESTRING Z (338826.162 7380632.174 0.000, 33...       None
# 1   LINESTRING Z (339038.423 7380797.758 0.000, 33...       None
# 2   MULTILINESTRING Z ((339535.192 7380817.867 0.0...       None
# 3   LINESTRING Z (339254.982 7380727.724 0.000, 33...       None
# 4   LINESTRING Z (338904.211 7380723.301 0.000, 33...       None
# 5   MULTILINESTRING Z ((339347.025 7380832.388 0.0...       None
# 6   LINESTRING Z (339478.841 7380817.526 0.000, 33...       None
# 7   LINESTRING Z (338991.844 7380630.689 0.000, 33...       None
# 8   LINESTRING Z (339220.694 7380451.475 0.000, 33...       None
# 9   LINESTRING Z (339285.680 7380860.317 0.000, 33...       None
# 10  LINESTRING Z (339122.680 7380717.247 0.000, 33...       None
# 11  LINESTRING Z (339267.298 7380435.950 0.000, 33...       None
# 12  LINESTRING Z (339453.927 7380482.390 0.000, 33...       None
# 13  LINESTRING Z (339103.977 7380489.345 0.000, 33...       None
# 14  LINESTRING Z (339321.300 7380763.046 0.000, 33...       None
# 15  LINESTRING Z (339145.316 7380788.276 0.000, 33...       None
# 16  LINESTRING Z (338950.604 7380710.573 0.000, 33...       None
# 17  LINESTRING Z (339183.391 7380515.296 0.000, 33...       None
# 18  LINESTRING Z (339202.172 7380801.233 0.000, 33...       None
# 19  LINESTRING Z (339424.736 7380385.081 0.000, 33...       None
# 20  LINESTRING Z (339392.016 7380285.122 0.000, 33...       None
# 21  LINESTRING Z (339345.338 7380462.309 0.000, 33...       None
# 22  LINESTRING Z (339331.823 7380261.576 0.000, 33...       None
# 23  LINESTRING Z (339555.874 7380630.417 0.000, 33...       None
# 24  LINESTRING Z (339055.127 7380505.278 0.000, 33...       None
# 25  LINESTRING Z (339569.797 7380314.991 0.000, 33...       None
# 26  LINESTRING Z (339413.136 7380676.275 0.000, 33...       None
# 27  LINESTRING Z (339292.274 7380664.124 0.000, 33...       None
# 28  LINESTRING Z (339300.410 7380531.428 0.000, 33...       None
# 29  LINESTRING Z (339376.602 7380400.262 0.000, 33...       None
# 30  LINESTRING Z (339335.664 7380647.718 0.000, 33...       None
# 31  LINESTRING Z (339194.764 7380693.515 0.000, 33...       None
# 32  LINESTRING Z (339088.768 7380781.477 0.000, 33...       None
# 33  LINESTRING Z (339072.678 7380393.349 0.000, 33...       None
# 34  LINESTRING Z (339237.619 7380344.119 0.000, 33...       None
# 35  LINESTRING Z (339473.671 7380542.991 0.000, 33...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None           79  None
# 1   AcDbEntity:AcDb2dPolyline     None           89  None
# 2         AcDbEntity:AcDbLine     None           CD  None
# 3   AcDbEntity:AcDb2dPolyline     None           F5  None
# 4   AcDbEntity:AcDb2dPolyline     None           74  None
# 5         AcDbEntity:AcDbLine     None           9D  None
# 6   AcDbEntity:AcDb2dPolyline     None           D1  None
# 7   AcDbEntity:AcDb2dPolyline     None           A2  None
# 8   AcDbEntity:AcDb2dPolyline     None          122  None
# 9   AcDbEntity:AcDb2dPolyline     None           84  None
# 10  AcDbEntity:AcDb2dPolyline     None          104  None
# 11  AcDbEntity:AcDb2dPolyline     None          127  None
# 12  AcDbEntity:AcDb2dPolyline     None           93  None
# 13  AcDbEntity:AcDb2dPolyline     None           B1  None
# 14        AcDbEntity:AcDbLine     None           A0  None
# 15  AcDbEntity:AcDb2dPolyline     None           98  None
# 16  AcDbEntity:AcDb2dPolyline     None           6F  None
# 17  AcDbEntity:AcDb2dPolyline     None          131  None
# 18  AcDbEntity:AcDb2dPolyline     None           D6  None
# 19  AcDbEntity:AcDb2dPolyline     None          12C  None
# 20  AcDbEntity:AcDb2dPolyline     None           C7  None
# 21  AcDbEntity:AcDb2dPolyline     None           B6  None
# 22  AcDbEntity:AcDb2dPolyline     None           E7  None
# 23  AcDbEntity:AcDb2dPolyline     None           8E  None
# 24  AcDbEntity:AcDb2dPolyline     None           AC  None
# 25  AcDbEntity:AcDb2dPolyline     None           EC  None
# 26  AcDbEntity:AcDb2dPolyline     None           A7  None
# 27  AcDbEntity:AcDb2dPolyline     None          113  None
# 28  AcDbEntity:AcDb2dPolyline     None          109  None
# 29  AcDbEntity:AcDb2dPolyline     None           C0  None
# 30  AcDbEntity:AcDb2dPolyline     None           FA  None
# 31  AcDbEntity:AcDb2dPolyline     None          10E  None
# 32  AcDbEntity:AcDb2dPolyline     None           FF  None
# 33  AcDbEntity:AcDb2dPolyline     None          11D  None
# 34  AcDbEntity:AcDb2dPolyline     None           BB  None
# 35  AcDbEntity:AcDb2dPolyline     None          118  None
#
#                                                 lista      DJI   data_voo  \
# 0            [RUA ADOLFO MONTEIRO, 05_01_2021, JOR18]  [JOR18]  05_01_20/
# 1            [RUA ALFREDO ANGELINI, 05_01_2021, JOR8]   [JOR8]  05_01_20/
# 2          [RUA ARNALDO MARGONARI, 05_01_2021, JOR10]  [JOR10]  05_01_20/
# 3              [RUA ARTUR PONTUAL, 05_01_2021, JOR38]  [JOR38]  05_01_20/
# 4             [RUA CARLOS RIZZINI, 05_01_2021, JOR17]  [JOR17]  05_01_20/
# 5    [RUA CLEONICE CÂNDIDA FANANI, 05_01_2021, JOR36]  [JOR36]  05_01_20/
# 6      [RUA CÉLSO TADEU DOS SANTOS, 05_01_2021, JOR9]   [JOR9]  05_01_20/
# 7          [RUA DALVA DE OLIVEIRA, 05_01_2021, JOR20]  [JOR20]  05_01_20/
# 8      [RUA EDMUNDO BARRETO PINTO, 05_01_2021, JOR14]  [JOR14]  05_01_20/
# 9              [RUA EDNO ZENORINI, 05_01_2021, JOR37]  [JOR37]  05_01_20/
# 10         [RUA EGÍDIO MICHAELSEN, 05_01_2021, JOR28]  [JOR28]  05_01_20/
# 11             [RUA EUGÊNIO GOMES, 05_01_2021, JOR34]  [JOR34]  05_01_20/
# 12             [RUA GÓIS MONTEIRO, 05_01_2021, JOR26]  [JOR26]  05_01_20/
# 13             [RUA HENRIQUE DIAS, 05_01_2021, JOR40]  [JOR40]  05_01_20/
# 14             [RUA HERBERT MOSES, 05_01_2021, JOR35]  [JOR35]  05_01_20/
# 15         [RUA LUÍS ALONSO PÉREZ, 05_01_2021, JOR42]  [JOR42]  05_01_20/
# 16     [RUA MARIO JÚLIO RODRIGUES, 05_01_2021, JOR19]  [JOR19]  05_01_20/
# 17           [RUA MARTIM SILVEIRA, 05_01_2021, JOR39]  [JOR39]  05_01_20/
# 18  [RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES, 05_...  [JOR11]  05_01_20/
# 19             [RUA MIGUEL GUSTAVO, 05_01_2021, JOR6]   [JOR6]  05_01_20/
# 20              [RUA MILTON CAMPOS, 05_01_2021, JOR3]   [JOR3]  05_01_20/
# 21            [RUA MILTON RIBEIRO, 05_01_2021, JOR33]  [JOR33]  05_01_20/
# 22            [RUA MOACIR PADILHA, 05_01_2021, JOR31]  [JOR31]  05_01_20/
# 23           [RUA NOVAIS TEIXEIRA, 05_01_2021, JOR25]  [JOR25]  05_01_20/
# 24            [RUA ODUVALDO VIANA, 05_01_2021, JOR12]  [JOR12]  05_01_20/
# 25         [RUA OSWALD DE ANDRADE, 05_01_2021, JOR16]  [JOR16]  05_01_20/
# 26           [RUA PAGANO SOBRINHO, 05_01_2021, JOR30]  [JOR30]  05_01_20/
# 27         [RUA PATRÍCIO TEIXEIRA, 05_01_2021, JOR27]  [JOR27]  05_01_20/
# 28           [RUA PAULO MAGALHÃES, 05_01_2021, JOR21]  [JOR21]  05_01_20/
# 29                 [RUA PERCY LAU, 05_01_2021, JOR15]  [JOR15]  05_01_20/
# 30       [RUA QUINTANILHA RIBEIRO, 05_01_2021, JOR29]  [JOR29]  05_01_20/
# 31        [RUA RANGEL DE CARVALHO, 05_01_2021, JOR41]  [JOR41]  05_01_20/
# 32         [RUA RODRIGUES DO VALE, 05_01_2021, JOR43]  [JOR43]  05_01_20/
# 33          [RUA SILAS DE OLIVEIRA, 05_01_2021, JOR5]   [JOR5]  05_01_20/
# 34              [RUA SOUZA DANTAS, 05_01_2021, JOR32]  [JOR32]  05_01_20/
# 35            [RUA ÉDSON CARNEIRO, 05_01_2021, JOR24]  [JOR24]  05_01_20/
#
#                                   logradouro      etapa    Video_0  \
# 0                        RUA ADOLFO MONTEIRO  etapa_00/  JOR18.MOV
# 1                       RUA ALFREDO ANGELINI  etapa_00/   JOR8.MOV
# 2                      RUA ARNALDO MARGONARI  etapa_00/  JOR10.MOV
# 3                          RUA ARTUR PONTUAL  etapa_00/  JOR38.MOV
# 4                         RUA CARLOS RIZZINI  etapa_00/  JOR17.MOV
# 5                RUA CLEONICE CÂNDIDA FANANI  etapa_00/  JOR36.MOV
# 6                 RUA CÉLSO TADEU DOS SANTOS  etapa_00/   JOR9.MOV
# 7                      RUA DALVA DE OLIVEIRA  etapa_00/  JOR20.MOV
# 8                  RUA EDMUNDO BARRETO PINTO  etapa_00/  JOR14.MOV
# 9                          RUA EDNO ZENORINI  etapa_00/  JOR37.MOV
# 10                     RUA EGÍDIO MICHAELSEN  etapa_00/  JOR28.MOV
# 11                         RUA EUGÊNIO GOMES  etapa_00/  JOR34.MOV
# 12                         RUA GÓIS MONTEIRO  etapa_00/  JOR26.MOV
# 13                         RUA HENRIQUE DIAS  etapa_00/  JOR40.MOV
# 14                         RUA HERBERT MOSES  etapa_00/  JOR35.MOV
# 15                     RUA LUÍS ALONSO PÉREZ  etapa_00/  JOR42.MOV
# 16                 RUA MARIO JÚLIO RODRIGUES  etapa_00/  JOR19.MOV
# 17                       RUA MARTIM SILVEIRA  etapa_00/  JOR39.MOV
# 18  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES  etapa_00/  JOR11.MOV
# 19                        RUA MIGUEL GUSTAVO  etapa_00/   JOR6.MOV
# 20                         RUA MILTON CAMPOS  etapa_00/   JOR3.MOV
# 21                        RUA MILTON RIBEIRO  etapa_00/  JOR33.MOV
# 22                        RUA MOACIR PADILHA  etapa_00/  JOR31.MOV
# 23                       RUA NOVAIS TEIXEIRA  etapa_00/  JOR25.MOV
# 24                        RUA ODUVALDO VIANA  etapa_00/  JOR12.MOV
# 25                     RUA OSWALD DE ANDRADE  etapa_00/  JOR16.MOV
# 26                       RUA PAGANO SOBRINHO  etapa_00/  JOR30.MOV
# 27                     RUA PATRÍCIO TEIXEIRA  etapa_00/  JOR27.MOV
# 28                       RUA PAULO MAGALHÃES  etapa_00/  JOR21.MOV
# 29                             RUA PERCY LAU  etapa_00/  JOR15.MOV
# 30                   RUA QUINTANILHA RIBEIRO  etapa_00/  JOR29.MOV
# 31                    RUA RANGEL DE CARVALHO  etapa_00/  JOR41.MOV
# 32                     RUA RODRIGUES DO VALE  etapa_00/  JOR43.MOV
# 33                     RUA SILAS DE OLIVEIRA  etapa_00/   JOR5.MOV
# 34                          RUA SOUZA DANTAS  etapa_00/  JOR32.MOV
# 35                        RUA ÉDSON CARNEIRO  etapa_00/  JOR24.MOV
#
#                               Video_0_path
# 0   videos/jordanopolis/etapa_00/JOR18.MOV
# 1    videos/jordanopolis/etapa_00/JOR8.MOV
# 2   videos/jordanopolis/etapa_00/JOR10.MOV
# 3   videos/jordanopolis/etapa_00/JOR38.MOV
# 4   videos/jordanopolis/etapa_00/JOR17.MOV
# 5   videos/jordanopolis/etapa_00/JOR36.MOV
# 6    videos/jordanopolis/etapa_00/JOR9.MOV
# 7   videos/jordanopolis/etapa_00/JOR20.MOV
# 8   videos/jordanopolis/etapa_00/JOR14.MOV
# 9   videos/jordanopolis/etapa_00/JOR37.MOV
# 10  videos/jordanopolis/etapa_00/JOR28.MOV
# 11  videos/jordanopolis/etapa_00/JOR34.MOV
# 12  videos/jordanopolis/etapa_00/JOR26.MOV
# 13  videos/jordanopolis/etapa_00/JOR40.MOV
# 14  videos/jordanopolis/etapa_00/JOR35.MOV
# 15  videos/jordanopolis/etapa_00/JOR42.MOV
# 16  videos/jordanopolis/etapa_00/JOR19.MOV
# 17  videos/jordanopolis/etapa_00/JOR39.MOV
# 18  videos/jordanopolis/etapa_00/JOR11.MOV
# 19   videos/jordanopolis/etapa_00/JOR6.MOV
# 20   videos/jordanopolis/etapa_00/JOR3.MOV
# 21  videos/jordanopolis/etapa_00/JOR33.MOV
# 22  videos/jordanopolis/etapa_00/JOR31.MOV
# 23  videos/jordanopolis/etapa_00/JOR25.MOV
# 24  videos/jordanopolis/etapa_00/JOR12.MOV
# 25  videos/jordanopolis/etapa_00/JOR16.MOV
# 26  videos/jordanopolis/etapa_00/JOR30.MOV
# 27  videos/jordanopolis/etapa_00/JOR27.MOV
# 28  videos/jordanopolis/etapa_00/JOR21.MOV
# 29  videos/jordanopolis/etapa_00/JOR15.MOV
# 30  videos/jordanopolis/etapa_00/JOR29.MOV
# 31  videos/jordanopolis/etapa_00/JOR41.MOV
# 32  videos/jordanopolis/etapa_00/JOR43.MOV
# 33   videos/jordanopolis/etapa_00/JOR5.MOV
# 34  videos/jordanopolis/etapa_00/JOR32.MOV
# 35  videos/jordanopolis/etapa_00/JOR24.MOV

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1)
# Out:
#                                              geometry   data_voo  \
# 0   LINESTRING Z (338826.162 7380632.174 0.000, 33...  05_01_20/
# 1   LINESTRING Z (339038.423 7380797.758 0.000, 33...  05_01_20/
# 2   MULTILINESTRING Z ((339535.192 7380817.867 0.0...  05_01_20/
# 3   LINESTRING Z (339254.982 7380727.724 0.000, 33...  05_01_20/
# 4   LINESTRING Z (338904.211 7380723.301 0.000, 33...  05_01_20/
# 5   MULTILINESTRING Z ((339347.025 7380832.388 0.0...  05_01_20/
# 6   LINESTRING Z (339478.841 7380817.526 0.000, 33...  05_01_20/
# 7   LINESTRING Z (338991.844 7380630.689 0.000, 33...  05_01_20/
# 8   LINESTRING Z (339220.694 7380451.475 0.000, 33...  05_01_20/
# 9   LINESTRING Z (339285.680 7380860.317 0.000, 33...  05_01_20/
# 10  LINESTRING Z (339122.680 7380717.247 0.000, 33...  05_01_20/
# 11  LINESTRING Z (339267.298 7380435.950 0.000, 33...  05_01_20/
# 12  LINESTRING Z (339453.927 7380482.390 0.000, 33...  05_01_20/
# 13  LINESTRING Z (339103.977 7380489.345 0.000, 33...  05_01_20/
# 14  LINESTRING Z (339321.300 7380763.046 0.000, 33...  05_01_20/
# 15  LINESTRING Z (339145.316 7380788.276 0.000, 33...  05_01_20/
# 16  LINESTRING Z (338950.604 7380710.573 0.000, 33...  05_01_20/
# 17  LINESTRING Z (339183.391 7380515.296 0.000, 33...  05_01_20/
# 18  LINESTRING Z (339202.172 7380801.233 0.000, 33...  05_01_20/
# 19  LINESTRING Z (339424.736 7380385.081 0.000, 33...  05_01_20/
# 20  LINESTRING Z (339392.016 7380285.122 0.000, 33...  05_01_20/
# 21  LINESTRING Z (339345.338 7380462.309 0.000, 33...  05_01_20/
# 22  LINESTRING Z (339331.823 7380261.576 0.000, 33...  05_01_20/
# 23  LINESTRING Z (339555.874 7380630.417 0.000, 33...  05_01_20/
# 24  LINESTRING Z (339055.127 7380505.278 0.000, 33...  05_01_20/
# 25  LINESTRING Z (339569.797 7380314.991 0.000, 33...  05_01_20/
# 26  LINESTRING Z (339413.136 7380676.275 0.000, 33...  05_01_20/
# 27  LINESTRING Z (339292.274 7380664.124 0.000, 33...  05_01_20/
# 28  LINESTRING Z (339300.410 7380531.428 0.000, 33...  05_01_20/
# 29  LINESTRING Z (339376.602 7380400.262 0.000, 33...  05_01_20/
# 30  LINESTRING Z (339335.664 7380647.718 0.000, 33...  05_01_20/
# 31  LINESTRING Z (339194.764 7380693.515 0.000, 33...  05_01_20/
# 32  LINESTRING Z (339088.768 7380781.477 0.000, 33...  05_01_20/
# 33  LINESTRING Z (339072.678 7380393.349 0.000, 33...  05_01_20/
# 34  LINESTRING Z (339237.619 7380344.119 0.000, 33...  05_01_20/
# 35  LINESTRING Z (339473.671 7380542.991 0.000, 33...  05_01_20/
#
#                                   logradouro      etapa    Video_0  \
# 0                        RUA ADOLFO MONTEIRO  etapa_00/  JOR18.MOV
# 1                       RUA ALFREDO ANGELINI  etapa_00/   JOR8.MOV
# 2                      RUA ARNALDO MARGONARI  etapa_00/  JOR10.MOV
# 3                          RUA ARTUR PONTUAL  etapa_00/  JOR38.MOV
# 4                         RUA CARLOS RIZZINI  etapa_00/  JOR17.MOV
# 5                RUA CLEONICE CÂNDIDA FANANI  etapa_00/  JOR36.MOV
# 6                 RUA CÉLSO TADEU DOS SANTOS  etapa_00/   JOR9.MOV
# 7                      RUA DALVA DE OLIVEIRA  etapa_00/  JOR20.MOV
# 8                  RUA EDMUNDO BARRETO PINTO  etapa_00/  JOR14.MOV
# 9                          RUA EDNO ZENORINI  etapa_00/  JOR37.MOV
# 10                     RUA EGÍDIO MICHAELSEN  etapa_00/  JOR28.MOV
# 11                         RUA EUGÊNIO GOMES  etapa_00/  JOR34.MOV
# 12                         RUA GÓIS MONTEIRO  etapa_00/  JOR26.MOV
# 13                         RUA HENRIQUE DIAS  etapa_00/  JOR40.MOV
# 14                         RUA HERBERT MOSES  etapa_00/  JOR35.MOV
# 15                     RUA LUÍS ALONSO PÉREZ  etapa_00/  JOR42.MOV
# 16                 RUA MARIO JÚLIO RODRIGUES  etapa_00/  JOR19.MOV
# 17                       RUA MARTIM SILVEIRA  etapa_00/  JOR39.MOV
# 18  RUA MEJICA LEDESMA SEQUEIRA DE RODRIGUES  etapa_00/  JOR11.MOV
# 19                        RUA MIGUEL GUSTAVO  etapa_00/   JOR6.MOV
# 20                         RUA MILTON CAMPOS  etapa_00/   JOR3.MOV
# 21                        RUA MILTON RIBEIRO  etapa_00/  JOR33.MOV
# 22                        RUA MOACIR PADILHA  etapa_00/  JOR31.MOV
# 23                       RUA NOVAIS TEIXEIRA  etapa_00/  JOR25.MOV
# 24                        RUA ODUVALDO VIANA  etapa_00/  JOR12.MOV
# 25                     RUA OSWALD DE ANDRADE  etapa_00/  JOR16.MOV
# 26                       RUA PAGANO SOBRINHO  etapa_00/  JOR30.MOV
# 27                     RUA PATRÍCIO TEIXEIRA  etapa_00/  JOR27.MOV
# 28                       RUA PAULO MAGALHÃES  etapa_00/  JOR21.MOV
# 29                             RUA PERCY LAU  etapa_00/  JOR15.MOV
# 30                   RUA QUINTANILHA RIBEIRO  etapa_00/  JOR29.MOV
# 31                    RUA RANGEL DE CARVALHO  etapa_00/  JOR41.MOV
# 32                     RUA RODRIGUES DO VALE  etapa_00/  JOR43.MOV
# 33                     RUA SILAS DE OLIVEIRA  etapa_00/   JOR5.MOV
# 34                          RUA SOUZA DANTAS  etapa_00/  JOR32.MOV
# 35                        RUA ÉDSON CARNEIRO  etapa_00/  JOR24.MOV
#
#                               Video_0_path
# 0   videos/jordanopolis/etapa_00/JOR18.MOV
# 1    videos/jordanopolis/etapa_00/JOR8.MOV
# 2   videos/jordanopolis/etapa_00/JOR10.MOV
# 3   videos/jordanopolis/etapa_00/JOR38.MOV
# 4   videos/jordanopolis/etapa_00/JOR17.MOV
# 5   videos/jordanopolis/etapa_00/JOR36.MOV
# 6    videos/jordanopolis/etapa_00/JOR9.MOV
# 7   videos/jordanopolis/etapa_00/JOR20.MOV
# 8   videos/jordanopolis/etapa_00/JOR14.MOV
# 9   videos/jordanopolis/etapa_00/JOR37.MOV
# 10  videos/jordanopolis/etapa_00/JOR28.MOV
# 11  videos/jordanopolis/etapa_00/JOR34.MOV
# 12  videos/jordanopolis/etapa_00/JOR26.MOV
# 13  videos/jordanopolis/etapa_00/JOR40.MOV
# 14  videos/jordanopolis/etapa_00/JOR35.MOV
# 15  videos/jordanopolis/etapa_00/JOR42.MOV
# 16  videos/jordanopolis/etapa_00/JOR19.MOV
# 17  videos/jordanopolis/etapa_00/JOR39.MOV
# 18  videos/jordanopolis/etapa_00/JOR11.MOV
# 19   videos/jordanopolis/etapa_00/JOR6.MOV
# 20   videos/jordanopolis/etapa_00/JOR3.MOV
# 21  videos/jordanopolis/etapa_00/JOR33.MOV
# 22  videos/jordanopolis/etapa_00/JOR31.MOV
# 23  videos/jordanopolis/etapa_00/JOR25.MOV
# 24  videos/jordanopolis/etapa_00/JOR12.MOV
# 25  videos/jordanopolis/etapa_00/JOR16.MOV
# 26  videos/jordanopolis/etapa_00/JOR30.MOV
# 27  videos/jordanopolis/etapa_00/JOR27.MOV
# 28  videos/jordanopolis/etapa_00/JOR21.MOV
# 29  videos/jordanopolis/etapa_00/JOR15.MOV
# 30  videos/jordanopolis/etapa_00/JOR29.MOV
# 31  videos/jordanopolis/etapa_00/JOR41.MOV
# 32  videos/jordanopolis/etapa_00/JOR43.MOV
# 33   videos/jordanopolis/etapa_00/JOR5.MOV
# 34  videos/jordanopolis/etapa_00/JOR32.MOV
# 35  videos/jordanopolis/etapa_00/JOR24.MOV

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'etapa', 'data_voo', 'Video_0'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-Conflito-de-programas.gpkg', driver='GPKG')

# %%
gdf_dxf.to_crs('EPSG:4326').drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'etapa', 'data_voo', 'Video_0'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-Conflito-de-programas.geojson', driver='GeoJSON')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# data_voo          object
# logradouro        object
# etapa             object
# Video_0           object
# Video_0_path      object
# dtype: object

# %%
gdf_dxf.Video_0.isna().value_counts()
# Out:
# False    36
# Name: Video_0, dtype: int64
