# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/PAULICEIA EIXOS VIA - Conflito de Programas.dxf', encoding='ANSI_1252')

# %%
bairro = 'PAULICEIA'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0                RUA ACLIMAÃÃO - 06_01_2021 - PAL56       None
# 1            RUA LÃBERO BADARÃ - 06_01_2021 - PAL36       None
# 2           RUA XAVIER DE TOLEDO - 06_01_2021 - PAL48       None
# 3                    RUA MARTINS - 06_01_2021 - PAL30       None
# 4               RUA 17 DE MARÃO - 06_01_2021 - PAL73       None
# 5                    RUA CAMARGO - 06_01_2021 - PAL71       None
# 6                   RUA DRÃUSIO - 06_01_2021 - PAL72       None
# 7           RUA JOÃO BIANCALANA - 06_01_2021 - PAL70       None
# 8                    RUA SANTANA - 06_01_20210 - PAL3       None
# 9           RUA MIRAGAIA - 06_01_2021 - PAL31 - PAL32       None
# 10   RUA CÃSPER LÃBERO - 06_01_2021 - PAL28 - PAL29       None
# 11             RUA SENJI SUGUINO - 06_01_2021 - PAL58       None
# 12                 RUA JABAQUARA - 06_01_2021 - PAL55       None
# 13                      RUA LAPA - 06_01_2021 - PAL54       None
# 14              RUA ROSA CAPASSI - 06_01_2021 - PAL74       None
# 15  RUA JOAQUIM JOSÃ DE FRANÃA - 06_01_2021 - PAL75       None
# 16                   RUA VERÃO - 06_01_2021 -  PAL61       None
# 17             RUA JOÃO DEPOLLI - 06_01_2021 - PAL60       None
# 18                      RUA BRAZ - 06_01_2021 - PAL57       None
# 19                   RUA PERDIZES - 06_01_2021 - PAL4       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None           6F  None
# 1   AcDbEntity:AcDb2dPolyline     None           74  None
# 2   AcDbEntity:AcDb2dPolyline     None           79  None
# 3   AcDbEntity:AcDb2dPolyline     None           7E  None
# 4   AcDbEntity:AcDb2dPolyline     None           84  None
# 5   AcDbEntity:AcDb2dPolyline     None           8B  None
# 6   AcDbEntity:AcDb2dPolyline     None           92  None
# 7   AcDbEntity:AcDb2dPolyline     None           99  None
# 8   AcDbEntity:AcDb2dPolyline     None           9E  None
# 9   AcDbEntity:AcDb2dPolyline     None           A4  None
# 10  AcDbEntity:AcDb2dPolyline     None           B0  None
# 11  AcDbEntity:AcDb2dPolyline     None           BA  None
# 12  AcDbEntity:AcDb2dPolyline     None           BF  None
# 13  AcDbEntity:AcDb2dPolyline     None           C4  None
# 14  AcDbEntity:AcDb2dPolyline     None           C9  None
# 15  AcDbEntity:AcDb2dPolyline     None           CE  None
# 16  AcDbEntity:AcDb2dPolyline     None           D3  None
# 17  AcDbEntity:AcDb2dPolyline     None           D8  None
# 18  AcDbEntity:AcDb2dPolyline     None           DD  None
# 19  AcDbEntity:AcDb2dPolyline     None           E2  None
#
#                                              geometry
# 0   LINESTRING Z (337748.412 7381317.345 0.000, 33...
# 1   LINESTRING Z (338149.995 7381365.434 0.000, 33...
# 2   LINESTRING Z (338293.253 7381168.527 0.000, 33...
# 3   LINESTRING Z (337582.564 7381626.775 0.000, 33...
# 4   LINESTRING Z (337482.201 7381672.835 0.000, 33...
# 5   LINESTRING Z (337068.264 7381630.249 0.000, 33...
# 6   LINESTRING Z (337296.571 7381524.374 0.000, 33...
# 7   LINESTRING Z (337202.100 7381568.407 0.000, 33...
# 8   LINESTRING Z (337759.835 7381005.513 0.000, 33...
# 9   LINESTRING Z (337997.528 7382043.488 0.000, 33...
# 10  LINESTRING Z (338578.967 7381165.433 0.000, 33...
# 11  LINESTRING Z (337944.453 7381228.055 0.000, 33...
# 12  LINESTRING Z (337708.178 7381569.023 0.000, 33...
# 13  LINESTRING Z (337644.929 7381598.154 0.000, 33...
# 14  LINESTRING Z (337471.704 7381512.303 0.000, 33...
# 15  LINESTRING Z (337357.562 7381580.324 0.000, 33...
# 16  LINESTRING Z (338045.479 7381302.582 0.000, 33...
# 17  LINESTRING Z (338000.007 7381202.597 0.000, 33...
# 18  LINESTRING Z (337811.798 7381288.516 0.000, 33...
# 19  LINESTRING Z (337348.487 7381111.437 0.000, 33...

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
# gdf_dxf.Layer.to_list()

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('!', '1')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('PAL[0-9]{1,4}')

# %%
gdf_dxf.DJI
# Out:
# 0            [PAL56]
# 1            [PAL36]
# 2            [PAL48]
# 3            [PAL30]
# 4            [PAL73]
# 5            [PAL71]
# 6            [PAL72]
# 7            [PAL70]
# 8             [PAL3]
# 9     [PAL31, PAL32]
# 10    [PAL28, PAL29]
# 11           [PAL58]
# 12           [PAL55]
# 13           [PAL54]
# 14           [PAL74]
# 15           [PAL75]
# 16           [PAL61]
# 17           [PAL60]
# 18           [PAL57]
# 19            [PAL4]
# Name: DJI, dtype: object

# %%
# gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer'].to_list()
# Out:
# []

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(PAL[0-9]{1,4})', expand=True)
# Out:
#                                 0         1     2       3     4      5    6  \
# 0                RUA ACLIMAÇÃO -   06_01_20  None   21 -   None  PAL56
# 1            RUA LÍBERO BADARÓ -   06_01_20  None   21 -   None  PAL36
# 2         RUA XAVIER DE TOLEDO -   06_01_20  None   21 -   None  PAL48
# 3                  RUA MARTINS -   06_01_20  None   21 -   None  PAL30
# 4              RUA 17 DE MARÇO -   06_01_20  None   21 -   None  PAL73
# 5                  RUA CAMARGO -   06_01_20  None   21 -   None  PAL71
# 6                  RUA DRÁUSIO -   06_01_20  None   21 -   None  PAL72
# 7          RUA JOÃO BIANCALANA -   06_01_20  None   21 -   None  PAL70
# 8                  RUA SANTANA -   06_01_20  None  210 -   None   PAL3
# 9                 RUA MIRAGAIA -   06_01_20  None   21 -   None  PAL31   -
# 10           RUA CÁSPER LÍBERO -   06_01_20  None   21 -   None  PAL28   -
# 11           RUA SENJI SUGUINO -   06_01_20  None   21 -   None  PAL58
# 12               RUA JABAQUARA -   06_01_20  None   21 -   None  PAL55
# 13                    RUA LAPA -   06_01_20  None   21 -   None  PAL54
# 14            RUA ROSA CAPASSI -   06_01_20  None   21 -   None  PAL74
# 15  RUA JOAQUIM JOSÉ DE FRANÇA -   06_01_20  None   21 -   None  PAL75
# 16                   RUA VERÃO -   06_01_20  None  21 -    None  PAL61
# 17            RUA JOÃO DEPOLLI -   06_01_20  None   21 -   None  PAL60
# 18                    RUA BRAZ -   06_01_20  None   21 -   None  PAL57
# 19                RUA PERDIZES -   06_01_20  None   21 -   None   PAL4
#
#        7      8     9
# 0   None   None  None
# 1   None   None  None
# 2   None   None  None
# 3   None   None  None
# 4   None   None  None
# 5   None   None  None
# 6   None   None  None
# 7   None   None  None
# 8   None   None  None
# 9   None  PAL32
# 10  None  PAL29
# 11  None   None  None
# 12  None   None  None
# 13  None   None  None
# 14  None   None  None
# 15  None   None  None
# 16  None   None  None
# 17  None   None  None
# 18  None   None  None
# 19  None   None  None

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(PAL[0-9]{1,4})', expand=True)[3].unique().tolist()
# Out:
# ['21 - ', '210 - ', '21 -  ']

# %%
etapas = {
     '21 - ':'etapa_00', 
    '210 - ':'etapa_00',
    '':'etapa_00',
    '21 -  ':'etapa_00'
}

# %%
len(etapas)
# Out:
# 4

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(PAL[0-9]{1,4})', expand=True)[3].map(etapas)
# Out:
# 0     etapa_00
# 1     etapa_00
# 2     etapa_00
# 3     etapa_00
# 4     etapa_00
# 5     etapa_00
# 6     etapa_00
# 7     etapa_00
# 8     etapa_00
# 9     etapa_00
# 10    etapa_00
# 11    etapa_00
# 12    etapa_00
# 13    etapa_00
# 14    etapa_00
# 15    etapa_00
# 16    etapa_00
# 17    etapa_00
# 18    etapa_00
# 19    etapa_00
# Name: 3, dtype: object

# %%
gdf_dxf.loc[:, 'etapa'] = gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(PAL[0-9]{1,4})', expand=True)[3].map(etapas)

# %%
gdf_dxf.loc[:, 'etapa']
# Out:
# 0     etapa_00
# 1     etapa_00
# 2     etapa_00
# 3     etapa_00
# 4     etapa_00
# 5     etapa_00
# 6     etapa_00
# 7     etapa_00
# 8     etapa_00
# 9     etapa_00
# 10    etapa_00
# 11    etapa_00
# 12    etapa_00
# 13    etapa_00
# 14    etapa_00
# 15    etapa_00
# 16    etapa_00
# 17    etapa_00
# 18    etapa_00
# 19    etapa_00
# Name: etapa, dtype: object

# %%
gdf_dxf
# Out:
#                                               Layer PaperSpace  \
# 0                RUA ACLIMAÇÃO - 06_01_2021 - PAL56       None
# 1            RUA LÍBERO BADARÓ - 06_01_2021 - PAL36       None
# 2         RUA XAVIER DE TOLEDO - 06_01_2021 - PAL48       None
# 3                  RUA MARTINS - 06_01_2021 - PAL30       None
# 4              RUA 17 DE MARÇO - 06_01_2021 - PAL73       None
# 5                  RUA CAMARGO - 06_01_2021 - PAL71       None
# 6                  RUA DRÁUSIO - 06_01_2021 - PAL72       None
# 7          RUA JOÃO BIANCALANA - 06_01_2021 - PAL70       None
# 8                  RUA SANTANA - 06_01_20210 - PAL3       None
# 9         RUA MIRAGAIA - 06_01_2021 - PAL31 - PAL32       None
# 10   RUA CÁSPER LÍBERO - 06_01_2021 - PAL28 - PAL29       None
# 11           RUA SENJI SUGUINO - 06_01_2021 - PAL58       None
# 12               RUA JABAQUARA - 06_01_2021 - PAL55       None
# 13                    RUA LAPA - 06_01_2021 - PAL54       None
# 14            RUA ROSA CAPASSI - 06_01_2021 - PAL74       None
# 15  RUA JOAQUIM JOSÉ DE FRANÇA - 06_01_2021 - PAL75       None
# 16                  RUA VERÃO - 06_01_2021 -  PAL61       None
# 17            RUA JOÃO DEPOLLI - 06_01_2021 - PAL60       None
# 18                    RUA BRAZ - 06_01_2021 - PAL57       None
# 19                 RUA PERDIZES - 06_01_2021 - PAL4       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None           6F  None
# 1   AcDbEntity:AcDb2dPolyline     None           74  None
# 2   AcDbEntity:AcDb2dPolyline     None           79  None
# 3   AcDbEntity:AcDb2dPolyline     None           7E  None
# 4   AcDbEntity:AcDb2dPolyline     None           84  None
# 5   AcDbEntity:AcDb2dPolyline     None           8B  None
# 6   AcDbEntity:AcDb2dPolyline     None           92  None
# 7   AcDbEntity:AcDb2dPolyline     None           99  None
# 8   AcDbEntity:AcDb2dPolyline     None           9E  None
# 9   AcDbEntity:AcDb2dPolyline     None           A4  None
# 10  AcDbEntity:AcDb2dPolyline     None           B0  None
# 11  AcDbEntity:AcDb2dPolyline     None           BA  None
# 12  AcDbEntity:AcDb2dPolyline     None           BF  None
# 13  AcDbEntity:AcDb2dPolyline     None           C4  None
# 14  AcDbEntity:AcDb2dPolyline     None           C9  None
# 15  AcDbEntity:AcDb2dPolyline     None           CE  None
# 16  AcDbEntity:AcDb2dPolyline     None           D3  None
# 17  AcDbEntity:AcDb2dPolyline     None           D8  None
# 18  AcDbEntity:AcDb2dPolyline     None           DD  None
# 19  AcDbEntity:AcDb2dPolyline     None           E2  None
#
#                                              geometry  \
# 0   LINESTRING Z (337748.412 7381317.345 0.000, 33...
# 1   LINESTRING Z (338149.995 7381365.434 0.000, 33...
# 2   LINESTRING Z (338293.253 7381168.527 0.000, 33...
# 3   LINESTRING Z (337582.564 7381626.775 0.000, 33...
# 4   LINESTRING Z (337482.201 7381672.835 0.000, 33...
# 5   LINESTRING Z (337068.264 7381630.249 0.000, 33...
# 6   LINESTRING Z (337296.571 7381524.374 0.000, 33...
# 7   LINESTRING Z (337202.100 7381568.407 0.000, 33...
# 8   LINESTRING Z (337759.835 7381005.513 0.000, 33...
# 9   LINESTRING Z (337997.528 7382043.488 0.000, 33...
# 10  LINESTRING Z (338578.967 7381165.433 0.000, 33...
# 11  LINESTRING Z (337944.453 7381228.055 0.000, 33...
# 12  LINESTRING Z (337708.178 7381569.023 0.000, 33...
# 13  LINESTRING Z (337644.929 7381598.154 0.000, 33...
# 14  LINESTRING Z (337471.704 7381512.303 0.000, 33...
# 15  LINESTRING Z (337357.562 7381580.324 0.000, 33...
# 16  LINESTRING Z (338045.479 7381302.582 0.000, 33...
# 17  LINESTRING Z (338000.007 7381202.597 0.000, 33...
# 18  LINESTRING Z (337811.798 7381288.516 0.000, 33...
# 19  LINESTRING Z (337348.487 7381111.437 0.000, 33...
#
#                                               lista             DJI  data_voo  \
# 0                [RUA ACLIMAÇÃO, 06_01_2021, PAL56]         [PAL56]  06_01_20
# 1            [RUA LÍBERO BADARÓ, 06_01_2021, PAL36]         [PAL36]  06_01_20
# 2         [RUA XAVIER DE TOLEDO, 06_01_2021, PAL48]         [PAL48]  06_01_20
# 3                  [RUA MARTINS, 06_01_2021, PAL30]         [PAL30]  06_01_20
# 4              [RUA 17 DE MARÇO, 06_01_2021, PAL73]         [PAL73]  06_01_20
# 5                  [RUA CAMARGO, 06_01_2021, PAL71]         [PAL71]  06_01_20
# 6                  [RUA DRÁUSIO, 06_01_2021, PAL72]         [PAL72]  06_01_20
# 7          [RUA JOÃO BIANCALANA, 06_01_2021, PAL70]         [PAL70]  06_01_20
# 8                  [RUA SANTANA, 06_01_20210, PAL3]          [PAL3]  06_01_20
# 9          [RUA MIRAGAIA, 06_01_2021, PAL31, PAL32]  [PAL31, PAL32]  06_01_20
# 10    [RUA CÁSPER LÍBERO, 06_01_2021, PAL28, PAL29]  [PAL28, PAL29]  06_01_20
# 11           [RUA SENJI SUGUINO, 06_01_2021, PAL58]         [PAL58]  06_01_20
# 12               [RUA JABAQUARA, 06_01_2021, PAL55]         [PAL55]  06_01_20
# 13                    [RUA LAPA, 06_01_2021, PAL54]         [PAL54]  06_01_20
# 14            [RUA ROSA CAPASSI, 06_01_2021, PAL74]         [PAL74]  06_01_20
# 15  [RUA JOAQUIM JOSÉ DE FRANÇA, 06_01_2021, PAL75]         [PAL75]  06_01_20
# 16                  [RUA VERÃO, 06_01_2021,  PAL61]         [PAL61]  06_01_20
# 17            [RUA JOÃO DEPOLLI, 06_01_2021, PAL60]         [PAL60]  06_01_20
# 18                    [RUA BRAZ, 06_01_2021, PAL57]         [PAL57]  06_01_20
# 19                 [RUA PERDIZES, 06_01_2021, PAL4]          [PAL4]  06_01_20
#
#                     logradouro     etapa
# 0                RUA ACLIMAÇÃO  etapa_00
# 1            RUA LÍBERO BADARÓ  etapa_00
# 2         RUA XAVIER DE TOLEDO  etapa_00
# 3                  RUA MARTINS  etapa_00
# 4              RUA 17 DE MARÇO  etapa_00
# 5                  RUA CAMARGO  etapa_00
# 6                  RUA DRÁUSIO  etapa_00
# 7          RUA JOÃO BIANCALANA  etapa_00
# 8                  RUA SANTANA  etapa_00
# 9                 RUA MIRAGAIA  etapa_00
# 10           RUA CÁSPER LÍBERO  etapa_00
# 11           RUA SENJI SUGUINO  etapa_00
# 12               RUA JABAQUARA  etapa_00
# 13                    RUA LAPA  etapa_00
# 14            RUA ROSA CAPASSI  etapa_00
# 15  RUA JOAQUIM JOSÉ DE FRANÇA  etapa_00
# 16                   RUA VERÃO  etapa_00
# 17            RUA JOÃO DEPOLLI  etapa_00
# 18                    RUA BRAZ  etapa_00
# 19                RUA PERDIZES  etapa_00

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#       Video_0    Video_1
# 0   PAL56.MOV       None
# 1   PAL36.MOV       None
# 2   PAL48.MOV       None
# 3   PAL30.MOV       None
# 4   PAL73.MOV       None
# 5   PAL71.MOV       None
# 6   PAL72.MOV       None
# 7   PAL70.MOV       None
# 8    PAL3.MOV       None
# 9   PAL31.MOV  PAL32.MOV
# 10  PAL28.MOV  PAL29.MOV
# 11  PAL58.MOV       None
# 12  PAL55.MOV       None
# 13  PAL54.MOV       None
# 14  PAL74.MOV       None
# 15  PAL75.MOV       None
# 16  PAL61.MOV       None
# 17  PAL60.MOV       None
# 18  PAL57.MOV       None
# 19   PAL4.MOV       None

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'data_voo', 'logradouro', 'etapa',
#        'Video_0', 'Video_1'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + bairro.lower().replace('-', '_') + '/' + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                               Layer  \
# 0              RUA 17 DE MARÇO - 06_01_2021 - PAL73
# 1                RUA ACLIMAÇÃO - 06_01_2021 - PAL56
# 2                     RUA BRAZ - 06_01_2021 - PAL57
# 3                  RUA CAMARGO - 06_01_2021 - PAL71
# 4    RUA CÁSPER LÍBERO - 06_01_2021 - PAL28 - PAL29
# 5                  RUA DRÁUSIO - 06_01_2021 - PAL72
# 6                RUA JABAQUARA - 06_01_2021 - PAL55
# 7   RUA JOAQUIM JOSÉ DE FRANÇA - 06_01_2021 - PAL75
# 8          RUA JOÃO BIANCALANA - 06_01_2021 - PAL70
# 9             RUA JOÃO DEPOLLI - 06_01_2021 - PAL60
# 10                    RUA LAPA - 06_01_2021 - PAL54
# 11           RUA LÍBERO BADARÓ - 06_01_2021 - PAL36
# 12                 RUA MARTINS - 06_01_2021 - PAL30
# 13        RUA MIRAGAIA - 06_01_2021 - PAL31 - PAL32
# 14                 RUA PERDIZES - 06_01_2021 - PAL4
# 15            RUA ROSA CAPASSI - 06_01_2021 - PAL74
# 16                 RUA SANTANA - 06_01_20210 - PAL3
# 17           RUA SENJI SUGUINO - 06_01_2021 - PAL58
# 18                  RUA VERÃO - 06_01_2021 -  PAL61
# 19        RUA XAVIER DE TOLEDO - 06_01_2021 - PAL48
#
#                                              geometry PaperSpace  \
# 0   LINESTRING Z (337482.201 7381672.835 0.000, 33...       None
# 1   LINESTRING Z (337748.412 7381317.345 0.000, 33...       None
# 2   LINESTRING Z (337811.798 7381288.516 0.000, 33...       None
# 3   LINESTRING Z (337068.264 7381630.249 0.000, 33...       None
# 4   LINESTRING Z (338578.967 7381165.433 0.000, 33...       None
# 5   LINESTRING Z (337296.571 7381524.374 0.000, 33...       None
# 6   LINESTRING Z (337708.178 7381569.023 0.000, 33...       None
# 7   LINESTRING Z (337357.562 7381580.324 0.000, 33...       None
# 8   LINESTRING Z (337202.100 7381568.407 0.000, 33...       None
# 9   LINESTRING Z (338000.007 7381202.597 0.000, 33...       None
# 10  LINESTRING Z (337644.929 7381598.154 0.000, 33...       None
# 11  LINESTRING Z (338149.995 7381365.434 0.000, 33...       None
# 12  LINESTRING Z (337582.564 7381626.775 0.000, 33...       None
# 13  LINESTRING Z (337997.528 7382043.488 0.000, 33...       None
# 14  LINESTRING Z (337348.487 7381111.437 0.000, 33...       None
# 15  LINESTRING Z (337471.704 7381512.303 0.000, 33...       None
# 16  LINESTRING Z (337759.835 7381005.513 0.000, 33...       None
# 17  LINESTRING Z (337944.453 7381228.055 0.000, 33...       None
# 18  LINESTRING Z (338045.479 7381302.582 0.000, 33...       None
# 19  LINESTRING Z (338293.253 7381168.527 0.000, 33...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None           84  None
# 1   AcDbEntity:AcDb2dPolyline     None           6F  None
# 2   AcDbEntity:AcDb2dPolyline     None           DD  None
# 3   AcDbEntity:AcDb2dPolyline     None           8B  None
# 4   AcDbEntity:AcDb2dPolyline     None           B0  None
# 5   AcDbEntity:AcDb2dPolyline     None           92  None
# 6   AcDbEntity:AcDb2dPolyline     None           BF  None
# 7   AcDbEntity:AcDb2dPolyline     None           CE  None
# 8   AcDbEntity:AcDb2dPolyline     None           99  None
# 9   AcDbEntity:AcDb2dPolyline     None           D8  None
# 10  AcDbEntity:AcDb2dPolyline     None           C4  None
# 11  AcDbEntity:AcDb2dPolyline     None           74  None
# 12  AcDbEntity:AcDb2dPolyline     None           7E  None
# 13  AcDbEntity:AcDb2dPolyline     None           A4  None
# 14  AcDbEntity:AcDb2dPolyline     None           E2  None
# 15  AcDbEntity:AcDb2dPolyline     None           C9  None
# 16  AcDbEntity:AcDb2dPolyline     None           9E  None
# 17  AcDbEntity:AcDb2dPolyline     None           BA  None
# 18  AcDbEntity:AcDb2dPolyline     None           D3  None
# 19  AcDbEntity:AcDb2dPolyline     None           79  None
#
#                                               lista             DJI  \
# 0              [RUA 17 DE MARÇO, 06_01_2021, PAL73]         [PAL73]
# 1                [RUA ACLIMAÇÃO, 06_01_2021, PAL56]         [PAL56]
# 2                     [RUA BRAZ, 06_01_2021, PAL57]         [PAL57]
# 3                  [RUA CAMARGO, 06_01_2021, PAL71]         [PAL71]
# 4     [RUA CÁSPER LÍBERO, 06_01_2021, PAL28, PAL29]  [PAL28, PAL29]
# 5                  [RUA DRÁUSIO, 06_01_2021, PAL72]         [PAL72]
# 6                [RUA JABAQUARA, 06_01_2021, PAL55]         [PAL55]
# 7   [RUA JOAQUIM JOSÉ DE FRANÇA, 06_01_2021, PAL75]         [PAL75]
# 8          [RUA JOÃO BIANCALANA, 06_01_2021, PAL70]         [PAL70]
# 9             [RUA JOÃO DEPOLLI, 06_01_2021, PAL60]         [PAL60]
# 10                    [RUA LAPA, 06_01_2021, PAL54]         [PAL54]
# 11           [RUA LÍBERO BADARÓ, 06_01_2021, PAL36]         [PAL36]
# 12                 [RUA MARTINS, 06_01_2021, PAL30]         [PAL30]
# 13         [RUA MIRAGAIA, 06_01_2021, PAL31, PAL32]  [PAL31, PAL32]
# 14                 [RUA PERDIZES, 06_01_2021, PAL4]          [PAL4]
# 15            [RUA ROSA CAPASSI, 06_01_2021, PAL74]         [PAL74]
# 16                 [RUA SANTANA, 06_01_20210, PAL3]          [PAL3]
# 17           [RUA SENJI SUGUINO, 06_01_2021, PAL58]         [PAL58]
# 18                  [RUA VERÃO, 06_01_2021,  PAL61]         [PAL61]
# 19        [RUA XAVIER DE TOLEDO, 06_01_2021, PAL48]         [PAL48]
#
#      data_voo                  logradouro      etapa    Video_0    Video_1  \
# 0   06_01_20/             RUA 17 DE MARÇO  etapa_00/  PAL73.MOV       None
# 1   06_01_20/               RUA ACLIMAÇÃO  etapa_00/  PAL56.MOV       None
# 2   06_01_20/                    RUA BRAZ  etapa_00/  PAL57.MOV       None
# 3   06_01_20/                 RUA CAMARGO  etapa_00/  PAL71.MOV       None
# 4   06_01_20/           RUA CÁSPER LÍBERO  etapa_00/  PAL28.MOV  PAL29.MOV
# 5   06_01_20/                 RUA DRÁUSIO  etapa_00/  PAL72.MOV       None
# 6   06_01_20/               RUA JABAQUARA  etapa_00/  PAL55.MOV       None
# 7   06_01_20/  RUA JOAQUIM JOSÉ DE FRANÇA  etapa_00/  PAL75.MOV       None
# 8   06_01_20/         RUA JOÃO BIANCALANA  etapa_00/  PAL70.MOV       None
# 9   06_01_20/            RUA JOÃO DEPOLLI  etapa_00/  PAL60.MOV       None
# 10  06_01_20/                    RUA LAPA  etapa_00/  PAL54.MOV       None
# 11  06_01_20/           RUA LÍBERO BADARÓ  etapa_00/  PAL36.MOV       None
# 12  06_01_20/                 RUA MARTINS  etapa_00/  PAL30.MOV       None
# 13  06_01_20/                RUA MIRAGAIA  etapa_00/  PAL31.MOV  PAL32.MOV
# 14  06_01_20/                RUA PERDIZES  etapa_00/   PAL4.MOV       None
# 15  06_01_20/            RUA ROSA CAPASSI  etapa_00/  PAL74.MOV       None
# 16  06_01_20/                 RUA SANTANA  etapa_00/   PAL3.MOV       None
# 17  06_01_20/           RUA SENJI SUGUINO  etapa_00/  PAL58.MOV       None
# 18  06_01_20/                   RUA VERÃO  etapa_00/  PAL61.MOV       None
# 19  06_01_20/        RUA XAVIER DE TOLEDO  etapa_00/  PAL48.MOV       None
#
#                            Video_0_path                         Video_1_path
# 0   videos/pauliceia/etapa_00/PAL73.MOV                                 None
# 1   videos/pauliceia/etapa_00/PAL56.MOV                                 None
# 2   videos/pauliceia/etapa_00/PAL57.MOV                                 None
# 3   videos/pauliceia/etapa_00/PAL71.MOV                                 None
# 4   videos/pauliceia/etapa_00/PAL28.MOV  videos/pauliceia/etapa_00/PAL29.MOV
# 5   videos/pauliceia/etapa_00/PAL72.MOV                                 None
# 6   videos/pauliceia/etapa_00/PAL55.MOV                                 None
# 7   videos/pauliceia/etapa_00/PAL75.MOV                                 None
# 8   videos/pauliceia/etapa_00/PAL70.MOV                                 None
# 9   videos/pauliceia/etapa_00/PAL60.MOV                                 None
# 10  videos/pauliceia/etapa_00/PAL54.MOV                                 None
# 11  videos/pauliceia/etapa_00/PAL36.MOV                                 None
# 12  videos/pauliceia/etapa_00/PAL30.MOV                                 None
# 13  videos/pauliceia/etapa_00/PAL31.MOV  videos/pauliceia/etapa_00/PAL32.MOV
# 14   videos/pauliceia/etapa_00/PAL4.MOV                                 None
# 15  videos/pauliceia/etapa_00/PAL74.MOV                                 None
# 16   videos/pauliceia/etapa_00/PAL3.MOV                                 None
# 17  videos/pauliceia/etapa_00/PAL58.MOV                                 None
# 18  videos/pauliceia/etapa_00/PAL61.MOV                                 None
# 19  videos/pauliceia/etapa_00/PAL48.MOV                                 None

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1)
# Out:
#                                              geometry   data_voo  \
# 0   LINESTRING Z (337482.201 7381672.835 0.000, 33...  06_01_20/
# 1   LINESTRING Z (337748.412 7381317.345 0.000, 33...  06_01_20/
# 2   LINESTRING Z (337811.798 7381288.516 0.000, 33...  06_01_20/
# 3   LINESTRING Z (337068.264 7381630.249 0.000, 33...  06_01_20/
# 4   LINESTRING Z (338578.967 7381165.433 0.000, 33...  06_01_20/
# 5   LINESTRING Z (337296.571 7381524.374 0.000, 33...  06_01_20/
# 6   LINESTRING Z (337708.178 7381569.023 0.000, 33...  06_01_20/
# 7   LINESTRING Z (337357.562 7381580.324 0.000, 33...  06_01_20/
# 8   LINESTRING Z (337202.100 7381568.407 0.000, 33...  06_01_20/
# 9   LINESTRING Z (338000.007 7381202.597 0.000, 33...  06_01_20/
# 10  LINESTRING Z (337644.929 7381598.154 0.000, 33...  06_01_20/
# 11  LINESTRING Z (338149.995 7381365.434 0.000, 33...  06_01_20/
# 12  LINESTRING Z (337582.564 7381626.775 0.000, 33...  06_01_20/
# 13  LINESTRING Z (337997.528 7382043.488 0.000, 33...  06_01_20/
# 14  LINESTRING Z (337348.487 7381111.437 0.000, 33...  06_01_20/
# 15  LINESTRING Z (337471.704 7381512.303 0.000, 33...  06_01_20/
# 16  LINESTRING Z (337759.835 7381005.513 0.000, 33...  06_01_20/
# 17  LINESTRING Z (337944.453 7381228.055 0.000, 33...  06_01_20/
# 18  LINESTRING Z (338045.479 7381302.582 0.000, 33...  06_01_20/
# 19  LINESTRING Z (338293.253 7381168.527 0.000, 33...  06_01_20/
#
#                     logradouro      etapa    Video_0    Video_1  \
# 0              RUA 17 DE MARÇO  etapa_00/  PAL73.MOV       None
# 1                RUA ACLIMAÇÃO  etapa_00/  PAL56.MOV       None
# 2                     RUA BRAZ  etapa_00/  PAL57.MOV       None
# 3                  RUA CAMARGO  etapa_00/  PAL71.MOV       None
# 4            RUA CÁSPER LÍBERO  etapa_00/  PAL28.MOV  PAL29.MOV
# 5                  RUA DRÁUSIO  etapa_00/  PAL72.MOV       None
# 6                RUA JABAQUARA  etapa_00/  PAL55.MOV       None
# 7   RUA JOAQUIM JOSÉ DE FRANÇA  etapa_00/  PAL75.MOV       None
# 8          RUA JOÃO BIANCALANA  etapa_00/  PAL70.MOV       None
# 9             RUA JOÃO DEPOLLI  etapa_00/  PAL60.MOV       None
# 10                    RUA LAPA  etapa_00/  PAL54.MOV       None
# 11           RUA LÍBERO BADARÓ  etapa_00/  PAL36.MOV       None
# 12                 RUA MARTINS  etapa_00/  PAL30.MOV       None
# 13                RUA MIRAGAIA  etapa_00/  PAL31.MOV  PAL32.MOV
# 14                RUA PERDIZES  etapa_00/   PAL4.MOV       None
# 15            RUA ROSA CAPASSI  etapa_00/  PAL74.MOV       None
# 16                 RUA SANTANA  etapa_00/   PAL3.MOV       None
# 17           RUA SENJI SUGUINO  etapa_00/  PAL58.MOV       None
# 18                   RUA VERÃO  etapa_00/  PAL61.MOV       None
# 19        RUA XAVIER DE TOLEDO  etapa_00/  PAL48.MOV       None
#
#                            Video_0_path                         Video_1_path
# 0   videos/pauliceia/etapa_00/PAL73.MOV                                 None
# 1   videos/pauliceia/etapa_00/PAL56.MOV                                 None
# 2   videos/pauliceia/etapa_00/PAL57.MOV                                 None
# 3   videos/pauliceia/etapa_00/PAL71.MOV                                 None
# 4   videos/pauliceia/etapa_00/PAL28.MOV  videos/pauliceia/etapa_00/PAL29.MOV
# 5   videos/pauliceia/etapa_00/PAL72.MOV                                 None
# 6   videos/pauliceia/etapa_00/PAL55.MOV                                 None
# 7   videos/pauliceia/etapa_00/PAL75.MOV                                 None
# 8   videos/pauliceia/etapa_00/PAL70.MOV                                 None
# 9   videos/pauliceia/etapa_00/PAL60.MOV                                 None
# 10  videos/pauliceia/etapa_00/PAL54.MOV                                 None
# 11  videos/pauliceia/etapa_00/PAL36.MOV                                 None
# 12  videos/pauliceia/etapa_00/PAL30.MOV                                 None
# 13  videos/pauliceia/etapa_00/PAL31.MOV  videos/pauliceia/etapa_00/PAL32.MOV
# 14   videos/pauliceia/etapa_00/PAL4.MOV                                 None
# 15  videos/pauliceia/etapa_00/PAL74.MOV                                 None
# 16   videos/pauliceia/etapa_00/PAL3.MOV                                 None
# 17  videos/pauliceia/etapa_00/PAL58.MOV                                 None
# 18  videos/pauliceia/etapa_00/PAL61.MOV                                 None
# 19  videos/pauliceia/etapa_00/PAL48.MOV                                 None

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'etapa', 'data_voo', 'Video_0', 'Video_1'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-Conflito-de-programas.gpkg', driver='GPKG')

# %%
gdf_dxf.to_crs('EPSG:4326').drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'etapa', 'data_voo', 'Video_0', 'Video_1'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-Conflito-de-programas.geojson', driver='GeoJSON')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# data_voo          object
# logradouro        object
# etapa             object
# Video_0           object
# Video_1           object
# Video_0_path      object
# Video_1_path      object
# dtype: object

# %%
gdf_dxf.Video_0.isna().value_counts()
# Out:
# False    20
# Name: Video_0, dtype: int64
