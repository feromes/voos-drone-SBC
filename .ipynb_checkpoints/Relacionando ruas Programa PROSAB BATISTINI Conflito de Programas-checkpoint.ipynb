# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/BATISTINI - EIXOS VIA_AREA COM CONFLITOS PROSAB.dxf', encoding='ANSI_1252')

# %%
bairro = 'BATISTINI'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0   RUA LUIGI BATISTINI - 30_12_20 - etapa 01 - DJ...       None
# 1     RUA DA ÃRVORE - 30_12_20 - etapa 01 - DJI_0006       None
# 2   PASSAGEM DE ACÃCIA - 30_12_20 - etapa 01 - DJ...       None
# 3   PASSAGEM SÃO RAFAEL - 30_12_20 - etapa 01 - D...       None
# 4   RUA PEDRO ZAMPIERRI - 30_12_20 - etapa 01 - DJ...       None
# 5            MCT RUA PROF. BENEDITO CARLOS DOS SANTOS       None
# 6   RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...       None
# 7   RUA IPÃLITO MINUCCI - 30_12_20 - etapa 01 - D...       None
# 8   ESTRADA ARTHUR MARSON - 30_12_20 - etapa 01 - ...       None
# 9     RUA DA ÃRVORE - 30_12_20 - etapa 01 - DJI_0006       None
# 10  RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...       None
# 11  RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...       None
# 12    RUA DAS FLORES - 30_12_20 - etapa 01 - DJI_0001       None
# 13  RUA DA CONQUISTA - 30_12_20 - etapa 01 - DJI_0...       None
# 14  RUA SANTE BATTISTINI - 30_12_20 - etapa 01 - D...       None
# 15  RUA AGUAS DE PRATA - 30_12_20 - etapa 01 - DJI...       None
# 16  RUA ÃGUAS DE SANTA CLARA - 30_12_20 - etapa 0...       None
# 17  RUA ÃGUAS DE SANTA BÃRBARA - 30_12_20 - etap...       None
# 18  RUA ANTONIO BATTISTINI - 30_12_20 - etapa 01 -...       None
# 19  ESTRADA LUIZ MARSON - 30_12_20 - etapa 01 - DJ...       None
# 20  ESTRADA LUIZ MARSON - 30_12_20 - etapa 01 - DJ...       None
# 21  RUA LUIGI BATISTINI - 30_12_20 - etapa 01 - DJ...       None
# 22  RUA ASSUMPTA SABATINI ROSSI - 30_12_20 - etapa...       None
# 23  RUA JOSÃ JOÃO SANTANA - 30_12_20 - etapa 01 ...       None
# 24  RUA LUIZA DE O. SANTANA - 30_12_20 - etapa 01 ...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None          3D5  None
# 1   AcDbEntity:AcDb2dPolyline     None          3DC  None
# 2   AcDbEntity:AcDb2dPolyline     None          3F1  None
# 3   AcDbEntity:AcDb2dPolyline     None          3F7  None
# 4   AcDbEntity:AcDb2dPolyline     None          3FD  None
# 5   AcDbEntity:AcDb2dPolyline     None          404  None
# 6   AcDbEntity:AcDb2dPolyline     None          40D  None
# 7   AcDbEntity:AcDb2dPolyline     None          411  None
# 8   AcDbEntity:AcDb2dPolyline     None          417  None
# 9   AcDbEntity:AcDb2dPolyline     None          41E  None
# 10  AcDbEntity:AcDb2dPolyline     None          422  None
# 11  AcDbEntity:AcDb2dPolyline     None          42E  None
# 12  AcDbEntity:AcDb2dPolyline     None          437  None
# 13  AcDbEntity:AcDb2dPolyline     None          442  None
# 14  AcDbEntity:AcDb2dPolyline     None          453  None
# 15  AcDbEntity:AcDb2dPolyline     None          460  None
# 16  AcDbEntity:AcDb2dPolyline     None          46E  None
# 17  AcDbEntity:AcDb2dPolyline     None          47A  None
# 18  AcDbEntity:AcDb2dPolyline     None          48C  None
# 19  AcDbEntity:AcDb2dPolyline     None          49C  None
# 20  AcDbEntity:AcDb2dPolyline     None          4A7  None
# 21  AcDbEntity:AcDb2dPolyline     None          4AE  None
# 22  AcDbEntity:AcDb2dPolyline     None          4C2  None
# 23  AcDbEntity:AcDb2dPolyline     None          4D0  None
# 24  AcDbEntity:AcDb2dPolyline     None          4D4  None
#
#                                              geometry
# 0   LINESTRING Z (338667.780 7372633.849 0.000, 33...
# 1   LINESTRING Z (338920.885 7372130.664 0.000, 33...
# 2   LINESTRING Z (339013.276 7372160.846 0.000, 33...
# 3   LINESTRING Z (338991.536 7372179.271 0.000, 33...
# 4   LINESTRING Z (338939.769 7372153.684 0.000, 33...
# 5   LINESTRING Z (338823.785 7372000.159 0.000, 33...
# 6   LINESTRING Z (338814.368 7371988.788 0.000, 33...
# 7   LINESTRING Z (338872.760 7372065.634 0.000, 33...
# 8   LINESTRING Z (338888.677 7372088.845 0.000, 33...
# 9   LINESTRING Z (338902.509 7372134.539 0.000, 33...
# 10  LINESTRING Z (338848.217 7372029.662 0.000, 33...
# 11  LINESTRING Z (338792.487 7371988.319 0.000, 33...
# 12  LINESTRING Z (339112.349 7371822.283 0.000, 33...
# 13  LINESTRING Z (339082.105 7371792.808 0.000, 33...
# 14  LINESTRING Z (338888.663 7372263.635 0.000, 33...
# 15  LINESTRING Z (338874.449 7372250.753 0.000, 33...
# 16  LINESTRING Z (339016.597 7372199.634 0.000, 33...
# 17  LINESTRING Z (339031.662 7372223.595 0.000, 33...
# 18  LINESTRING Z (339102.406 7372415.296 0.000, 33...
# 19  LINESTRING Z (338750.839 7372670.954 0.000, 33...
# 20  LINESTRING Z (339510.371 7372069.861 0.000, 33...
# 21  LINESTRING Z (338670.420 7372634.327 0.000, 33...
# 22  LINESTRING Z (339037.145 7372695.600 0.000, 33...
# 23  LINESTRING Z (339490.347 7372295.254 0.000, 33...
# 24  LINESTRING Z (339426.563 7372304.360 0.000, 33...

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
# gdf_dxf.Layer.to_list()

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('MCT - ', '')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('DJI_[0-9]{4}')

# %%
# gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer']
# Out:
# 5    MCT RUA PROF. BENEDITO CARLOS DOS SANTOS
# Name: Layer, dtype: object

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)
# Out:
#                                            0         1     2               3  \
# 0                     RUA LUIGI BATISTINI -   30_12_20  None   - etapa 01 -
# 1                           RUA DA ÁRVORE -   30_12_20  None   - etapa 01 -
# 2                      PASSAGEM DE ACÁCIA -   30_12_20  None   - etapa 01 -
# 3                     PASSAGEM SÃO RAFAEL -   30_12_20  None   - etapa 01 -
# 4                     RUA PEDRO ZAMPIERRI -   30_12_20  None   - etapa 01 -
# 5   MCT RUA PROF. BENEDITO CARLOS DOS SANTOS      None  None            None
# 6               RUA ALAMEDA DAS PAINEIRAS -   30_12_20  None   - etapa 01 -
# 7                     RUA IPÓLITO MINUCCI -   30_12_20  None   - etapa 01 -
# 8                   ESTRADA ARTHUR MARSON -   30_12_20  None   - etapa 01 -
# 9                           RUA DA ÁRVORE -   30_12_20  None   - etapa 01 -
# 10              RUA ALAMEDA DAS PAINEIRAS -   30_12_20  None   - etapa 01 -
# 11              RUA ALAMEDA DAS PAINEIRAS -   30_12_20  None   - etapa 01 -
# 12                         RUA DAS FLORES -   30_12_20  None   - etapa 01 -
# 13                       RUA DA CONQUISTA -   30_12_20  None   - etapa 01 -
# 14                   RUA SANTE BATTISTINI -   30_12_20  None   - etapa 01 -
# 15                     RUA AGUAS DE PRATA -   30_12_20  None   - etapa 01 -
# 16               RUA ÁGUAS DE SANTA CLARA -   30_12_20  None   - etapa 01 -
# 17             RUA ÁGUAS DE SANTA BÁRBARA -   30_12_20  None   - etapa 01 -
# 18                 RUA ANTONIO BATTISTINI -   30_12_20  None   - etapa 01 -
# 19                    ESTRADA LUIZ MARSON -   30_12_20  None   - etapa 01 -
# 20                    ESTRADA LUIZ MARSON -   30_12_20  None   - etapa 01 -
# 21                    RUA LUIGI BATISTINI -   30_12_20  None   - etapa 01 -
# 22            RUA ASSUMPTA SABATINI ROSSI -   30_12_20  None   - etapa 01 -
# 23                  RUA JOSÉ JOÃO SANTANA -   30_12_20  None   - etapa 01 -
# 24                RUA LUIZA DE O. SANTANA -   30_12_20  None   - etapa 01 -
#
#        4         5     6     7         8     9
# 0   None  DJI_0027        None      None  None
# 1   None  DJI_0006        None      None  None
# 2   None  DJI_0013        None      None  None
# 3   None  DJI_0014        None      None  None
# 4   None  DJI_0015        None      None  None
# 5   None      None  None  None      None  None
# 6   None  DJI_0004    -   None  DJI_0001
# 7   None  DJI_0017        None      None  None
# 8   None  DJI_0007        None      None  None
# 9   None  DJI_0006        None      None  None
# 10  None  DJI_0004    -   None  DJI_0001
# 11  None  DJI_0004    -   None  DJI_0001
# 12  None  DJI_0001        None      None  None
# 13  None  DJI_0002    -   None  DJI_0003
# 14  None  DJI_0005        None      None  None
# 15  None  DJI_0012        None      None  None
# 16  None  DJI_0011        None      None  None
# 17  None  DJI_0010        None      None  None
# 18  None  DJI_0026        None      None  None
# 19  None  DJI_0025        None      None  None
# 20  None  DJI_0025        None      None  None
# 21  None  DJI_0027        None      None  None
# 22  None  DJI_0024        None      None  None
# 23  None  DJI_0023        None      None  None
# 24  None  DJI_0021        None      None  None

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].unique()
# Out:
# array([' - etapa 01 - ', None], dtype=object)

# %%
etapas = {
    ' - etapa 03 - ':'etapa_03', 
    ' - etapa 01  - ':'etapa_01', 
    ' - etapa 01 - ':'etapa_01',
    ' - etapa 04 - ':'etapa_04', 
    ' - MAVIC - ':'mavic', 
    ' - etapa 02 - ':'etapa_02',
    ' - etapa 03 -  ':'etapa_03', 
    '  - etapa 02 - ':'etapa_02', 
    '  - etapa 04 - ':'etapa_04'
}

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(etapas)
# Out:
# 0     etapa_01
# 1     etapa_01
# 2     etapa_01
# 3     etapa_01
# 4     etapa_01
# 5          NaN
# 6     etapa_01
# 7     etapa_01
# 8     etapa_01
# 9     etapa_01
# 10    etapa_01
# 11    etapa_01
# 12    etapa_01
# 13    etapa_01
# 14    etapa_01
# 15    etapa_01
# 16    etapa_01
# 17    etapa_01
# 18    etapa_01
# 19    etapa_01
# 20    etapa_01
# 21    etapa_01
# 22    etapa_01
# 23    etapa_01
# 24    etapa_01
# Name: 3, dtype: object

# %%
gdf_dxf.loc[:, 'etapa'] = gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(etapas)

# %%
gdf_dxf.loc[:, 'etapa']
# Out:
# 0     etapa_01
# 1     etapa_01
# 2     etapa_01
# 3     etapa_01
# 4     etapa_01
# 5          NaN
# 6     etapa_01
# 7     etapa_01
# 8     etapa_01
# 9     etapa_01
# 10    etapa_01
# 11    etapa_01
# 12    etapa_01
# 13    etapa_01
# 14    etapa_01
# 15    etapa_01
# 16    etapa_01
# 17    etapa_01
# 18    etapa_01
# 19    etapa_01
# 20    etapa_01
# 21    etapa_01
# 22    etapa_01
# 23    etapa_01
# 24    etapa_01
# Name: etapa, dtype: object

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0   RUA LUIGI BATISTINI - 30_12_20 - etapa 01 - DJ...       None
# 1      RUA DA ÁRVORE - 30_12_20 - etapa 01 - DJI_0006       None
# 2   PASSAGEM DE ACÁCIA - 30_12_20 - etapa 01 - DJI...       None
# 3   PASSAGEM SÃO RAFAEL - 30_12_20 - etapa 01 - DJ...       None
# 4   RUA PEDRO ZAMPIERRI - 30_12_20 - etapa 01 - DJ...       None
# 5            MCT RUA PROF. BENEDITO CARLOS DOS SANTOS       None
# 6   RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...       None
# 7   RUA IPÓLITO MINUCCI - 30_12_20 - etapa 01 - DJ...       None
# 8   ESTRADA ARTHUR MARSON - 30_12_20 - etapa 01 - ...       None
# 9      RUA DA ÁRVORE - 30_12_20 - etapa 01 - DJI_0006       None
# 10  RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...       None
# 11  RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...       None
# 12    RUA DAS FLORES - 30_12_20 - etapa 01 - DJI_0001       None
# 13  RUA DA CONQUISTA - 30_12_20 - etapa 01 - DJI_0...       None
# 14  RUA SANTE BATTISTINI - 30_12_20 - etapa 01 - D...       None
# 15  RUA AGUAS DE PRATA - 30_12_20 - etapa 01 - DJI...       None
# 16  RUA ÁGUAS DE SANTA CLARA - 30_12_20 - etapa 01...       None
# 17  RUA ÁGUAS DE SANTA BÁRBARA - 30_12_20 - etapa ...       None
# 18  RUA ANTONIO BATTISTINI - 30_12_20 - etapa 01 -...       None
# 19  ESTRADA LUIZ MARSON - 30_12_20 - etapa 01 - DJ...       None
# 20  ESTRADA LUIZ MARSON - 30_12_20 - etapa 01 - DJ...       None
# 21  RUA LUIGI BATISTINI - 30_12_20 - etapa 01 - DJ...       None
# 22  RUA ASSUMPTA SABATINI ROSSI - 30_12_20 - etapa...       None
# 23  RUA JOSÉ JOÃO SANTANA - 30_12_20 - etapa 01 - ...       None
# 24  RUA LUIZA DE O. SANTANA - 30_12_20 - etapa 01 ...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None          3D5  None
# 1   AcDbEntity:AcDb2dPolyline     None          3DC  None
# 2   AcDbEntity:AcDb2dPolyline     None          3F1  None
# 3   AcDbEntity:AcDb2dPolyline     None          3F7  None
# 4   AcDbEntity:AcDb2dPolyline     None          3FD  None
# 5   AcDbEntity:AcDb2dPolyline     None          404  None
# 6   AcDbEntity:AcDb2dPolyline     None          40D  None
# 7   AcDbEntity:AcDb2dPolyline     None          411  None
# 8   AcDbEntity:AcDb2dPolyline     None          417  None
# 9   AcDbEntity:AcDb2dPolyline     None          41E  None
# 10  AcDbEntity:AcDb2dPolyline     None          422  None
# 11  AcDbEntity:AcDb2dPolyline     None          42E  None
# 12  AcDbEntity:AcDb2dPolyline     None          437  None
# 13  AcDbEntity:AcDb2dPolyline     None          442  None
# 14  AcDbEntity:AcDb2dPolyline     None          453  None
# 15  AcDbEntity:AcDb2dPolyline     None          460  None
# 16  AcDbEntity:AcDb2dPolyline     None          46E  None
# 17  AcDbEntity:AcDb2dPolyline     None          47A  None
# 18  AcDbEntity:AcDb2dPolyline     None          48C  None
# 19  AcDbEntity:AcDb2dPolyline     None          49C  None
# 20  AcDbEntity:AcDb2dPolyline     None          4A7  None
# 21  AcDbEntity:AcDb2dPolyline     None          4AE  None
# 22  AcDbEntity:AcDb2dPolyline     None          4C2  None
# 23  AcDbEntity:AcDb2dPolyline     None          4D0  None
# 24  AcDbEntity:AcDb2dPolyline     None          4D4  None
#
#                                              geometry  \
# 0   LINESTRING Z (338667.780 7372633.849 0.000, 33...
# 1   LINESTRING Z (338920.885 7372130.664 0.000, 33...
# 2   LINESTRING Z (339013.276 7372160.846 0.000, 33...
# 3   LINESTRING Z (338991.536 7372179.271 0.000, 33...
# 4   LINESTRING Z (338939.769 7372153.684 0.000, 33...
# 5   LINESTRING Z (338823.785 7372000.159 0.000, 33...
# 6   LINESTRING Z (338814.368 7371988.788 0.000, 33...
# 7   LINESTRING Z (338872.760 7372065.634 0.000, 33...
# 8   LINESTRING Z (338888.677 7372088.845 0.000, 33...
# 9   LINESTRING Z (338902.509 7372134.539 0.000, 33...
# 10  LINESTRING Z (338848.217 7372029.662 0.000, 33...
# 11  LINESTRING Z (338792.487 7371988.319 0.000, 33...
# 12  LINESTRING Z (339112.349 7371822.283 0.000, 33...
# 13  LINESTRING Z (339082.105 7371792.808 0.000, 33...
# 14  LINESTRING Z (338888.663 7372263.635 0.000, 33...
# 15  LINESTRING Z (338874.449 7372250.753 0.000, 33...
# 16  LINESTRING Z (339016.597 7372199.634 0.000, 33...
# 17  LINESTRING Z (339031.662 7372223.595 0.000, 33...
# 18  LINESTRING Z (339102.406 7372415.296 0.000, 33...
# 19  LINESTRING Z (338750.839 7372670.954 0.000, 33...
# 20  LINESTRING Z (339510.371 7372069.861 0.000, 33...
# 21  LINESTRING Z (338670.420 7372634.327 0.000, 33...
# 22  LINESTRING Z (339037.145 7372695.600 0.000, 33...
# 23  LINESTRING Z (339490.347 7372295.254 0.000, 33...
# 24  LINESTRING Z (339426.563 7372304.360 0.000, 33...
#
#                                                 lista                   DJI  \
# 0   [RUA LUIGI BATISTINI, 30_12_20, etapa 01, DJI_...            [DJI_0027]
# 1       [RUA DA ÁRVORE, 30_12_20, etapa 01, DJI_0006]            [DJI_0006]
# 2   [PASSAGEM DE ACÁCIA, 30_12_20, etapa 01, DJI_0...            [DJI_0013]
# 3   [PASSAGEM SÃO RAFAEL, 30_12_20, etapa 01, DJI_...            [DJI_0014]
# 4   [RUA PEDRO ZAMPIERRI, 30_12_20, etapa 01, DJI_...            [DJI_0015]
# 5          [MCT RUA PROF. BENEDITO CARLOS DOS SANTOS]                    []
# 6   [RUA ALAMEDA DAS PAINEIRAS, 30_12_20, etapa 01...  [DJI_0004, DJI_0001]
# 7   [RUA IPÓLITO MINUCCI, 30_12_20, etapa 01, DJI_...            [DJI_0017]
# 8   [ESTRADA ARTHUR MARSON, 30_12_20, etapa 01, DJ...            [DJI_0007]
# 9       [RUA DA ÁRVORE, 30_12_20, etapa 01, DJI_0006]            [DJI_0006]
# 10  [RUA ALAMEDA DAS PAINEIRAS, 30_12_20, etapa 01...  [DJI_0004, DJI_0001]
# 11  [RUA ALAMEDA DAS PAINEIRAS, 30_12_20, etapa 01...  [DJI_0004, DJI_0001]
# 12     [RUA DAS FLORES, 30_12_20, etapa 01, DJI_0001]            [DJI_0001]
# 13  [RUA DA CONQUISTA, 30_12_20, etapa 01, DJI_000...  [DJI_0002, DJI_0003]
# 14  [RUA SANTE BATTISTINI, 30_12_20, etapa 01, DJI...            [DJI_0005]
# 15  [RUA AGUAS DE PRATA, 30_12_20, etapa 01, DJI_0...            [DJI_0012]
# 16  [RUA ÁGUAS DE SANTA CLARA, 30_12_20, etapa 01,...            [DJI_0011]
# 17  [RUA ÁGUAS DE SANTA BÁRBARA, 30_12_20, etapa 0...            [DJI_0010]
# 18  [RUA ANTONIO BATTISTINI, 30_12_20, etapa 01, D...            [DJI_0026]
# 19  [ESTRADA LUIZ MARSON, 30_12_20, etapa 01, DJI_...            [DJI_0025]
# 20  [ESTRADA LUIZ MARSON, 30_12_20, etapa 01, DJI_...            [DJI_0025]
# 21  [RUA LUIGI BATISTINI, 30_12_20, etapa 01, DJI_...            [DJI_0027]
# 22  [RUA ASSUMPTA SABATINI ROSSI, 30_12_20, etapa ...            [DJI_0024]
# 23  [RUA JOSÉ JOÃO SANTANA, 30_12_20, etapa 01, DJ...            [DJI_0023]
# 24  [RUA LUIZA DE O. SANTANA, 30_12_20, etapa 01, ...            [DJI_0021]
#
#     data_voo                                logradouro     etapa
# 0   30_12_20                       RUA LUIGI BATISTINI  etapa_01
# 1   30_12_20                             RUA DA ÁRVORE  etapa_01
# 2   30_12_20                        PASSAGEM DE ACÁCIA  etapa_01
# 3   30_12_20                       PASSAGEM SÃO RAFAEL  etapa_01
# 4   30_12_20                       RUA PEDRO ZAMPIERRI  etapa_01
# 5        NaN  MCT RUA PROF. BENEDITO CARLOS DOS SANTOS       NaN
# 6   30_12_20                 RUA ALAMEDA DAS PAINEIRAS  etapa_01
# 7   30_12_20                       RUA IPÓLITO MINUCCI  etapa_01
# 8   30_12_20                     ESTRADA ARTHUR MARSON  etapa_01
# 9   30_12_20                             RUA DA ÁRVORE  etapa_01
# 10  30_12_20                 RUA ALAMEDA DAS PAINEIRAS  etapa_01
# 11  30_12_20                 RUA ALAMEDA DAS PAINEIRAS  etapa_01
# 12  30_12_20                            RUA DAS FLORES  etapa_01
# 13  30_12_20                          RUA DA CONQUISTA  etapa_01
# 14  30_12_20                      RUA SANTE BATTISTINI  etapa_01
# 15  30_12_20                        RUA AGUAS DE PRATA  etapa_01
# 16  30_12_20                  RUA ÁGUAS DE SANTA CLARA  etapa_01
# 17  30_12_20                RUA ÁGUAS DE SANTA BÁRBARA  etapa_01
# 18  30_12_20                    RUA ANTONIO BATTISTINI  etapa_01
# 19  30_12_20                       ESTRADA LUIZ MARSON  etapa_01
# 20  30_12_20                       ESTRADA LUIZ MARSON  etapa_01
# 21  30_12_20                       RUA LUIGI BATISTINI  etapa_01
# 22  30_12_20               RUA ASSUMPTA SABATINI ROSSI  etapa_01
# 23  30_12_20                     RUA JOSÉ JOÃO SANTANA  etapa_01
# 24  30_12_20                   RUA LUIZA DE O. SANTANA  etapa_01

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#          Video_0       Video_1
# 0   DJI_0027.MOV          None
# 1   DJI_0006.MOV          None
# 2   DJI_0013.MOV          None
# 3   DJI_0014.MOV          None
# 4   DJI_0015.MOV          None
# 5           None          None
# 6   DJI_0004.MOV  DJI_0001.MOV
# 7   DJI_0017.MOV          None
# 8   DJI_0007.MOV          None
# 9   DJI_0006.MOV          None
# 10  DJI_0004.MOV  DJI_0001.MOV
# 11  DJI_0004.MOV  DJI_0001.MOV
# 12  DJI_0001.MOV          None
# 13  DJI_0002.MOV  DJI_0003.MOV
# 14  DJI_0005.MOV          None
# 15  DJI_0012.MOV          None
# 16  DJI_0011.MOV          None
# 17  DJI_0010.MOV          None
# 18  DJI_0026.MOV          None
# 19  DJI_0025.MOV          None
# 20  DJI_0025.MOV          None
# 21  DJI_0027.MOV          None
# 22  DJI_0024.MOV          None
# 23  DJI_0023.MOV          None
# 24  DJI_0021.MOV          None

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'data_voo', 'logradouro', 'etapa',
#        'Video_0', 'Video_1'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + bairro.lower().replace('-', '_') + '/' + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                                 Layer  \
# 0   ESTRADA ARTHUR MARSON - 30_12_20 - etapa 01 - ...
# 1   ESTRADA LUIZ MARSON - 30_12_20 - etapa 01 - DJ...
# 2            MCT RUA PROF. BENEDITO CARLOS DOS SANTOS
# 3   PASSAGEM DE ACÁCIA - 30_12_20 - etapa 01 - DJI...
# 4   PASSAGEM SÃO RAFAEL - 30_12_20 - etapa 01 - DJ...
# 5   RUA AGUAS DE PRATA - 30_12_20 - etapa 01 - DJI...
# 6   RUA ALAMEDA DAS PAINEIRAS - 30_12_20 - etapa 0...
# 7   RUA ANTONIO BATTISTINI - 30_12_20 - etapa 01 -...
# 8   RUA ASSUMPTA SABATINI ROSSI - 30_12_20 - etapa...
# 9   RUA DA CONQUISTA - 30_12_20 - etapa 01 - DJI_0...
# 10     RUA DA ÁRVORE - 30_12_20 - etapa 01 - DJI_0006
# 11    RUA DAS FLORES - 30_12_20 - etapa 01 - DJI_0001
# 12  RUA IPÓLITO MINUCCI - 30_12_20 - etapa 01 - DJ...
# 13  RUA JOSÉ JOÃO SANTANA - 30_12_20 - etapa 01 - ...
# 14  RUA LUIGI BATISTINI - 30_12_20 - etapa 01 - DJ...
# 15  RUA LUIZA DE O. SANTANA - 30_12_20 - etapa 01 ...
# 16  RUA PEDRO ZAMPIERRI - 30_12_20 - etapa 01 - DJ...
# 17  RUA SANTE BATTISTINI - 30_12_20 - etapa 01 - D...
# 18  RUA ÁGUAS DE SANTA BÁRBARA - 30_12_20 - etapa ...
# 19  RUA ÁGUAS DE SANTA CLARA - 30_12_20 - etapa 01...
#
#                                              geometry PaperSpace  \
# 0   LINESTRING Z (338888.677 7372088.845 0.000, 33...       None
# 1   MULTILINESTRING Z ((338750.839 7372670.954 0.0...       None
# 2   LINESTRING Z (338823.785 7372000.159 0.000, 33...       None
# 3   LINESTRING Z (339013.276 7372160.846 0.000, 33...       None
# 4   LINESTRING Z (338991.536 7372179.271 0.000, 33...       None
# 5   LINESTRING Z (338874.449 7372250.753 0.000, 33...       None
# 6   MULTILINESTRING Z ((338814.368 7371988.788 0.0...       None
# 7   LINESTRING Z (339102.406 7372415.296 0.000, 33...       None
# 8   LINESTRING Z (339037.145 7372695.600 0.000, 33...       None
# 9   LINESTRING Z (339082.105 7371792.808 0.000, 33...       None
# 10  MULTILINESTRING Z ((338920.885 7372130.664 0.0...       None
# 11  LINESTRING Z (339112.349 7371822.283 0.000, 33...       None
# 12  LINESTRING Z (338872.760 7372065.634 0.000, 33...       None
# 13  LINESTRING Z (339490.347 7372295.254 0.000, 33...       None
# 14  MULTILINESTRING Z ((338667.780 7372633.849 0.0...       None
# 15  LINESTRING Z (339426.563 7372304.360 0.000, 33...       None
# 16  LINESTRING Z (338939.769 7372153.684 0.000, 33...       None
# 17  LINESTRING Z (338888.663 7372263.635 0.000, 33...       None
# 18  LINESTRING Z (339031.662 7372223.595 0.000, 33...       None
# 19  LINESTRING Z (339016.597 7372199.634 0.000, 33...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None          417  None
# 1   AcDbEntity:AcDb2dPolyline     None          49C  None
# 2   AcDbEntity:AcDb2dPolyline     None          404  None
# 3   AcDbEntity:AcDb2dPolyline     None          3F1  None
# 4   AcDbEntity:AcDb2dPolyline     None          3F7  None
# 5   AcDbEntity:AcDb2dPolyline     None          460  None
# 6   AcDbEntity:AcDb2dPolyline     None          40D  None
# 7   AcDbEntity:AcDb2dPolyline     None          48C  None
# 8   AcDbEntity:AcDb2dPolyline     None          4C2  None
# 9   AcDbEntity:AcDb2dPolyline     None          442  None
# 10  AcDbEntity:AcDb2dPolyline     None          3DC  None
# 11  AcDbEntity:AcDb2dPolyline     None          437  None
# 12  AcDbEntity:AcDb2dPolyline     None          411  None
# 13  AcDbEntity:AcDb2dPolyline     None          4D0  None
# 14  AcDbEntity:AcDb2dPolyline     None          3D5  None
# 15  AcDbEntity:AcDb2dPolyline     None          4D4  None
# 16  AcDbEntity:AcDb2dPolyline     None          3FD  None
# 17  AcDbEntity:AcDb2dPolyline     None          453  None
# 18  AcDbEntity:AcDb2dPolyline     None          47A  None
# 19  AcDbEntity:AcDb2dPolyline     None          46E  None
#
#                                                 lista                   DJI  \
# 0   [ESTRADA ARTHUR MARSON, 30_12_20, etapa 01, DJ...            [DJI_0007]
# 1   [ESTRADA LUIZ MARSON, 30_12_20, etapa 01, DJI_...            [DJI_0025]
# 2          [MCT RUA PROF. BENEDITO CARLOS DOS SANTOS]                    []
# 3   [PASSAGEM DE ACÁCIA, 30_12_20, etapa 01, DJI_0...            [DJI_0013]
# 4   [PASSAGEM SÃO RAFAEL, 30_12_20, etapa 01, DJI_...            [DJI_0014]
# 5   [RUA AGUAS DE PRATA, 30_12_20, etapa 01, DJI_0...            [DJI_0012]
# 6   [RUA ALAMEDA DAS PAINEIRAS, 30_12_20, etapa 01...  [DJI_0004, DJI_0001]
# 7   [RUA ANTONIO BATTISTINI, 30_12_20, etapa 01, D...            [DJI_0026]
# 8   [RUA ASSUMPTA SABATINI ROSSI, 30_12_20, etapa ...            [DJI_0024]
# 9   [RUA DA CONQUISTA, 30_12_20, etapa 01, DJI_000...  [DJI_0002, DJI_0003]
# 10      [RUA DA ÁRVORE, 30_12_20, etapa 01, DJI_0006]            [DJI_0006]
# 11     [RUA DAS FLORES, 30_12_20, etapa 01, DJI_0001]            [DJI_0001]
# 12  [RUA IPÓLITO MINUCCI, 30_12_20, etapa 01, DJI_...            [DJI_0017]
# 13  [RUA JOSÉ JOÃO SANTANA, 30_12_20, etapa 01, DJ...            [DJI_0023]
# 14  [RUA LUIGI BATISTINI, 30_12_20, etapa 01, DJI_...            [DJI_0027]
# 15  [RUA LUIZA DE O. SANTANA, 30_12_20, etapa 01, ...            [DJI_0021]
# 16  [RUA PEDRO ZAMPIERRI, 30_12_20, etapa 01, DJI_...            [DJI_0015]
# 17  [RUA SANTE BATTISTINI, 30_12_20, etapa 01, DJI...            [DJI_0005]
# 18  [RUA ÁGUAS DE SANTA BÁRBARA, 30_12_20, etapa 0...            [DJI_0010]
# 19  [RUA ÁGUAS DE SANTA CLARA, 30_12_20, etapa 01,...            [DJI_0011]
#
#      data_voo                                logradouro      etapa  \
# 0   30_12_20/                     ESTRADA ARTHUR MARSON  etapa_01/
# 1   30_12_20/                       ESTRADA LUIZ MARSON  etapa_01/
# 2        None  MCT RUA PROF. BENEDITO CARLOS DOS SANTOS
# 3   30_12_20/                        PASSAGEM DE ACÁCIA  etapa_01/
# 4   30_12_20/                       PASSAGEM SÃO RAFAEL  etapa_01/
# 5   30_12_20/                        RUA AGUAS DE PRATA  etapa_01/
# 6   30_12_20/                 RUA ALAMEDA DAS PAINEIRAS  etapa_01/
# 7   30_12_20/                    RUA ANTONIO BATTISTINI  etapa_01/
# 8   30_12_20/               RUA ASSUMPTA SABATINI ROSSI  etapa_01/
# 9   30_12_20/                          RUA DA CONQUISTA  etapa_01/
# 10  30_12_20/                             RUA DA ÁRVORE  etapa_01/
# 11  30_12_20/                            RUA DAS FLORES  etapa_01/
# 12  30_12_20/                       RUA IPÓLITO MINUCCI  etapa_01/
# 13  30_12_20/                     RUA JOSÉ JOÃO SANTANA  etapa_01/
# 14  30_12_20/                       RUA LUIGI BATISTINI  etapa_01/
# 15  30_12_20/                   RUA LUIZA DE O. SANTANA  etapa_01/
# 16  30_12_20/                       RUA PEDRO ZAMPIERRI  etapa_01/
# 17  30_12_20/                      RUA SANTE BATTISTINI  etapa_01/
# 18  30_12_20/                RUA ÁGUAS DE SANTA BÁRBARA  etapa_01/
# 19  30_12_20/                  RUA ÁGUAS DE SANTA CLARA  etapa_01/
#
#          Video_0       Video_1                            Video_0_path  \
# 0   DJI_0007.MOV          None  videos/batistini/etapa_01/DJI_0007.MOV
# 1   DJI_0025.MOV          None  videos/batistini/etapa_01/DJI_0025.MOV
# 2           None          None                                    None
# 3   DJI_0013.MOV          None  videos/batistini/etapa_01/DJI_0013.MOV
# 4   DJI_0014.MOV          None  videos/batistini/etapa_01/DJI_0014.MOV
# 5   DJI_0012.MOV          None  videos/batistini/etapa_01/DJI_0012.MOV
# 6   DJI_0004.MOV  DJI_0001.MOV  videos/batistini/etapa_01/DJI_0004.MOV
# 7   DJI_0026.MOV          None  videos/batistini/etapa_01/DJI_0026.MOV
# 8   DJI_0024.MOV          None  videos/batistini/etapa_01/DJI_0024.MOV
# 9   DJI_0002.MOV  DJI_0003.MOV  videos/batistini/etapa_01/DJI_0002.MOV
# 10  DJI_0006.MOV          None  videos/batistini/etapa_01/DJI_0006.MOV
# 11  DJI_0001.MOV          None  videos/batistini/etapa_01/DJI_0001.MOV
# 12  DJI_0017.MOV          None  videos/batistini/etapa_01/DJI_0017.MOV
# 13  DJI_0023.MOV          None  videos/batistini/etapa_01/DJI_0023.MOV
# 14  DJI_0027.MOV          None  videos/batistini/etapa_01/DJI_0027.MOV
# 15  DJI_0021.MOV          None  videos/batistini/etapa_01/DJI_0021.MOV
# 16  DJI_0015.MOV          None  videos/batistini/etapa_01/DJI_0015.MOV
# 17  DJI_0005.MOV          None  videos/batistini/etapa_01/DJI_0005.MOV
# 18  DJI_0010.MOV          None  videos/batistini/etapa_01/DJI_0010.MOV
# 19  DJI_0011.MOV          None  videos/batistini/etapa_01/DJI_0011.MOV
#
#                               Video_1_path
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6   videos/batistini/etapa_01/DJI_0001.MOV
# 7                                     None
# 8                                     None
# 9   videos/batistini/etapa_01/DJI_0003.MOV
# 10                                    None
# 11                                    None
# 12                                    None
# 13                                    None
# 14                                    None
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1)
# Out:
#                                              geometry   data_voo  \
# 0   LINESTRING Z (338888.677 7372088.845 0.000, 33...  30_12_20/
# 1   MULTILINESTRING Z ((338750.839 7372670.954 0.0...  30_12_20/
# 2   LINESTRING Z (338823.785 7372000.159 0.000, 33...       None
# 3   LINESTRING Z (339013.276 7372160.846 0.000, 33...  30_12_20/
# 4   LINESTRING Z (338991.536 7372179.271 0.000, 33...  30_12_20/
# 5   LINESTRING Z (338874.449 7372250.753 0.000, 33...  30_12_20/
# 6   MULTILINESTRING Z ((338814.368 7371988.788 0.0...  30_12_20/
# 7   LINESTRING Z (339102.406 7372415.296 0.000, 33...  30_12_20/
# 8   LINESTRING Z (339037.145 7372695.600 0.000, 33...  30_12_20/
# 9   LINESTRING Z (339082.105 7371792.808 0.000, 33...  30_12_20/
# 10  MULTILINESTRING Z ((338920.885 7372130.664 0.0...  30_12_20/
# 11  LINESTRING Z (339112.349 7371822.283 0.000, 33...  30_12_20/
# 12  LINESTRING Z (338872.760 7372065.634 0.000, 33...  30_12_20/
# 13  LINESTRING Z (339490.347 7372295.254 0.000, 33...  30_12_20/
# 14  MULTILINESTRING Z ((338667.780 7372633.849 0.0...  30_12_20/
# 15  LINESTRING Z (339426.563 7372304.360 0.000, 33...  30_12_20/
# 16  LINESTRING Z (338939.769 7372153.684 0.000, 33...  30_12_20/
# 17  LINESTRING Z (338888.663 7372263.635 0.000, 33...  30_12_20/
# 18  LINESTRING Z (339031.662 7372223.595 0.000, 33...  30_12_20/
# 19  LINESTRING Z (339016.597 7372199.634 0.000, 33...  30_12_20/
#
#                                   logradouro      etapa       Video_0  \
# 0                      ESTRADA ARTHUR MARSON  etapa_01/  DJI_0007.MOV
# 1                        ESTRADA LUIZ MARSON  etapa_01/  DJI_0025.MOV
# 2   MCT RUA PROF. BENEDITO CARLOS DOS SANTOS                     None
# 3                         PASSAGEM DE ACÁCIA  etapa_01/  DJI_0013.MOV
# 4                        PASSAGEM SÃO RAFAEL  etapa_01/  DJI_0014.MOV
# 5                         RUA AGUAS DE PRATA  etapa_01/  DJI_0012.MOV
# 6                  RUA ALAMEDA DAS PAINEIRAS  etapa_01/  DJI_0004.MOV
# 7                     RUA ANTONIO BATTISTINI  etapa_01/  DJI_0026.MOV
# 8                RUA ASSUMPTA SABATINI ROSSI  etapa_01/  DJI_0024.MOV
# 9                           RUA DA CONQUISTA  etapa_01/  DJI_0002.MOV
# 10                             RUA DA ÁRVORE  etapa_01/  DJI_0006.MOV
# 11                            RUA DAS FLORES  etapa_01/  DJI_0001.MOV
# 12                       RUA IPÓLITO MINUCCI  etapa_01/  DJI_0017.MOV
# 13                     RUA JOSÉ JOÃO SANTANA  etapa_01/  DJI_0023.MOV
# 14                       RUA LUIGI BATISTINI  etapa_01/  DJI_0027.MOV
# 15                   RUA LUIZA DE O. SANTANA  etapa_01/  DJI_0021.MOV
# 16                       RUA PEDRO ZAMPIERRI  etapa_01/  DJI_0015.MOV
# 17                      RUA SANTE BATTISTINI  etapa_01/  DJI_0005.MOV
# 18                RUA ÁGUAS DE SANTA BÁRBARA  etapa_01/  DJI_0010.MOV
# 19                  RUA ÁGUAS DE SANTA CLARA  etapa_01/  DJI_0011.MOV
#
#          Video_1                            Video_0_path  \
# 0           None  videos/batistini/etapa_01/DJI_0007.MOV
# 1           None  videos/batistini/etapa_01/DJI_0025.MOV
# 2           None                                    None
# 3           None  videos/batistini/etapa_01/DJI_0013.MOV
# 4           None  videos/batistini/etapa_01/DJI_0014.MOV
# 5           None  videos/batistini/etapa_01/DJI_0012.MOV
# 6   DJI_0001.MOV  videos/batistini/etapa_01/DJI_0004.MOV
# 7           None  videos/batistini/etapa_01/DJI_0026.MOV
# 8           None  videos/batistini/etapa_01/DJI_0024.MOV
# 9   DJI_0003.MOV  videos/batistini/etapa_01/DJI_0002.MOV
# 10          None  videos/batistini/etapa_01/DJI_0006.MOV
# 11          None  videos/batistini/etapa_01/DJI_0001.MOV
# 12          None  videos/batistini/etapa_01/DJI_0017.MOV
# 13          None  videos/batistini/etapa_01/DJI_0023.MOV
# 14          None  videos/batistini/etapa_01/DJI_0027.MOV
# 15          None  videos/batistini/etapa_01/DJI_0021.MOV
# 16          None  videos/batistini/etapa_01/DJI_0015.MOV
# 17          None  videos/batistini/etapa_01/DJI_0005.MOV
# 18          None  videos/batistini/etapa_01/DJI_0010.MOV
# 19          None  videos/batistini/etapa_01/DJI_0011.MOV
#
#                               Video_1_path
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6   videos/batistini/etapa_01/DJI_0001.MOV
# 7                                     None
# 8                                     None
# 9   videos/batistini/etapa_01/DJI_0003.MOV
# 10                                    None
# 11                                    None
# 12                                    None
# 13                                    None
# 14                                    None
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'data_voo', 'Video_1', 'Video_0', 'etapa'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-CONFLITO-DE-PROGRAMAS.gpkg', driver='GPKG')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-f7d76493cca3> in <module>
# ----> 1 gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'data_voo', 'Video_1', 'Video_0', 'Video_2', 'etapa'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-CONFLITO-DE-PROGRAMAS.gpkg', driver='GPKG')
#
# ~/miniconda3/envs/geo/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/miniconda3/envs/geo/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/miniconda3/envs/geo/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/miniconda3/envs/geo/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Video_2'] not found in axis"

# %%
gdf_dxf.dtypes
