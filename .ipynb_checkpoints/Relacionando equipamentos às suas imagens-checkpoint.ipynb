# %%
import pandas as pd
import geopandas as gpd

# %%
from pathlib import Path
import re

files = []

for path in Path('imagens').rglob('*.*'):
    for i in re.findall(r"([A-Z]{2,4}-[0-9]{2})", path.name):
        files.append([i, path.as_posix()])
#     print(re.findall(r"([A-Z]{2,4}-[0-9]{2})", path.name), path )

# %%
df_imagens = pd.DataFrame(files, columns=['cod', 'path'])

# %%
df_cods = pd.DataFrame(df_imagens.groupby('cod')['path'].apply(list))

# %%
df_imagens = pd.DataFrame(list(map(lambda x: x, df_cods.path))).add_prefix('imagem_')

# %%
df_imagens['cod'] = df_cods.index

# %%
df_imagens.set_index('cod')
# Out:
#                                                  imagem_0  \
# cod
# AUR-00  imagens/BOTUJURU/EQUIPAMENTOS NOVOS/AUR-00 Pra...
# AUR-01  imagens/JORDANOPOLIS/AUR-01 Praça Domingos Van...
# AUR-02  imagens/JORDANOPOLIS/AUR-02 Praça Ronald. De C...
# AUR-03  imagens/MONTANHÃO/AUR-03 Praça Henrique Trinda...
# AUR-04  imagens/MONTANHÃO/AUR-04 Praça Vicente de Paul...
# ...                                                   ...
# SAU-15  imagens/INDEPENDÊNCIA/EQUIPAMENTOS EXISTENTES/...
# SAU-16  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-17  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-19  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# SAU-20  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
#
#                                                  imagem_1  \
# cod
# AUR-00  imagens/BOTUJURU/EQUIPAMENTOS NOVOS/AUR-00 Pra...
# AUR-01  imagens/JORDANOPOLIS/AUR-01 Praça Domingos Van...
# AUR-02  imagens/JORDANOPOLIS/AUR-02 Praça Ronald. De C...
# AUR-03  imagens/MONTANHÃO/AUR-03 Praça Henrique Trinda...
# AUR-04  imagens/MONTANHÃO/AUR-04 Praça Vicente de Paul...
# ...                                                   ...
# SAU-15  imagens/INDEPENDÊNCIA/EQUIPAMENTOS EXISTENTES/...
# SAU-16  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-17  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-19  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# SAU-20  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
#
#                                                  imagem_2  \
# cod
# AUR-00                                               None
# AUR-01  imagens/JORDANOPOLIS/AUR-01 Praça Domingos Van...
# AUR-02  imagens/JORDANOPOLIS/AUR-02 Praça Ronald. De C...
# AUR-03  imagens/MONTANHÃO/AUR-03 Praça Henrique Trinda...
# AUR-04  imagens/MONTANHÃO/AUR-04 Praça Vicente de Paul...
# ...                                                   ...
# SAU-15  imagens/INDEPENDÊNCIA/EQUIPAMENTOS EXISTENTES/...
# SAU-16  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-17  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-19  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# SAU-20  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
#
#                                                  imagem_3  \
# cod
# AUR-00                                               None
# AUR-01  imagens/JORDANOPOLIS/AUR-01 Praça Domingos Van...
# AUR-02  imagens/JORDANOPOLIS/AUR-02 Praça Ronald. De C...
# AUR-03                                               None
# AUR-04  imagens/MONTANHÃO/AUR-04 Praça Vicente de Paul...
# ...                                                   ...
# SAU-15  imagens/INDEPENDÊNCIA/EQUIPAMENTOS EXISTENTES/...
# SAU-16  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-17  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-19                                               None
# SAU-20  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
#
#                                                  imagem_4  \
# cod
# AUR-00                                               None
# AUR-01                                               None
# AUR-02                                               None
# AUR-03                                               None
# AUR-04  imagens/MONTANHÃO/AUR-04 Praça Vicente de Paul...
# ...                                                   ...
# SAU-15  imagens/INDEPENDÊNCIA/EQUIPAMENTOS EXISTENTES/...
# SAU-16  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-17  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...
# SAU-19                                               None
# SAU-20  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
#
#                                                  imagem_5 imagem_6 imagem_7
# cod
# AUR-00                                               None     None     None
# AUR-01                                               None     None     None
# AUR-02                                               None     None     None
# AUR-03                                               None     None     None
# AUR-04  imagens/MONTANHÃO/AUR-04 Praça Vicente de Paul...     None     None
# ...                                                   ...      ...      ...
# SAU-15  imagens/INDEPENDÊNCIA/EQUIPAMENTOS EXISTENTES/...     None     None
# SAU-16  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...     None     None
# SAU-17  imagens/PAULICÉIA/EQUIPAMENTOS EXISTENTES/SAU-...     None     None
# SAU-19                                               None     None     None
# SAU-20  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...     None     None
#
# [94 rows x 8 columns]

# %%
df_equip = pd.read_csv('./GIS/planilhas/equipamentos-XY.csv', delimiter=';', decimal=',')

# %%
df_equip['cod'] = df_equip['COD DO LOCAL ']
# df_equip.columns

# %%
df_equip = pd.merge(df_equip, df_imagens.set_index('cod'), on='cod', how='left')

# %%
gdf_equip = gpd.GeoDataFrame(df_equip, geometry=gpd.points_from_xy(df_equip.X, df_equip.Y))

# %%
gdf_equip.drop(['X', 'Y', 'COD DO LOCAL ',  ], axis=1)
# Out:
#         BAIRRO                                               NOME  \
# 0    BATISTINI                  EMEB 1 OCTAVIO EDGARD DE OLIVEIRA
# 1    BATISTINI                     EMEB ANTONIO DOS SANTOS FARIAS
# 2    BATISTINI                  EMEB CLEIA MARIA TEURES DE SOUZA
# 3    BATISTINI                              EMEB MANOEL DE BARROS
# 4    BATISTINI                   EMEB PROFESSOR WALDEMAR CANCIANI
# ..         ...                                                ...
# 94  RIO GRANDE                                  UBS RIACHO GRANDE
# 95  RIO GRANDE  Rio Grande - E.I/ Fundamental / Integral EMEB ...
# 96      TABOÃO                          Praça José Pino Cassetari
# 97      TABOÃO  Taboão - E. Infantil/ Fundamental/  ESCOLA EST...
# 98      TABOÃO                           Taboão - Creche/Integral
#
#                                 TIPO  \
# 0                           EDUCAÇÃO
# 1                           EDUCAÇÃO
# 2                           EDUCAÇÃO
# 3                           EDUCAÇÃO
# 4                           EDUCAÇÃO
# ..                               ...
# 94                             SAÚDE
# 95                          EDUCAÇÃO
# 96  REQUALIFICAÇÃO DE ÁREAS URBANAS
# 97                          EDUCAÇÃO
# 98                          EDUCAÇÃO
#
#                                              ENDEREÇO  PRIORIDADE  \
# 0                                R. João Saldanha 424         NaN
# 1                                        R. Irati, 11         NaN
# 2                                         R. Irati, 2         NaN
# 3                                       Rua Canada, 1         NaN
# 4                       R. José Martins Fernandes, 86         NaN
# ..                                                ...         ...
# 94                                 R. Santa Maria, 20         NaN
# 95  R. João D'Ângelo, 71 - Vila do Rio Grande, CEP...         3.0
# 96                                Rua Neuchatel , 270         3.0
# 97  Av. do Taboão, 3550 - Vila Santa Luzia, CEP 09...         NaN
# 98      R. dos Alpes, alt. 109 - Suiço, CEP 09663-070         NaN
#
#    ESTADO DO EQUIPAMENTO                     geometry     cod  \
# 0              EXISTENTE  POINT (-46.61087 -23.77109)   ED-31
# 1              EXISTENTE  POINT (-46.59905 -23.77569)   ED-32
# 2              EXISTENTE  POINT (-46.59930 -23.77555)   ED-33
# 3              EXISTENTE  POINT (-46.59692 -23.77679)   ED-34
# 4              EXISTENTE  POINT (-46.59060 -23.76960)   ED-35
# ..                   ...                          ...     ...
# 94             EXISTENTE  POINT (-46.52968 -23.77981)  SAU-20
# 95               REFORMA  POINT (-46.52911 -23.77968)   ED-61
# 96        REQUALIFICAÇÃO  POINT (-46.59927 -23.65646)  AUR-12
# 97               REFORMA  POINT (-46.60555 -23.66059)     NaN
# 98                  NOVO  POINT (-46.60034 -23.65683)     NaN
#
#                                              imagem_0  \
# 0   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 1   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 2                                                 NaN
# 3   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 4   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# ..                                                ...
# 94  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# 95  imagens/RIO GRANDE/EQUIPAMENTOS NOVOS/ED-61 Ri...
# 96  imagens/TABOÃO/EQUIPAMENTOS NOVOS/AUR-12 Praça...
# 97                                                NaN
# 98                                                NaN
#
#                                              imagem_1  \
# 0   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 1   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 2                                                 NaN
# 3   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 4   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# ..                                                ...
# 94  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# 95  imagens/RIO GRANDE/EQUIPAMENTOS NOVOS/ED-61 Ri...
# 96  imagens/TABOÃO/EQUIPAMENTOS NOVOS/AUR-12 Praça...
# 97                                                NaN
# 98                                                NaN
#
#                                              imagem_2  \
# 0   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 1   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 2                                                 NaN
# 3   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 4   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# ..                                                ...
# 94  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# 95  imagens/RIO GRANDE/EQUIPAMENTOS NOVOS/ED-61 Ri...
# 96  imagens/TABOÃO/EQUIPAMENTOS NOVOS/AUR-12 Praça...
# 97                                                NaN
# 98                                                NaN
#
#                                              imagem_3  \
# 0   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 1   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 2                                                 NaN
# 3   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 4   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# ..                                                ...
# 94  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# 95  imagens/RIO GRANDE/EQUIPAMENTOS NOVOS/ED-61 Ri...
# 96  imagens/TABOÃO/EQUIPAMENTOS NOVOS/AUR-12 Praça...
# 97                                                NaN
# 98                                                NaN
#
#                                              imagem_4  \
# 0   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 1   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# 2                                                 NaN
# 3                                                None
# 4   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...
# ..                                                ...
# 94  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...
# 95  imagens/RIO GRANDE/EQUIPAMENTOS NOVOS/ED-61 Ri...
# 96  imagens/TABOÃO/EQUIPAMENTOS NOVOS/AUR-12 Praça...
# 97                                                NaN
# 98                                                NaN
#
#                                              imagem_5 imagem_6 imagem_7
# 0   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...     None     None
# 1   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...     None     None
# 2                                                 NaN      NaN      NaN
# 3                                                None     None     None
# 4   imagens/BATISTINI/EQUIPAMENTOS EXISTENTES/ED-3...     None     None
# ..                                                ...      ...      ...
# 94  imagens/RIO GRANDE/EQUIPAMENTOS EXISTENTES/SAU...     None     None
# 95                                               None     None     None
# 96  imagens/TABOÃO/EQUIPAMENTOS NOVOS/AUR-12 Praça...     None     None
# 97                                                NaN      NaN      NaN
# 98                                                NaN      NaN      NaN
#
# [99 rows x 16 columns]
