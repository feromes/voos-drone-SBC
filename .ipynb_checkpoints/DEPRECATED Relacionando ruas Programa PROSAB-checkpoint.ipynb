# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/Base - PROGRAMA PROSAB.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                  Layer PaperSpace  \
# 0    PASSAGEM SANTOS DIAS DA SILVA - 09_12_20 - DJI...       None
# 1                                    VETORIZAÃÃO RUA       None
# 2          AVENIDA PÃROLA NEGRA - 09_12_20 - DJI_0030       None
# 3                  RUA BORTOLITO - 09_12_20 - DJI_0024       None
# 4    RUA MARIANA BENVINDA DA COSTA - 12_12_20 - PAS...       None
# ..                                                 ...        ...
# 650  RUA 11 DE JULHO - 10_12_20 - PASTA ETAPA 04 - ...       None
# 651  RUA 26 DE NOVEMBRO - 10_12_20 - PASTA ETAPA 03...       None
# 652  RUA DA EVOLUÃÃO - 10_12_20 - PASTA ETAPA 03 ...       None
# 653  RUA DA EVOLUÃÃO - 10_12_20 - PASTA ETAPA 03 ...       None
# 654                                 MCT - RUA FLORESTA       None
#
#                     SubClasses    Linetype EntityHandle  Text  \
# 0    AcDbEntity:AcDb2dPolyline  Continuous           6F  None
# 1    AcDbEntity:AcDb2dPolyline  Continuous           7B  None
# 2    AcDbEntity:AcDb2dPolyline  Continuous           84  None
# 3    AcDbEntity:AcDb2dPolyline  Continuous           91  None
# 4    AcDbEntity:AcDb2dPolyline  Continuous           96  None
# ..                         ...         ...          ...   ...
# 650  AcDbEntity:AcDb2dPolyline  Continuous         108B  None
# 651  AcDbEntity:AcDb2dPolyline  Continuous         1090  None
# 652  AcDbEntity:AcDb2dPolyline  Continuous         1095  None
# 653  AcDbEntity:AcDb2dPolyline  Continuous         10A3  None
# 654  AcDbEntity:AcDb2dPolyline  Continuous         10AA  None
#
#                                               geometry
# 0    LINESTRING Z (338840.785 7373796.688 0.000, 33...
# 1    LINESTRING Z (339127.037 7373351.847 0.000, 33...
# 2    LINESTRING Z (339075.393 7373029.977 0.000, 33...
# 3    LINESTRING Z (339151.229 7372743.960 0.000, 33...
# 4    LINESTRING Z (338748.464 7373483.833 0.000, 33...
# ..                                                 ...
# 650  LINESTRING Z (334491.001 7372425.842 0.000, 33...
# 651  LINESTRING Z (334329.489 7372267.133 0.000, 33...
# 652  LINESTRING Z (334374.396 7372240.787 0.000, 33...
# 653  LINESTRING Z (334329.489 7372267.133 0.000, 33...
# 654  LINESTRING Z (334293.507 7372225.595 0.000, 33...
#
# [655 rows x 7 columns]

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('MCT - ', '')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('DJI_[0-9]{4}')

# %%
gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf
# Out:
#                                                  Layer PaperSpace  \
# 0    PASSAGEM SANTOS DIAS DA SILVA - 09_12_20 - DJI...       None
# 1                                      VETORIZAÇÃO RUA       None
# 2           AVENIDA PÉROLA NEGRA - 09_12_20 - DJI_0030       None
# 3                  RUA BORTOLITO - 09_12_20 - DJI_0024       None
# 4    RUA MARIANA BENVINDA DA COSTA - 12_12_20 - PAS...       None
# ..                                                 ...        ...
# 650  RUA 11 DE JULHO - 10_12_20 - PASTA ETAPA 04 - ...       None
# 651  RUA 26 DE NOVEMBRO - 10_12_20 - PASTA ETAPA 03...       None
# 652  RUA DA EVOLUÇÃO - 10_12_20 - PASTA ETAPA 03 - ...       None
# 653  RUA DA EVOLUÇÃO - 10_12_20 - PASTA ETAPA 03 - ...       None
# 654                                       RUA FLORESTA       None
#
#                     SubClasses    Linetype EntityHandle  Text  \
# 0    AcDbEntity:AcDb2dPolyline  Continuous           6F  None
# 1    AcDbEntity:AcDb2dPolyline  Continuous           7B  None
# 2    AcDbEntity:AcDb2dPolyline  Continuous           84  None
# 3    AcDbEntity:AcDb2dPolyline  Continuous           91  None
# 4    AcDbEntity:AcDb2dPolyline  Continuous           96  None
# ..                         ...         ...          ...   ...
# 650  AcDbEntity:AcDb2dPolyline  Continuous         108B  None
# 651  AcDbEntity:AcDb2dPolyline  Continuous         1090  None
# 652  AcDbEntity:AcDb2dPolyline  Continuous         1095  None
# 653  AcDbEntity:AcDb2dPolyline  Continuous         10A3  None
# 654  AcDbEntity:AcDb2dPolyline  Continuous         10AA  None
#
#                                               geometry  \
# 0    LINESTRING Z (338840.785 7373796.688 0.000, 33...
# 1    LINESTRING Z (339127.037 7373351.847 0.000, 33...
# 2    LINESTRING Z (339075.393 7373029.977 0.000, 33...
# 3    LINESTRING Z (339151.229 7372743.960 0.000, 33...
# 4    LINESTRING Z (338748.464 7373483.833 0.000, 33...
# ..                                                 ...
# 650  LINESTRING Z (334491.001 7372425.842 0.000, 33...
# 651  LINESTRING Z (334329.489 7372267.133 0.000, 33...
# 652  LINESTRING Z (334374.396 7372240.787 0.000, 33...
# 653  LINESTRING Z (334329.489 7372267.133 0.000, 33...
# 654  LINESTRING Z (334293.507 7372225.595 0.000, 33...
#
#                                                  lista         DJI     etapa  \
# 0    [PASSAGEM SANTOS DIAS DA SILVA, 09_12_20, DJI_...  [DJI_0042]       NaN
# 1                                    [VETORIZAÇÃO RUA]          []       NaN
# 2           [AVENIDA PÉROLA NEGRA, 09_12_20, DJI_0030]  [DJI_0030]       NaN
# 3                  [RUA BORTOLITO, 09_12_20, DJI_0024]  [DJI_0024]       NaN
# 4    [RUA MARIANA BENVINDA DA COSTA, 12_12_20, PAST...  [DJI_0015]  ETAPA 02
# ..                                                 ...         ...       ...
# 650  [RUA 11 DE JULHO, 10_12_20, PASTA ETAPA 04, DJ...  [DJI_0019]  ETAPA 04
# 651  [RUA 26 DE NOVEMBRO, 10_12_20, PASTA ETAPA 03,...  [DJI_0010]  ETAPA 03
# 652  [RUA DA EVOLUÇÃO, 10_12_20, PASTA ETAPA 03, DJ...  [DJI_0009]  ETAPA 03
# 653  [RUA DA EVOLUÇÃO, 10_12_20, PASTA ETAPA 03, DJ...  [DJI_0009]  ETAPA 03
# 654                                     [RUA FLORESTA]          []       NaN
#
#      data_voo                     logradouro
# 0    09_12_20  PASSAGEM SANTOS DIAS DA SILVA
# 1         NaN                VETORIZAÇÃO RUA
# 2    09_12_20           AVENIDA PÉROLA NEGRA
# 3    09_12_20                  RUA BORTOLITO
# 4    12_12_20  RUA MARIANA BENVINDA DA COSTA
# ..        ...                            ...
# 650  10_12_20                RUA 11 DE JULHO
# 651  10_12_20             RUA 26 DE NOVEMBRO
# 652  10_12_20                RUA DA EVOLUÇÃO
# 653  10_12_20                RUA DA EVOLUÇÃO
# 654       NaN                   RUA FLORESTA
#
# [655 rows x 12 columns]

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#           Video_0 Video_1 Video_2 Video_3
# 0    DJI_0042.MOV    None    None    None
# 1            None    None    None    None
# 2    DJI_0030.MOV    None    None    None
# 3    DJI_0024.MOV    None    None    None
# 4    DJI_0015.MOV    None    None    None
# ..            ...     ...     ...     ...
# 650  DJI_0019.MOV    None    None    None
# 651  DJI_0010.MOV    None    None    None
# 652  DJI_0009.MOV    None    None    None
# 653  DJI_0009.MOV    None    None    None
# 654          None    None    None    None
#
# [655 rows x 4 columns]

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'etapa', 'data_voo', 'logradouro',
#        'Video_0', 'Video_1', 'Video_2', 'Video_3'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + gdf_dxf.data_voo + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1).to_file('./videos/ruas-videos-PROSAB.gpkg', driver='GPKG')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# etapa             object
# data_voo          object
# logradouro        object
# Video_0           object
# Video_1           object
# Video_2           object
# Video_3           object
# Video_0_path      object
# Video_1_path      object
# Video_2_path      object
# Video_3_path      object
# dtype: object
