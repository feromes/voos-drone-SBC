# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/DOS ALVARENGA Conflito de Programas.dxf', encoding='ANSI_1252')

# %%
bairro = 'DOS-ALVARENGA'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0                                       MCT - VIELA 4       None
# 1                  RUA GUANAMBY - 11_12_20 - DJI_0013       None
# 2               MCT - RUA CORONEL BONIFÃCIO CARVALHO       None
# 3                 MCT - RUA MARIA DA PENHA N. E SILVA       None
# 4                                MCT - RUA BRAZ CUBAS       None
# ..                                                ...        ...
# 77  RUA JOSEFINA FELTRIN - 12_12_20 - PASTA ETAPA ...       None
# 78  RUA JOÃO BRUNI - 12_12_20 - PASTA ETAPA 01 - ...       None
# 79                                     MCT - VIELA 06       None
# 80                               MCT - RUA PARAGUAÃU       None
# 81  RUA BENEDITO SERAFIM BUENO - 12_12_20 - PASTA ...       None
#
#                    SubClasses    Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline  Continuous           6F  None
# 1   AcDbEntity:AcDb2dPolyline  Continuous           74  None
# 2   AcDbEntity:AcDb2dPolyline  Continuous           79  None
# 3   AcDbEntity:AcDb2dPolyline  Continuous           7E  None
# 4   AcDbEntity:AcDb2dPolyline  Continuous           85  None
# ..                        ...         ...          ...   ...
# 77  AcDbEntity:AcDb2dPolyline  Continuous          12B  None
# 78        AcDbEntity:AcDbLine  Continuous          132  None
# 79  AcDbEntity:AcDb2dPolyline  Continuous          134  None
# 80  AcDbEntity:AcDb2dPolyline  Continuous          13B  None
# 81  AcDbEntity:AcDb2dPolyline  Continuous          151  None
#
#                                              geometry
# 0   LINESTRING Z (336610.182 7371836.608 0.000, 33...
# 1   LINESTRING Z (336383.050 7371850.472 0.000, 33...
# 2   LINESTRING Z (336390.997 7371920.366 0.000, 33...
# 3   LINESTRING Z (336438.351 7371961.754 0.000, 33...
# 4   LINESTRING Z (336521.485 7371894.202 0.000, 33...
# ..                                                ...
# 77  LINESTRING Z (337768.274 7374141.406 0.000, 33...
# 78  LINESTRING Z (337753.218 7374199.581 0.000, 33...
# 79  LINESTRING Z (337759.464 7374532.702 0.000, 33...
# 80  LINESTRING Z (337666.967 7374583.589 0.000, 33...
# 81  LINESTRING Z (337679.634 7374524.189 0.000, 33...
#
# [82 rows x 7 columns]

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
# gdf_dxf.Layer.to_list()

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('!', '1')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('DJI_[0-9]{4}')

# %%
# gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer'].to_list()
# Out:
# [' VIELA 4',
#  ' RUA CORONEL BONIFÁCIO CARVALHO',
#  ' RUA MARIA DA PENHA N. E SILVA',
#  ' RUA BRAZ CUBAS',
#  ' RUA SÃO CRISTÓVÃO',
#  ' RUA DOS CAÇADORES',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA NORA ASTORGA',
#  ' RUA PASQUALE SCARANO',
#  ' RUA THELMA',
#  ' VIELA 05',
#  ' VIELA 07',
#  ' VIELA 06',
#  ' RUA PARAGUAÇU']

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)
# Out:
#                                   0         1     2                     3  \
# 0                           VIELA 4      None  None                  None
# 1                   RUA GUANAMBY -   11_12_20  None                    -
# 2    RUA CORONEL BONIFÁCIO CARVALHO      None  None                  None
# 3     RUA MARIA DA PENHA N. E SILVA      None  None                  None
# 4                    RUA BRAZ CUBAS      None  None                  None
# ..                              ...       ...   ...                   ...
# 77          RUA JOSEFINA FELTRIN -   12_12_20  None   - PASTA ETAPA 01 -
# 78                RUA JOÃO BRUNI -   12_12_20  None   - PASTA ETAPA 01 -
# 79                         VIELA 06      None  None                  None
# 80                    RUA PARAGUAÇU      None  None                  None
# 81    RUA BENEDITO SERAFIM BUENO -   12_12_20  None   - PASTA ETAPA 01 -
#
#        4         5     6
# 0   None      None  None
# 1   None  DJI_0013
# 2   None      None  None
# 3   None      None  None
# 4   None      None  None
# ..   ...       ...   ...
# 77  None  DJI_0058
# 78  None  DJI_0057
# 79  None      None  None
# 80  None      None  None
# 81  None  DJI_0055
#
# [82 rows x 7 columns]

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].unique()
# Out:
# array([None, ' - ', ' - PASTA ETAPA 01 - '], dtype=object)

# %%
etapas = {
    ' - PASTA ETAPA 04 - ':'etapa_04', 
    ' - ':'etapa_00', 
    '  - PASTA ETAPA 02 - ':'etapa_02',
    ' - PASTA ETAPA 02 - ':'etapa_02', 
    '  - PASTA ETAPA 01 - ':'etapa_01',
    ' - PASTA ETAPA 01 - ':'etapa_01', 
    ' -PASTA ETAPA 03 - ':'etapa_03',
    '':'etapa_00',
    ' - PASTA ETAPA 03 - ':'etapa_03', 
    ' - PASTA ETAPA 02 -':'etapa_02', 
    ' - ETAPA 03 - ':'etapa_03',
    '- PASTA ETAPA 03 - ':'etapa_03', 
    ' - PASTA ETAPA 01 -':'etapa_01',
    ' -  PASTA ETAPA 01 - ':'etapa_01', 
    '21 - Mavic - ':'etapa_00', 
    '21 - Mavic -  ':'etapa_00',
    '21 - Phantom - ':'etapa_00', 
    ' -PASTA ETAPA 01 - ':'etapa_01', 
    ' PASTA ETAPA 04':'etapa_04',
    '  - PASTA ETAPA 04 - ':'etapa_04', 
    '- PASTA ETAPA 04 -':'etapa_04',
    ' - PASTA ETAPA 04 -':'etapa_04'
}

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(etapas)
# Out:
# 0          NaN
# 1     etapa_00
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 77    etapa_01
# 78    etapa_01
# 79         NaN
# 80         NaN
# 81    etapa_01
# Name: 3, Length: 82, dtype: object

# %%
gdf_dxf.loc[:, 'etapa'] = gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(etapas)

# %%
gdf_dxf.loc[:, 'etapa']
# Out:
# 0          NaN
# 1     etapa_00
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 77    etapa_01
# 78    etapa_01
# 79         NaN
# 80         NaN
# 81    etapa_01
# Name: etapa, Length: 82, dtype: object

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0                                             VIELA 4       None
# 1                  RUA GUANAMBY - 11_12_20 - DJI_0013       None
# 2                      RUA CORONEL BONIFÁCIO CARVALHO       None
# 3                       RUA MARIA DA PENHA N. E SILVA       None
# 4                                      RUA BRAZ CUBAS       None
# ..                                                ...        ...
# 77  RUA JOSEFINA FELTRIN - 12_12_20 - PASTA ETAPA ...       None
# 78  RUA JOÃO BRUNI - 12_12_20 - PASTA ETAPA 01 - D...       None
# 79                                           VIELA 06       None
# 80                                      RUA PARAGUAÇU       None
# 81  RUA BENEDITO SERAFIM BUENO - 12_12_20 - PASTA ...       None
#
#                    SubClasses    Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline  Continuous           6F  None
# 1   AcDbEntity:AcDb2dPolyline  Continuous           74  None
# 2   AcDbEntity:AcDb2dPolyline  Continuous           79  None
# 3   AcDbEntity:AcDb2dPolyline  Continuous           7E  None
# 4   AcDbEntity:AcDb2dPolyline  Continuous           85  None
# ..                        ...         ...          ...   ...
# 77  AcDbEntity:AcDb2dPolyline  Continuous          12B  None
# 78        AcDbEntity:AcDbLine  Continuous          132  None
# 79  AcDbEntity:AcDb2dPolyline  Continuous          134  None
# 80  AcDbEntity:AcDb2dPolyline  Continuous          13B  None
# 81  AcDbEntity:AcDb2dPolyline  Continuous          151  None
#
#                                              geometry  \
# 0   LINESTRING Z (336610.182 7371836.608 0.000, 33...
# 1   LINESTRING Z (336383.050 7371850.472 0.000, 33...
# 2   LINESTRING Z (336390.997 7371920.366 0.000, 33...
# 3   LINESTRING Z (336438.351 7371961.754 0.000, 33...
# 4   LINESTRING Z (336521.485 7371894.202 0.000, 33...
# ..                                                ...
# 77  LINESTRING Z (337768.274 7374141.406 0.000, 33...
# 78  LINESTRING Z (337753.218 7374199.581 0.000, 33...
# 79  LINESTRING Z (337759.464 7374532.702 0.000, 33...
# 80  LINESTRING Z (337666.967 7374583.589 0.000, 33...
# 81  LINESTRING Z (337679.634 7374524.189 0.000, 33...
#
#                                                 lista         DJI  data_voo  \
# 0                                          [ VIELA 4]          []       NaN
# 1                  [RUA GUANAMBY, 11_12_20, DJI_0013]  [DJI_0013]  11_12_20
# 2                   [ RUA CORONEL BONIFÁCIO CARVALHO]          []       NaN
# 3                    [ RUA MARIA DA PENHA N. E SILVA]          []       NaN
# 4                                   [ RUA BRAZ CUBAS]          []       NaN
# ..                                                ...         ...       ...
# 77  [RUA JOSEFINA FELTRIN, 12_12_20, PASTA ETAPA 0...  [DJI_0058]  12_12_20
# 78  [RUA JOÃO BRUNI, 12_12_20, PASTA ETAPA 01, DJI...  [DJI_0057]  12_12_20
# 79                                        [ VIELA 06]          []       NaN
# 80                                   [ RUA PARAGUAÇU]          []       NaN
# 81  [RUA BENEDITO SERAFIM BUENO, 12_12_20, PASTA E...  [DJI_0055]  12_12_20
#
#                          logradouro     etapa
# 0                           VIELA 4       NaN
# 1                      RUA GUANAMBY  etapa_00
# 2    RUA CORONEL BONIFÁCIO CARVALHO       NaN
# 3     RUA MARIA DA PENHA N. E SILVA       NaN
# 4                    RUA BRAZ CUBAS       NaN
# ..                              ...       ...
# 77             RUA JOSEFINA FELTRIN  etapa_01
# 78                   RUA JOÃO BRUNI  etapa_01
# 79                         VIELA 06       NaN
# 80                    RUA PARAGUAÇU       NaN
# 81       RUA BENEDITO SERAFIM BUENO  etapa_01
#
# [82 rows x 12 columns]

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#          Video_0
# 0           None
# 1   DJI_0013.MOV
# 2           None
# 3           None
# 4           None
# ..           ...
# 77  DJI_0058.MOV
# 78  DJI_0057.MOV
# 79          None
# 80          None
# 81  DJI_0055.MOV
#
# [82 rows x 1 columns]

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'data_voo', 'logradouro', 'etapa',
#        'Video_0'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + bairro.lower().replace('-', '_') + '/' + gdf_dxf.data_voo + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                                 Layer  \
# 0                                      RUA BRAZ CUBAS
# 1                      RUA CORONEL BONIFÁCIO CARVALHO
# 2                                   RUA DOS CAÇADORES
# 3                       RUA MARIA DA PENHA N. E SILVA
# 4                                    RUA NORA ASTORGA
# 5                                       RUA PARAGUAÇU
# 6                                RUA PASQUALE SCARANO
# 7                                   RUA SÃO CRISTÓVÃO
# 8                                          RUA THELMA
# 9                                            VIELA 05
# 10                                           VIELA 06
# 11                                           VIELA 07
# 12                                            VIELA 4
# 13  RUA BENEDITO SERAFIM BUENO - 12_12_20 - PASTA ...
# 14  RUA EDGARD DE SOUZA - 12_12_20 - PASTA ETAPA 0...
# 15        RUA GREGÓRIO DE MATOS - 11_12_20 - DJI_0011
# 16                 RUA GUANAMBY - 11_12_20 - DJI_0013
# 17  RUA JOSEFINA FELTRIN - 12_12_20 - PASTA ETAPA ...
# 18  RUA JOÃO BRUNI - 12_12_20 - PASTA ETAPA 01 - D...
# 19    RUA MARGARIDA MARIA ALVES - 09_12_20 - DJI_0049
#
#                                              geometry PaperSpace  \
# 0   LINESTRING Z (336521.485 7371894.202 0.000, 33...       None
# 1   LINESTRING Z (336390.997 7371920.366 0.000, 33...       None
# 2   LINESTRING Z (336366.497 7371510.572 0.000, 33...       None
# 3   LINESTRING Z (336438.351 7371961.754 0.000, 33...       None
# 4   MULTILINESTRING Z ((336445.559 7371474.015 0.0...       None
# 5   LINESTRING Z (337666.967 7374583.589 0.000, 33...       None
# 6   LINESTRING Z (337753.229 7374267.099 0.000, 33...       None
# 7   LINESTRING Z (336453.987 7371810.033 0.000, 33...       None
# 8   LINESTRING Z (337862.023 7374372.934 0.000, 33...       None
# 9   LINESTRING Z (337732.971 7374345.007 0.000, 33...       None
# 10  LINESTRING Z (337759.464 7374532.702 0.000, 33...       None
# 11  LINESTRING Z (337697.676 7374479.797 0.000, 33...       None
# 12  LINESTRING Z (336610.182 7371836.608 0.000, 33...       None
# 13  LINESTRING Z (337679.634 7374524.189 0.000, 33...       None
# 14  LINESTRING Z (337787.743 7374082.512 0.000, 33...       None
# 15  MULTILINESTRING Z ((336584.045 7371963.768 0.0...       None
# 16  LINESTRING Z (336383.050 7371850.472 0.000, 33...       None
# 17  LINESTRING Z (337768.274 7374141.406 0.000, 33...       None
# 18  LINESTRING Z (337753.218 7374199.581 0.000, 33...       None
# 19  MULTILINESTRING Z ((336553.492 7371730.490 0.0...       None
#
#                        SubClasses    Linetype EntityHandle  Text  \
# 0       AcDbEntity:AcDb2dPolyline  Continuous           85  None
# 1       AcDbEntity:AcDb2dPolyline  Continuous           79  None
# 2       AcDbEntity:AcDb2dPolyline  Continuous           9A  None
# 3       AcDbEntity:AcDb2dPolyline  Continuous           7E  None
# 4             AcDbEntity:AcDbLine  Continuous           E1  None
# 5       AcDbEntity:AcDb2dPolyline  Continuous          13B  None
# 6       AcDbEntity:AcDb2dPolyline  Continuous          10C  None
# 7       AcDbEntity:AcDb2dPolyline  Continuous           8F  None
# 8       AcDbEntity:AcDb2dPolyline  Continuous          112  None
# 9       AcDbEntity:AcDb2dPolyline  Continuous          118  None
# 10      AcDbEntity:AcDb2dPolyline  Continuous          134  None
# 11      AcDbEntity:AcDb2dPolyline  Continuous          11E  None
# 12      AcDbEntity:AcDb2dPolyline  Continuous           6F  None
# 13      AcDbEntity:AcDb2dPolyline  Continuous          151  None
# 14      AcDbEntity:AcDb2dPolyline  Continuous          124  None
# 15            AcDbEntity:AcDbLine  Continuous           DC  None
# 16      AcDbEntity:AcDb2dPolyline  Continuous           74  None
# 17      AcDbEntity:AcDb2dPolyline  Continuous          12B  None
# 18            AcDbEntity:AcDbLine  Continuous          132  None
# 19  AcDbEntity:AcDbCircle:AcDbArc  Continuous           C8  None
#
#                                                 lista         DJI   data_voo  \
# 0                                   [ RUA BRAZ CUBAS]          []        NaN
# 1                   [ RUA CORONEL BONIFÁCIO CARVALHO]          []        NaN
# 2                                [ RUA DOS CAÇADORES]          []        NaN
# 3                    [ RUA MARIA DA PENHA N. E SILVA]          []        NaN
# 4                                 [ RUA NORA ASTORGA]          []        NaN
# 5                                    [ RUA PARAGUAÇU]          []        NaN
# 6                             [ RUA PASQUALE SCARANO]          []        NaN
# 7                                [ RUA SÃO CRISTÓVÃO]          []        NaN
# 8                                       [ RUA THELMA]          []        NaN
# 9                                         [ VIELA 05]          []        NaN
# 10                                        [ VIELA 06]          []        NaN
# 11                                        [ VIELA 07]          []        NaN
# 12                                         [ VIELA 4]          []        NaN
# 13  [RUA BENEDITO SERAFIM BUENO, 12_12_20, PASTA E...  [DJI_0055]  12_12_20/
# 14  [RUA EDGARD DE SOUZA, 12_12_20, PASTA ETAPA 01...  [DJI_0059]  12_12_20/
# 15        [RUA GREGÓRIO DE MATOS, 11_12_20, DJI_0011]  [DJI_0011]  11_12_20/
# 16                 [RUA GUANAMBY, 11_12_20, DJI_0013]  [DJI_0013]  11_12_20/
# 17  [RUA JOSEFINA FELTRIN, 12_12_20, PASTA ETAPA 0...  [DJI_0058]  12_12_20/
# 18  [RUA JOÃO BRUNI, 12_12_20, PASTA ETAPA 01, DJI...  [DJI_0057]  12_12_20/
# 19    [RUA MARGARIDA MARIA ALVES, 09_12_20, DJI_0049]  [DJI_0049]  09_12_20/
#
#                          logradouro      etapa       Video_0  \
# 0                    RUA BRAZ CUBAS                     None
# 1    RUA CORONEL BONIFÁCIO CARVALHO                     None
# 2                 RUA DOS CAÇADORES                     None
# 3     RUA MARIA DA PENHA N. E SILVA                     None
# 4                  RUA NORA ASTORGA                     None
# 5                     RUA PARAGUAÇU                     None
# 6              RUA PASQUALE SCARANO                     None
# 7                 RUA SÃO CRISTÓVÃO                     None
# 8                        RUA THELMA                     None
# 9                          VIELA 05                     None
# 10                         VIELA 06                     None
# 11                         VIELA 07                     None
# 12                          VIELA 4                     None
# 13       RUA BENEDITO SERAFIM BUENO  etapa_01/  DJI_0055.MOV
# 14              RUA EDGARD DE SOUZA  etapa_01/  DJI_0059.MOV
# 15            RUA GREGÓRIO DE MATOS  etapa_00/  DJI_0011.MOV
# 16                     RUA GUANAMBY  etapa_00/  DJI_0013.MOV
# 17             RUA JOSEFINA FELTRIN  etapa_01/  DJI_0058.MOV
# 18                   RUA JOÃO BRUNI  etapa_01/  DJI_0057.MOV
# 19        RUA MARGARIDA MARIA ALVES  etapa_00/  DJI_0049.MOV
#
#                                          Video_0_path
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 14  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 15  videos/dos_alvarenga/11_12_20/etapa_00/DJI_001...
# 16  videos/dos_alvarenga/11_12_20/etapa_00/DJI_001...
# 17  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 18  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 19  videos/dos_alvarenga/09_12_20/etapa_00/DJI_004...

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1)
# Out:
#                                              geometry   data_voo  \
# 0   LINESTRING Z (336521.485 7371894.202 0.000, 33...        NaN
# 1   LINESTRING Z (336390.997 7371920.366 0.000, 33...        NaN
# 2   LINESTRING Z (336366.497 7371510.572 0.000, 33...        NaN
# 3   LINESTRING Z (336438.351 7371961.754 0.000, 33...        NaN
# 4   MULTILINESTRING Z ((336445.559 7371474.015 0.0...        NaN
# 5   LINESTRING Z (337666.967 7374583.589 0.000, 33...        NaN
# 6   LINESTRING Z (337753.229 7374267.099 0.000, 33...        NaN
# 7   LINESTRING Z (336453.987 7371810.033 0.000, 33...        NaN
# 8   LINESTRING Z (337862.023 7374372.934 0.000, 33...        NaN
# 9   LINESTRING Z (337732.971 7374345.007 0.000, 33...        NaN
# 10  LINESTRING Z (337759.464 7374532.702 0.000, 33...        NaN
# 11  LINESTRING Z (337697.676 7374479.797 0.000, 33...        NaN
# 12  LINESTRING Z (336610.182 7371836.608 0.000, 33...        NaN
# 13  LINESTRING Z (337679.634 7374524.189 0.000, 33...  12_12_20/
# 14  LINESTRING Z (337787.743 7374082.512 0.000, 33...  12_12_20/
# 15  MULTILINESTRING Z ((336584.045 7371963.768 0.0...  11_12_20/
# 16  LINESTRING Z (336383.050 7371850.472 0.000, 33...  11_12_20/
# 17  LINESTRING Z (337768.274 7374141.406 0.000, 33...  12_12_20/
# 18  LINESTRING Z (337753.218 7374199.581 0.000, 33...  12_12_20/
# 19  MULTILINESTRING Z ((336553.492 7371730.490 0.0...  09_12_20/
#
#                          logradouro      etapa       Video_0  \
# 0                    RUA BRAZ CUBAS                     None
# 1    RUA CORONEL BONIFÁCIO CARVALHO                     None
# 2                 RUA DOS CAÇADORES                     None
# 3     RUA MARIA DA PENHA N. E SILVA                     None
# 4                  RUA NORA ASTORGA                     None
# 5                     RUA PARAGUAÇU                     None
# 6              RUA PASQUALE SCARANO                     None
# 7                 RUA SÃO CRISTÓVÃO                     None
# 8                        RUA THELMA                     None
# 9                          VIELA 05                     None
# 10                         VIELA 06                     None
# 11                         VIELA 07                     None
# 12                          VIELA 4                     None
# 13       RUA BENEDITO SERAFIM BUENO  etapa_01/  DJI_0055.MOV
# 14              RUA EDGARD DE SOUZA  etapa_01/  DJI_0059.MOV
# 15            RUA GREGÓRIO DE MATOS  etapa_00/  DJI_0011.MOV
# 16                     RUA GUANAMBY  etapa_00/  DJI_0013.MOV
# 17             RUA JOSEFINA FELTRIN  etapa_01/  DJI_0058.MOV
# 18                   RUA JOÃO BRUNI  etapa_01/  DJI_0057.MOV
# 19        RUA MARGARIDA MARIA ALVES  etapa_00/  DJI_0049.MOV
#
#                                          Video_0_path
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 14  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 15  videos/dos_alvarenga/11_12_20/etapa_00/DJI_001...
# 16  videos/dos_alvarenga/11_12_20/etapa_00/DJI_001...
# 17  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 18  videos/dos_alvarenga/12_12_20/etapa_01/DJI_005...
# 19  videos/dos_alvarenga/09_12_20/etapa_00/DJI_004...

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-Conflito-de-programas.gpkg', driver='GPKG')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# data_voo          object
# logradouro        object
# etapa             object
# Video_0           object
# Video_0_path      object
# dtype: object
