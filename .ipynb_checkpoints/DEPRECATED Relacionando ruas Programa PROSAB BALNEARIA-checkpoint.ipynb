# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/BALNEARIA EIXOS VIA.dxf', encoding='ANSI_1252')

# %%
bairro = 'BALNEARIA'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                Layer PaperSpace  \
# 0           AVENIDA BALNEÃRIA - 29_12_20 - DJI_0032       None
# 1  RUA JOHAN DE ALCÃNTARA SILVA - 29_12_20 - DJI...       None
# 2                 RUA MUTUÃPE - 29_12_20 - DJI_0030       None
# 3  ESTRADA MARTIM AFONSO DE SOUZA - 29_12_20 - DJ...       None
#
#                   SubClasses Linetype EntityHandle  Text  \
# 0  AcDbEntity:AcDb2dPolyline     None           6F  None
# 1  AcDbEntity:AcDb2dPolyline     None           74  None
# 2  AcDbEntity:AcDb2dPolyline     None           F0  None
# 3  AcDbEntity:AcDb2dPolyline     None           F5  None
#
#                                             geometry
# 0  LINESTRING Z (342823.761 7370822.653 0.000, 34...
# 1  LINESTRING Z (342729.170 7370805.590 0.000, 34...
# 2  LINESTRING Z (342065.913 7370104.198 0.000, 34...
# 3  LINESTRING Z (342021.277 7369702.265 0.000, 34...

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
gdf_dxf.Layer.to_list()
# Out:
# ['AVENIDA BALNEÃ\x81RIA - 29_12_20 - DJI_0032',
#  'RUA JOHAN DE ALCÃ\x82NTARA SILVA - 29_12_20 - DJI_0031',
#  'RUA MUTUÃ\x8dPE - 29_12_20 - DJI_0030',
#  'ESTRADA MARTIM AFONSO DE SOUZA - 29_12_20 - DJI_0028 - DJI_0029']

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('MCT - ', '')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('DJI_[0-9]{4}')

# %%
gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)
# Out:
#                                    0         1     2    3     4         5  \
# 0               AVENIDA BALNEÁRIA -   29_12_20  None   -   None  DJI_0032
# 1    RUA JOHAN DE ALCÂNTARA SILVA -   29_12_20  None   -   None  DJI_0031
# 2                     RUA MUTUÍPE -   29_12_20  None   -   None  DJI_0030
# 3  ESTRADA MARTIM AFONSO DE SOUZA -   29_12_20  None   -   None  DJI_0028
#
#      6     7         8     9
# 0       None      None  None
# 1       None      None  None
# 2       None      None  None
# 3   -   None  DJI_0029

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3
# 34  AVENIDA BEETHOVEN - 29_12_20 - MAVIC - BOTUJUR...       None
# 35  RUA VALSA DE VIENA - 29_12_20 - MAVIC - BOTUJU...       None
# 36  RUA BODAS DE PRATA - 29_12_20 - MAVIC - BOTUJU...       None
# 37  ESTRADA DO VERGUEIRO - 29_12_20 - PHANTOM 4 - ...       None
# 38  RUA FELIPE MACEDO PONTES - 29_12_20 - MAVIC - ...       None
# 39  RUA ARCO VERDE - 29_12_20 _ MAVIC - BOTUJURU -...       None
# 40                                   TRAVESSA GRAVATÁ       None
# 41  RUA MANFREDO MEYER - 29_12_20 - PHANTOM 4 - BO...       None
# 42  RUA ARCO-ÍRIS - 29_12_20 - MAVIC - BOTUJURU - ...       None
# 43  RUA MANGUE SECO - 29_12_20 - PHANTOM 4 - BOTUJ...       None
# 44  RUA MARLI BEZARRA DA SILVA - 29_12_20 - MAVIC ...       None
# 45  RUA JOSE D'ANGELO - 28 _12_20 - PASTA ÚNICA - ...       None
# 46  RUA LAGUNA - 29_12_20 - MAVIC - BOTUJURU - ETA...       None
# 47  RUA STRAUSS - 29_12_20 - MAVIC - BOTUJURU - ET...       None
# 48  RUA DANÚBIO AZUL - 29_12_20 - MAVIC - BOTUJURU...       None
# 49  RUA CHOPIN - 29_12_20 - MAVIC - BOTUJURU - ETA...       None
# 50  RUA ALIANÇAS - 29_12_20 - MAVIC - BOTUJURU - E...       None
# 51  RUA JOÃO INÁCIO DA SILVA - 29_12_20 - MAVIC - ...       None
# 52  AVENIDA NICOLA DEMARCHI - 29_12_20 - MAVIC - B...       None
# 53  RUA HUMAITÁ - 29_12_20 - PHANTOM 4 - BOTUJURU ...       None
# 54  RUA NOVO ORIENTE - 29_12_20 - PHANTOM 4 - BOTU...       None
# 55  RUA O - TRES - 29_12_20 - PHANTOM 4 - BOTUJURU...       None
#
#                    SubClasses    Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline  Continuous           6F  None
# 1   AcDbEntity:AcDb2dPolyline  Continuous           74  None
# 2   AcDbEntity:AcDb2dPolyline  Continuous           79  None
# 3   AcDbEntity:AcDb2dPolyline  Continuous           7E  None
# 4   AcDbEntity:AcDb2dPolyline  Continuous           87  None
# 5   AcDbEntity:AcDb2dPolyline  Continuous           8E  None
# 6   AcDbEntity:AcDb2dPolyline  Continuous           93  None
# 7   AcDbEntity:AcDb2dPolyline  Continuous           98  None
# 8   AcDbEntity:AcDb2dPolyline  Continuous           9D  None
# 9   AcDbEntity:AcDb2dPolyline  Continuous           A2  None
# 10  AcDbEntity:AcDb2dPolyline  Continuous           A7  None
# 11  AcDbEntity:AcDb2dPolyline  Continuous           AC  None
# 12  AcDbEntity:AcDb2dPolyline  Continuous           B1  None
# 13  AcDbEntity:AcDb2dPolyline  Continuous           B6  None
# 14  AcDbEntity:AcDb2dPolyline  Continuous           BD  None
# 15  AcDbEntity:AcDb2dPolyline  Continuous           C4  None
# 16  AcDbEntity:AcDb2dPolyline  Continuous           CA  None
# 17  AcDbEntity:AcDb2dPolyline  Continuous           D2  None
# 18  AcDbEntity:AcDb2dPolyline  Continuous           E1  None
# 19  AcDbEntity:AcDb2dPolyline  Continuous          101  None
# 20  AcDbEntity:AcDb2dPolyline  Continuous          106  None
# 21  AcDbEntity:AcDb2dPolyline  Continuous          115  None
# 22  AcDbEntity:AcDb2dPolyline  Continuous          11C  None
# 23  AcDbEntity:AcDb2dPolyline  Continuous          121  None
# 24  AcDbEntity:AcDb2dPolyline  Continuous          126  None
# 25  AcDbEntity:AcDb2dPolyline  Continuous          12B  None
# 26  AcDbEntity:AcDb2dPolyline  Continuous          130  None
# 27  AcDbEntity:AcDb2dPolyline  Continuous          135  None
# 28  AcDbEntity:AcDb2dPolyline  Continuous          13B  None
# 29  AcDbEntity:AcDb2dPolyline  Continuous          140  None
# 30  AcDbEntity:AcDb2dPolyline  Continuous          147  None
# 31  AcDbEntity:AcDb2dPolyline  Continuous          14E  None
# 32  AcDbEntity:AcDb2dPolyline  Continuous          153  None
# 33  AcDbEntity:AcDb2dPolyline  Continuous          15A  None
# 34  AcDbEntity:AcDb2dPolyline        None          15F  None
# 35  AcDbEntity:AcDb2dPolyline        None          164  None
# 36  AcDbEntity:AcDb2dPolyline        None          169  None
# 37  AcDbEntity:AcDb2dPolyline        None          16E  None
# 38  AcDbEntity:AcDb2dPolyline  Continuous          17E  None
# 39  AcDbEntity:AcDb2dPolyline  Continuous          183  None
# 40  AcDbEntity:AcDb2dPolyline  Continuous          188  None
# 41  AcDbEntity:AcDb2dPolyline  Continuous          18D  None
# 42  AcDbEntity:AcDb2dPolyline        None          193  None
# 43  AcDbEntity:AcDb2dPolyline  Continuous          199  None
# 44  AcDbEntity:AcDb2dPolyline        None          1A9  None
# 45  AcDbEntity:AcDb2dPolyline        None          1B9  None
# 46  AcDbEntity:AcDb2dPolyline  Continuous          1C4  None
# 47  AcDbEntity:AcDb2dPolyline  Continuous          1C9  None
# 48  AcDbEntity:AcDb2dPolyline  Continuous          1CF  None
# 49  AcDbEntity:AcDb2dPolyline  Continuous          1D5  None
# 50  AcDbEntity:AcDb2dPolyline  Continuous          1DA  None
# 51  AcDbEntity:AcDb2dPolyline        None          1E0  None
# 52  AcDbEntity:AcDb2dPolyline        None          1E7  None
# 53  AcDbEntity:AcDb2dPolyline  Continuous          1FE  None
# 54  AcDbEntity:AcDb2dPolyline  Continuous          20B  None
# 55  AcDbEntity:AcDb2dPolyline  Continuous          211  None
#
#                                              geometry  \
# 0   LINESTRING Z (341368.327 7372393.122 0.000, 34...
# 1   LINESTRING Z (341322.241 7372404.494 0.000, 34...
# 2   LINESTRING Z (341317.430 7372368.288 0.000, 34...
# 3   LINESTRING Z (341302.061 7372328.401 0.000, 34...
# 4   LINESTRING Z (341386.043 7372311.169 0.000, 34...
# 5   LINESTRING Z (341391.558 7372342.929 0.000, 34...
# 6   LINESTRING Z (341359.840 7372351.483 0.000, 34...
# 7   LINESTRING Z (341383.958 7372299.164 0.000, 34...
# 8   LINESTRING Z (341485.853 7372291.353 0.000, 34...
# 9   LINESTRING Z (341547.301 7372273.094 0.000, 34...
# 0   [RUA JOSÉ CARLOS DO NASCIMENTO, 29_12_20, MAVI...            [DJI_0071]
# 1   [TRAVESSA ESTRELA DE PRATA, 29_12_20, MAVIC, B...            [DJI_0045]
# 2   [TRAVESSA CAMÉLIA BRANCA, 29_12_20, MAVIC, BOT...            [DJI_0044]
# 3   [RUA PRIMAVERA, 29_12_20, MAVIC, BOTUJURU, ETA...            [DJI_0041]
# 4   [TRAVESSA GARANHUNS, 29_12_20, PHANTOM 4, BOTU...            [DJI_0007]
# 5   [RUA POPULAR, 29_12_20, MAVIC, BOTUJURU, ETAPA...            [DJI_0042]
# 6   [TRAVESSA BELA, 29_12_20, MAVIC, BOTUJURU, ETA...            [DJI_0043]
# 7   [RUA YANOMAMI, 29_12_20, MAVIC, BOTUJURU, ETAP...            [DJI_0041]
# 8   [AVENIDA IVANOVSKY, 29_12_20, MAVIC, BOTUJURU,...            [DJI_0069]
# 9   [RUA MUCUGEO, 29_12_20, MAVIC, BOTUJURU, ETAPA...            [DJI_0071]
# 10  [RUA SINFONIA, 29_12_20 -MAVIC, BOTUJURU, ETAP...            [DJI_0073]
# 11  [RUA DEBÉLIS, 29_12_20, MAVIC, BOTUJURU, ETAPA...            [DJI_0070]
# 12  [RUA FOLHAS DA MANHÃ, 29_12_20, MAVIC, BOTUJUR...            [DJI_0072]
# 13  [RUA VALSA DO IMPERADOR, 29_12_20, MAVIC, BOTU...            [DJI_0075]
# 14  [RUA DO TESOURO, 29_12_20, MAVIC, BOTUJURU, ET...            [DJI_0079]
# 15  [RUA COPÉLIA, 29_12_20, MAVIC, BOTUJURU, ETAPA...            [DJI_0076]
# 16  [RUA EFRAIM RAMOS DA SILVA -29_12_20, MAVIC, B...            [DJI_0051]
# 17  [AVENIDA MANAUS, 29_12_20, PHANTOM 4, BOTUJURU...            [DJI_0014]
# 18  [RUA JURUBEBA, 29_12_20, PHANTOM 4, BOTUJURU, ...            [DJI_0013]
# 19  [RUA CUNHA, 29_12_20, PHANTOM 4, BOTUJURU, DJI...            [DJI_0015]
# 20  [RUA 2 DE DEZEMBRO, 29_12_20, PHANTOM 4, BOTUJ...            [DJI_0016]
# 21  [RUA TARUMÃ, 29_12_20, PHANTOM 4, BOTUJURU, DJ...            [DJI_0021]
# 22  [RUA ANÉSIO SIQUEIRA LIMA, 29_12_20, PHANTOM 4...            [DJI_0022]
# 23                                  [TRAVESSA FROMER]                    []
# 24  [TRAVESSA RACHEL DE QUEIROZ, 29_12_20, MAVIC, ...            [DJI_0049]
# 25                                [TRAVESSA CAMAÇARI]                    []
# 26  [TRAVESSA IDEAL, 29_12_20, MAVIC, BOTUJURU, ET...            [DJI_0050]
# 27  [TRAVESSA ANITA MARIA DOS SANTOS, 29_12_20, MA...            [DJI_0048]
# 28  [TRAVESSA BELA DONA, 29_12_20, MAVIC, BOTUJURU...            [DJI_0057]
# 29  [TRAVESSA TEREZINHA LIMA, 29_12_20, MAVIC, BOT...            [DJI_0056]
# 30  [TRAVESSA MANOEL DE OLIVEIRA, 29_12_20, MAVIC,...            [DJI_0059]
# 31  [RUA UNIÃO, 29 _12_20, MAVIC, BOTUJURU, ETAPA ...            [DJI_0058]
# 32  [TRAVESSA SOBRAL, 29_12_20, MAVIC, BOTUJURU, E...            [DJI_0060]
# 33  [TRAVESSA RECANTO DO SOL, 29_12_20, MAVIC, BOT...            [DJI_0061]
# 34  [AVENIDA BEETHOVEN, 29_12_20, MAVIC, BOTUJURU,...            [DJI_0066]
# 35  [RUA VALSA DE VIENA, 29_12_20, MAVIC, BOTUJURU...            [DJI_0075]
# 36  [RUA BODAS DE PRATA, 29_12_20, MAVIC, BOTUJURU...            [DJI_0067]
# 37  [ESTRADA DO VERGUEIRO, 29_12_20, PHANTOM 4, BO...            [DJI_0011]
# 38  [RUA FELIPE MACEDO PONTES, 29_12_20, MAVIC, BO...            [DJI_0055]
# 39  [RUA ARCO VERDE, 29_12_20 _ MAVIC, BOTUJURU, E...            [DJI_0054]
# 40                                 [TRAVESSA GRAVATÁ]                    []
# 41  [RUA MANFREDO MEYER, 29_12_20, PHANTOM 4, BOTU...            [DJI_0020]
# 42  [RUA ARCO-ÍRIS, 29_12_20, MAVIC, BOTUJURU, ETA...            [DJI_0047]
# 43  [RUA MANGUE SECO, 29_12_20, PHANTOM 4, BOTUJUR...            [DJI_0018]
# 44  [RUA MARLI BEZARRA DA SILVA, 29_12_20, MAVIC, ...  [DJI_0063, DJI_0064]
# 45  [RUA JOSE D'ANGELO, 28 _12_20, PASTA ÚNICA, DJ...            [DJI_0005]
# 46  [RUA LAGUNA, 29_12_20, MAVIC, BOTUJURU, ETAPA ...            [DJI_0077]
# 47  [RUA STRAUSS, 29_12_20, MAVIC, BOTUJURU, ETAPA...            [DJI_0078]
# 48  [RUA DANÚBIO AZUL, 29_12_20, MAVIC, BOTUJURU, ...            [DJI_0081]
# 49  [RUA CHOPIN, 29_12_20, MAVIC, BOTUJURU, ETAPA ...            [DJI_0080]
# 50  [RUA ALIANÇAS, 29_12_20, MAVIC, BOTUJURU, ETAP...            [DJI_0062]
# 51  [RUA JOÃO INÁCIO DA SILVA, 29_12_20, MAVIC, BO...            [DJI_0052]
# 52  [AVENIDA NICOLA DEMARCHI, 29_12_20, MAVIC, BOT...            [DJI_0065]
# 53  [RUA HUMAITÁ, 29_12_20, PHANTOM 4, BOTUJURU, D...            [DJI_0012]
# 54  [RUA NOVO ORIENTE, 29_12_20, PHANTOM 4, BOTUJU...            [DJI_0017]
# 55  [RUA O, TRES, 29_12_20, PHANTOM 4, BOTUJURU, D...            [DJI_0019]
#
#        etapa  data_voo                           logradouro
# 0   ETAPA 01  29_12_20        RUA JOSÉ CARLOS DO NASCIMENTO
# 1   ETAPA 01  29_12_20            TRAVESSA ESTRELA DE PRATA
# 2   ETAPA 01  29_12_20              TRAVESSA CAMÉLIA BRANCA
# 3   ETAPA 01  29_12_20                        RUA PRIMAVERA
# 4        NaN  29_12_20                   TRAVESSA GARANHUNS
# 5   ETAPA 01  29_12_20                          RUA POPULAR
# 53       NaN  29_12_20                          RUA HUMAITÁ
# 54       NaN  29_12_20                     RUA NOVO ORIENTE
# 55       NaN  29_12_20                                RUA O

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#          Video_0       Video_1
# 0   DJI_0071.MOV          None
# 1   DJI_0045.MOV          None
# 2   DJI_0044.MOV          None
# 3   DJI_0041.MOV          None
# 4   DJI_0007.MOV          None
# 5   DJI_0042.MOV          None
# 6   DJI_0043.MOV          None
# 7   DJI_0041.MOV          None
# 8   DJI_0069.MOV          None
# 9   DJI_0071.MOV          None
# 10  DJI_0073.MOV          None
# 11  DJI_0070.MOV          None
# 12  DJI_0072.MOV          None
# 13  DJI_0075.MOV          None
# 14  DJI_0079.MOV          None
# 15  DJI_0076.MOV          None
# 16  DJI_0051.MOV          None
# 17  DJI_0014.MOV          None
# 18  DJI_0013.MOV          None
# 19  DJI_0015.MOV          None
# 20  DJI_0016.MOV          None
# 21  DJI_0021.MOV          None
# 22  DJI_0022.MOV          None
# 23          None          None
# 24  DJI_0049.MOV          None
# 25          None          None
# 26  DJI_0050.MOV          None
# 27  DJI_0048.MOV          None
# 28  DJI_0057.MOV          None
# 29  DJI_0056.MOV          None
# 30  DJI_0059.MOV          None
# 31  DJI_0058.MOV          None
# 32  DJI_0060.MOV          None
# 33  DJI_0061.MOV          None
# 34  DJI_0066.MOV          None
# 35  DJI_0075.MOV          None
# 36  DJI_0067.MOV          None
# 37  DJI_0011.MOV          None
# 38  DJI_0055.MOV          None
# 39  DJI_0054.MOV          None
# 40          None          None
# 41  DJI_0020.MOV          None
# 42  DJI_0047.MOV          None
# 43  DJI_0018.MOV          None
# 44  DJI_0063.MOV  DJI_0064.MOV
# 45  DJI_0005.MOV          None
# 46  DJI_0077.MOV          None
# 47  DJI_0078.MOV          None
# 48  DJI_0081.MOV          None
# 49  DJI_0080.MOV          None
# 50  DJI_0062.MOV          None
# 51  DJI_0052.MOV          None
# 52  DJI_0065.MOV          None
# 53  DJI_0012.MOV          None
# 54  DJI_0017.MOV          None
# 55  DJI_0019.MOV          None

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'etapa', 'data_voo', 'logradouro',
#        'Video_0', 'Video_1'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + gdf_dxf.data_voo + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                                Layer  \
# 0            AVENIDA BALNEÁRIA - 29_12_20 - DJI_0032
# 1  ESTRADA MARTIM AFONSO DE SOUZA - 29_12_20 - DJ...
# 2  RUA JOHAN DE ALCÂNTARA SILVA - 29_12_20 - DJI_...
# 3                  RUA MUTUÍPE - 29_12_20 - DJI_0030
#
#                                             geometry PaperSpace  \
# 0  LINESTRING Z (342823.761 7370822.653 0.000, 34...       None
# 1  LINESTRING Z (342021.277 7369702.265 0.000, 34...       None
# 2  LINESTRING Z (342729.170 7370805.590 0.000, 34...       None
# 3  LINESTRING Z (342065.913 7370104.198 0.000, 34...       None
#
#                   SubClasses Linetype EntityHandle  Text  \
# 0  AcDbEntity:AcDb2dPolyline     None           6F  None
# 1  AcDbEntity:AcDb2dPolyline     None           F5  None
# 2  AcDbEntity:AcDb2dPolyline     None           74  None
# 3  AcDbEntity:AcDb2dPolyline     None           F0  None
#
#                                                lista                   DJI  \
# 0            [AVENIDA BALNEÁRIA, 29_12_20, DJI_0032]            [DJI_0032]
# 1  [ESTRADA MARTIM AFONSO DE SOUZA, 29_12_20, DJI...  [DJI_0028, DJI_0029]
# 2  [RUA JOHAN DE ALCÂNTARA SILVA, 29_12_20, DJI_0...            [DJI_0031]
# 3                  [RUA MUTUÍPE, 29_12_20, DJI_0030]            [DJI_0030]
#
#   etapa   data_voo                      logradouro       Video_0  \
# 0        29_12_20/               AVENIDA BALNEÁRIA  DJI_0032.MOV
# 1        29_12_20/  ESTRADA MARTIM AFONSO DE SOUZA  DJI_0028.MOV
# 2        29_12_20/    RUA JOHAN DE ALCÂNTARA SILVA  DJI_0031.MOV
# 3        29_12_20/                     RUA MUTUÍPE  DJI_0030.MOV
#
#         Video_1                  Video_0_path                  Video_1_path
# 0          None  videos/29_12_20/DJI_0032.MOV                           NaN
# 1  DJI_0029.MOV  videos/29_12_20/DJI_0028.MOV  videos/29_12_20/DJI_0029.MOV
# 2          None  videos/29_12_20/DJI_0031.MOV                           NaN
# 3          None  videos/29_12_20/DJI_0030.MOV                           NaN

# %%
gdf_dxf.Layer
# Out:
# 0              AVENIDA BALNEÁRIA - 29_12_20 - DJI_0032
# 1    ESTRADA MARTIM AFONSO DE SOUZA - 29_12_20 - DJ...
# 2    RUA JOHAN DE ALCÂNTARA SILVA - 29_12_20 - DJI_...
# 3                    RUA MUTUÍPE - 29_12_20 - DJI_0030
# Name: Layer, dtype: object

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB.gpkg', driver='GPKG')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# etapa             object
# data_voo          object
# logradouro        object
# Video_0           object
# Video_1           object
# Video_2           object
# Video_3           object
# Video_0_path      object
# Video_1_path      object
# Video_2_path      object
# Video_3_path      object
# dtype: object
