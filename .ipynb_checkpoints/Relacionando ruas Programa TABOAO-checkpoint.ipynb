# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/FERRAZOPOLIS-MONTANHAO - PROSABS.dxf', encoding='ANSI_1252')

# %%
bairro = 'FERRAZOPOLIS-MONTANHAO'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                  Layer PaperSpace  \
# 0            RUA 21 DE ABRIL - 08_01_2021 - FERMOM_204       None
# 1                 RUA MONTE DAS OLIVEIRAS - FERMOM_199       None
# 2          RUA ALTO DA BELA VISTA - 21_01_2021 - MON09       None
# 3      PASSAGEM SANTO ANTONIO - 07_01_2021 - FERMOM_82       None
# 4       PASSAGEM LUIZ GONZAGA - 07_01_2021 - FERMOM_88       None
# ..                                                 ...        ...
# 229          RUA ELOI BORGES - 08_01_2021 - FERMOM_139       None
# 230  RUA VICENTE PASCHOALETTI - 07_01_2021 - FERMOM...       None
# 231  RUA GENIVAL FRANCISCO DA SILVA - 08_01_2021 - ...       None
# 232  RUA JOSÃ ALVES DA SILVA - 08_01_2021 - FERMOM...       None
# 233  RUA LUIZ CUSTÃDIO TIAGO - 08_01_2021 - FERMOM...       None
#
#                     SubClasses Linetype EntityHandle  Text  \
# 0    AcDbEntity:AcDb2dPolyline  ByBlock           6F  None
# 1    AcDbEntity:AcDb2dPolyline  ByBlock           79  None
# 2    AcDbEntity:AcDb2dPolyline  ByBlock           7F  None
# 3    AcDbEntity:AcDb2dPolyline  ByBlock           8A  None
# 4    AcDbEntity:AcDb2dPolyline  ByBlock           91  None
# ..                         ...      ...          ...   ...
# 229  AcDbEntity:AcDb2dPolyline  ByBlock          989  None
# 230  AcDbEntity:AcDb2dPolyline  ByBlock          98E  None
# 231  AcDbEntity:AcDb2dPolyline  ByBlock          999  None
# 232  AcDbEntity:AcDb2dPolyline  ByBlock          9A0  None
# 233  AcDbEntity:AcDb2dPolyline  ByBlock          9A5  None
#
#                                               geometry
# 0    LINESTRING Z (345101.345 7376069.317 0.000, 34...
# 1    LINESTRING Z (344843.032 7376194.570 0.000, 34...
# 2    LINESTRING Z (345021.110 7376313.351 0.000, 34...
# 3    LINESTRING Z (344540.290 7376989.987 0.000, 34...
# 4    LINESTRING Z (344331.718 7376698.640 0.000, 34...
# ..                                                 ...
# 229  LINESTRING Z (343681.483 7374510.715 0.000, 34...
# 230  LINESTRING Z (343621.835 7374474.660 0.000, 34...
# 231  LINESTRING Z (343981.972 7374032.712 0.000, 34...
# 232  LINESTRING Z (344035.289 7374222.113 0.000, 34...
# 233  LINESTRING Z (343971.600 7374396.982 0.000, 34...
#
# [234 rows x 7 columns]

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
# gdf_dxf.Layer.to_list()

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('!', '1')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('FERMOM_[0-9]{1,4}|MON[0-9]{2}')

# %%
gdf_dxf.DJI
# Out:
# 0      [FERMOM_204]
# 1      [FERMOM_199]
# 2           [MON09]
# 3       [FERMOM_82]
# 4       [FERMOM_88]
#            ...
# 229    [FERMOM_139]
# 230    [FERMOM_132]
# 231    [FERMOM_187]
# 232    [FERMOM_174]
# 233    [FERMOM_185]
# Name: DJI, Length: 234, dtype: object

# %%
# gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer'].to_list()
# Out:
# ['RUA MONTE DAS OLIVEIRAS - FERMOM_199',
#  ' RUA VASCO DA GAMA',
#  ' RUA VINTE E NOVE DE JULHO',
#  ' RUA DR. AFONSO PENA JÚNIOR',
#  ' RUA GREGÓRIO VITÓRIO MORASSI',
#  ' AVENIDA DA INVERNADA',
#  ' RUA FELICINA',
#  ' RUA HIDORO CUSTODIO',
#  ' RUA NOVO HORIZONTE',
#  ' RUA QUINZE DE NOVEMBRO',
#  ' RUA CINCO DE OUTUBRO',
#  'RUA MONTE DAS OLIVEIRAS - FERMOM_199',
#  ' RUA SAMUEL RÉIS DE OLIVEIRA',
#  ' RUA BÉLEM',
#  ' RUA ALMEIDA LEME',
#  ' RUA PIRATININGA',
#  ' RUA PRIMAVERIL',
#  ' RUA MARIA JOSÉ DA SILVA',
#  ' RUA DAS ZÍNIAS FILHO',
#  ' RUA DÁCIO ÁGUIAR DE MORÃES',
#  ' RUA MARIA JOSÉ DA SILVA',
#  ' RUA PETROLINA',
#  ' JOSÉ ARTHUR DA FROTA MOREIRA',
#  'RUA MIN. BARROS MONTEIRO - FERMOM_8',
#  ' RUA JERONIMO DE ATAÍDE',
#  ' TV. CANTAREIRA',
#  ' RUA COMANDANTE ELIAS JAFETE',
#  '  RUA PADRE LÉO COMISSARI',
#  '  TV. JOÃO AUGUSTO BECKER',
#  ' PASSAGEM JESUS DE NAZARÉ',
#  'RUA JESUS DE NAZARETH  - FERMOM_64',
#  '  PRAÇA CONSELHEIRO SARAIVA',
#  ' VIELA C',
#  ' VIELA B']

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(FERMOM_[0-9]{1,4}|MON[0-9]{2})', expand=True)
# Out:
#                                      0         1           2      3     4  \
# 0                   RUA 21 DE ABRIL -   08_01_20        None  21 -   None
# 1           RUA MONTE DAS OLIVEIRAS -       None  FERMOM_199         None
# 2            RUA ALTO DA BELA VISTA -   21_01_20        None  21 -   None
# 3            PASSAGEM SANTO ANTONIO -   07_01_20        None  21 -   None
# 4             PASSAGEM LUIZ GONZAGA -   07_01_20        None  21 -   None
# ..                                 ...       ...         ...    ...   ...
# 229                 RUA ELOI BORGES -   08_01_20        None  21 -   None
# 230        RUA VICENTE PASCHOALETTI -   07_01_20        None  21 -   None
# 231  RUA GENIVAL FRANCISCO DA SILVA -   08_01_20        None  21 -   None
# 232         RUA JOSÉ ALVES DA SILVA -   08_01_20        None  21 -   None
# 233         RUA LUIZ CUSTÓDIO TIAGO -   08_01_20        None  21 -   None
#
#               5     6     7     8     9
# 0    FERMOM_204        None  None  None
# 1          None  None  None  None  None
# 2         MON09        None  None  None
# 3     FERMOM_82        None  None  None
# 4     FERMOM_88        None  None  None
# ..          ...   ...   ...   ...   ...
# 229  FERMOM_139        None  None  None
# 230  FERMOM_132        None  None  None
# 231  FERMOM_187        None  None  None
# 232  FERMOM_174        None  None  None
# 233  FERMOM_185        None  None  None
#
# [234 rows x 10 columns]

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(FERMOM_[0-9]{1,4}|MON[0-9]{2})', expand=True)[3].unique().tolist()
# Out:
# ['21 - ', '', None, '21- ', '21 -']

# %%
etapas = {
    '21 - ':'etapa_00', 
    '':'etapa_00',
    '21- ':'etapa_00',
    '21 -':'etapa_00'
}

# %%
len(etapas)
# Out:
# 4

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(FERMOM_[0-9]{1,4})', expand=True)[3].map(etapas)
# Out:
# 0      etapa_00
# 1      etapa_00
# 2           NaN
# 3      etapa_00
# 4      etapa_00
#          ...
# 229    etapa_00
# 230    etapa_00
# 231    etapa_00
# 232    etapa_00
# 233    etapa_00
# Name: 3, Length: 234, dtype: object

# %%
gdf_dxf.loc[:, 'etapa'] = gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(FERMOM_[0-9]{1,4})|MON[0-9]{2}', expand=True)[3].map(etapas)

# %%
gdf_dxf.loc[:, 'etapa']
# Out:
# 0      etapa_00
# 1      etapa_00
# 2      etapa_00
# 3      etapa_00
# 4      etapa_00
#          ...
# 229    etapa_00
# 230    etapa_00
# 231    etapa_00
# 232    etapa_00
# 233    etapa_00
# Name: etapa, Length: 234, dtype: object

# %%
gdf_dxf
# Out:
#                                                  Layer PaperSpace  \
# 0            RUA 21 DE ABRIL - 08_01_2021 - FERMOM_204       None
# 1                 RUA MONTE DAS OLIVEIRAS - FERMOM_199       None
# 2          RUA ALTO DA BELA VISTA - 21_01_2021 - MON09       None
# 3      PASSAGEM SANTO ANTONIO - 07_01_2021 - FERMOM_82       None
# 4       PASSAGEM LUIZ GONZAGA - 07_01_2021 - FERMOM_88       None
# ..                                                 ...        ...
# 229          RUA ELOI BORGES - 08_01_2021 - FERMOM_139       None
# 230  RUA VICENTE PASCHOALETTI - 07_01_2021 - FERMOM...       None
# 231  RUA GENIVAL FRANCISCO DA SILVA - 08_01_2021 - ...       None
# 232  RUA JOSÉ ALVES DA SILVA - 08_01_2021 - FERMOM_174       None
# 233  RUA LUIZ CUSTÓDIO TIAGO - 08_01_2021 - FERMOM_185       None
#
#                     SubClasses Linetype EntityHandle  Text  \
# 0    AcDbEntity:AcDb2dPolyline  ByBlock           6F  None
# 1    AcDbEntity:AcDb2dPolyline  ByBlock           79  None
# 2    AcDbEntity:AcDb2dPolyline  ByBlock           7F  None
# 3    AcDbEntity:AcDb2dPolyline  ByBlock           8A  None
# 4    AcDbEntity:AcDb2dPolyline  ByBlock           91  None
# ..                         ...      ...          ...   ...
# 229  AcDbEntity:AcDb2dPolyline  ByBlock          989  None
# 230  AcDbEntity:AcDb2dPolyline  ByBlock          98E  None
# 231  AcDbEntity:AcDb2dPolyline  ByBlock          999  None
# 232  AcDbEntity:AcDb2dPolyline  ByBlock          9A0  None
# 233  AcDbEntity:AcDb2dPolyline  ByBlock          9A5  None
#
#                                               geometry  \
# 0    LINESTRING Z (345101.345 7376069.317 0.000, 34...
# 1    LINESTRING Z (344843.032 7376194.570 0.000, 34...
# 2    LINESTRING Z (345021.110 7376313.351 0.000, 34...
# 3    LINESTRING Z (344540.290 7376989.987 0.000, 34...
# 4    LINESTRING Z (344331.718 7376698.640 0.000, 34...
# ..                                                 ...
# 229  LINESTRING Z (343681.483 7374510.715 0.000, 34...
# 230  LINESTRING Z (343621.835 7374474.660 0.000, 34...
# 231  LINESTRING Z (343981.972 7374032.712 0.000, 34...
# 232  LINESTRING Z (344035.289 7374222.113 0.000, 34...
# 233  LINESTRING Z (343971.600 7374396.982 0.000, 34...
#
#                                                  lista           DJI  \
# 0            [RUA 21 DE ABRIL, 08_01_2021, FERMOM_204]  [FERMOM_204]
# 1                [RUA MONTE DAS OLIVEIRAS, FERMOM_199]  [FERMOM_199]
# 2          [RUA ALTO DA BELA VISTA, 21_01_2021, MON09]       [MON09]
# 3      [PASSAGEM SANTO ANTONIO, 07_01_2021, FERMOM_82]   [FERMOM_82]
# 4       [PASSAGEM LUIZ GONZAGA, 07_01_2021, FERMOM_88]   [FERMOM_88]
# ..                                                 ...           ...
# 229          [RUA ELOI BORGES, 08_01_2021, FERMOM_139]  [FERMOM_139]
# 230  [RUA VICENTE PASCHOALETTI, 07_01_2021, FERMOM_...  [FERMOM_132]
# 231  [RUA GENIVAL FRANCISCO DA SILVA, 08_01_2021, F...  [FERMOM_187]
# 232  [RUA JOSÉ ALVES DA SILVA, 08_01_2021, FERMOM_174]  [FERMOM_174]
# 233  [RUA LUIZ CUSTÓDIO TIAGO, 08_01_2021, FERMOM_185]  [FERMOM_185]
#
#      data_voo                      logradouro     etapa
# 0    08_01_20                 RUA 21 DE ABRIL  etapa_00
# 1         NaN         RUA MONTE DAS OLIVEIRAS  etapa_00
# 2    21_01_20          RUA ALTO DA BELA VISTA  etapa_00
# 3    07_01_20          PASSAGEM SANTO ANTONIO  etapa_00
# 4    07_01_20           PASSAGEM LUIZ GONZAGA  etapa_00
# ..        ...                             ...       ...
# 229  08_01_20                 RUA ELOI BORGES  etapa_00
# 230  07_01_20        RUA VICENTE PASCHOALETTI  etapa_00
# 231  08_01_20  RUA GENIVAL FRANCISCO DA SILVA  etapa_00
# 232  08_01_20         RUA JOSÉ ALVES DA SILVA  etapa_00
# 233  08_01_20         RUA LUIZ CUSTÓDIO TIAGO  etapa_00
#
# [234 rows x 12 columns]

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#             Video_0 Video_1
# 0    FERMOM_204.MOV    None
# 1    FERMOM_199.MOV    None
# 2         MON09.MOV    None
# 3     FERMOM_82.MOV    None
# 4     FERMOM_88.MOV    None
# ..              ...     ...
# 229  FERMOM_139.MOV    None
# 230  FERMOM_132.MOV    None
# 231  FERMOM_187.MOV    None
# 232  FERMOM_174.MOV    None
# 233  FERMOM_185.MOV    None
#
# [234 rows x 2 columns]

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'data_voo', 'logradouro', 'etapa',
#        'Video_0', 'Video_1'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + bairro.lower().replace('-', '_') + '/' + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                         Layer  \
# 0                   PRAÇA CONSELHEIRO SARAIVA
# 1                     RUA PADRE LÉO COMISSARI
# 2                     TV. JOÃO AUGUSTO BECKER
# 3                        AVENIDA DA INVERNADA
# 4                JOSÉ ARTHUR DA FROTA MOREIRA
# ..                                        ...
# 200  TV. VIODA NOVA - 07_01_2021 - FERMOM_123
# 201             VIELA 20 - 21_01_2021 - MON16
# 202        VIELA 2A - 07_01_2021 - FERMOM_122
# 203         VIELA 3 - 07_01_2021 - FERMOM_121
# 204     VIELA TREZE - 08_01_2021 - FERMOM_215
#
#                                               geometry PaperSpace  \
# 0    LINESTRING Z (343399.537 7373661.141 0.000, 34...       None
# 1    LINESTRING Z (343223.842 7374203.995 0.000, 34...       None
# 2    LINESTRING Z (342978.304 7373882.081 0.000, 34...       None
# 3    LINESTRING Z (343210.407 7373661.166 0.000, 34...       None
# 4    LINESTRING Z (342344.808 7375229.735 0.000, 34...       None
# ..                                                 ...        ...
# 200  LINESTRING Z (342865.831 7374092.746 0.000, 34...       None
# 201  LINESTRING Z (344840.223 7377007.224 0.000, 34...       None
# 202  LINESTRING Z (342895.366 7374195.576 0.000, 34...       None
# 203  LINESTRING Z (342907.559 7374289.031 0.000, 34...       None
# 204  LINESTRING Z (344740.357 7373987.292 0.000, 34...       None
#
#                     SubClasses Linetype EntityHandle  Text  \
# 0    AcDbEntity:AcDb2dPolyline  ByBlock          8A4  None
# 1    AcDbEntity:AcDb2dPolyline  ByBlock          694  None
# 2    AcDbEntity:AcDb2dPolyline  ByBlock          6CD  None
# 3    AcDbEntity:AcDb2dPolyline  ByBlock          28A  None
# 4    AcDbEntity:AcDb2dPolyline  ByBlock          5AC  None
# ..                         ...      ...          ...   ...
# 200  AcDbEntity:AcDb2dPolyline  ByBlock          277  None
# 201  AcDbEntity:AcDb2dPolyline  ByBlock          3F4  None
# 202  AcDbEntity:AcDb2dPolyline  ByBlock          739  None
# 203  AcDbEntity:AcDb2dPolyline  ByBlock          734  None
# 204  AcDbEntity:AcDb2dPolyline  ByBlock          938  None
#
#                                         lista           DJI   data_voo  \
# 0               [  PRAÇA CONSELHEIRO SARAIVA]            []       None
# 1                 [  RUA PADRE LÉO COMISSARI]            []       None
# 2                 [  TV. JOÃO AUGUSTO BECKER]            []       None
# 3                     [ AVENIDA DA INVERNADA]            []       None
# 4             [ JOSÉ ARTHUR DA FROTA MOREIRA]            []       None
# ..                                        ...           ...        ...
# 200  [TV. VIODA NOVA, 07_01_2021, FERMOM_123]  [FERMOM_123]  07_01_20/
# 201             [VIELA 20, 21_01_2021, MON16]       [MON16]  21_01_20/
# 202        [VIELA 2A, 07_01_2021, FERMOM_122]  [FERMOM_122]  07_01_20/
# 203         [VIELA 3, 07_01_2021, FERMOM_121]  [FERMOM_121]  07_01_20/
# 204     [VIELA TREZE, 08_01_2021, FERMOM_215]  [FERMOM_215]  08_01_20/
#
#                         logradouro      etapa         Video_0 Video_1  \
# 0        PRAÇA CONSELHEIRO SARAIVA                       None    None
# 1          RUA PADRE LÉO COMISSARI                       None    None
# 2          TV. JOÃO AUGUSTO BECKER                       None    None
# 3             AVENIDA DA INVERNADA                       None    None
# 4     JOSÉ ARTHUR DA FROTA MOREIRA                       None    None
# ..                             ...        ...             ...     ...
# 200                 TV. VIODA NOVA  etapa_00/  FERMOM_123.MOV    None
# 201                       VIELA 20  etapa_00/       MON16.MOV    None
# 202                       VIELA 2A  etapa_00/  FERMOM_122.MOV    None
# 203                        VIELA 3  etapa_00/  FERMOM_121.MOV    None
# 204                    VIELA TREZE  etapa_00/  FERMOM_215.MOV    None
#
#                                           Video_0_path Video_1_path
# 0                                                 None         None
# 1                                                 None         None
# 2                                                 None         None
# 3                                                 None         None
# 4                                                 None         None
# ..                                                 ...          ...
# 200  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
# 201   videos/ferrazopolis_montanhao/etapa_00/MON16.MOV         None
# 202  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
# 203  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
# 204  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
#
# [205 rows x 16 columns]

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1)
# Out:
#                                               geometry   data_voo  \
# 0    LINESTRING Z (343399.537 7373661.141 0.000, 34...       None
# 1    LINESTRING Z (343223.842 7374203.995 0.000, 34...       None
# 2    LINESTRING Z (342978.304 7373882.081 0.000, 34...       None
# 3    LINESTRING Z (343210.407 7373661.166 0.000, 34...       None
# 4    LINESTRING Z (342344.808 7375229.735 0.000, 34...       None
# ..                                                 ...        ...
# 200  LINESTRING Z (342865.831 7374092.746 0.000, 34...  07_01_20/
# 201  LINESTRING Z (344840.223 7377007.224 0.000, 34...  21_01_20/
# 202  LINESTRING Z (342895.366 7374195.576 0.000, 34...  07_01_20/
# 203  LINESTRING Z (342907.559 7374289.031 0.000, 34...  07_01_20/
# 204  LINESTRING Z (344740.357 7373987.292 0.000, 34...  08_01_20/
#
#                         logradouro      etapa         Video_0 Video_1  \
# 0        PRAÇA CONSELHEIRO SARAIVA                       None    None
# 1          RUA PADRE LÉO COMISSARI                       None    None
# 2          TV. JOÃO AUGUSTO BECKER                       None    None
# 3             AVENIDA DA INVERNADA                       None    None
# 4     JOSÉ ARTHUR DA FROTA MOREIRA                       None    None
# ..                             ...        ...             ...     ...
# 200                 TV. VIODA NOVA  etapa_00/  FERMOM_123.MOV    None
# 201                       VIELA 20  etapa_00/       MON16.MOV    None
# 202                       VIELA 2A  etapa_00/  FERMOM_122.MOV    None
# 203                        VIELA 3  etapa_00/  FERMOM_121.MOV    None
# 204                    VIELA TREZE  etapa_00/  FERMOM_215.MOV    None
#
#                                           Video_0_path Video_1_path
# 0                                                 None         None
# 1                                                 None         None
# 2                                                 None         None
# 3                                                 None         None
# 4                                                 None         None
# ..                                                 ...          ...
# 200  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
# 201   videos/ferrazopolis_montanhao/etapa_00/MON16.MOV         None
# 202  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
# 203  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
# 204  videos/ferrazopolis_montanhao/etapa_00/FERMOM_...         None
#
# [205 rows x 8 columns]

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'etapa', 'data_voo', 'Video_0', 'Video_1'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB.gpkg', driver='GPKG')

# %%
gdf_dxf.to_crs('EPSG:4326').drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista', 'etapa', 'data_voo', 'Video_0', 'Video_1'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB.geojson', driver='GeoJSON')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# data_voo          object
# logradouro        object
# etapa             object
# Video_0           object
# Video_1           object
# Video_0_path      object
# Video_1_path      object
# dtype: object

# %%
gdf_dxf.Video_0.isna().value_counts()
# Out:
# False    176
# True      29
# Name: Video_0, dtype: int64
