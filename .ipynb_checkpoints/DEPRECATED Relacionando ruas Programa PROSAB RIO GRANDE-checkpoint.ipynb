# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/RIO GRANDE.dxf', encoding='ANSI_1252')

# %%
bairro = 'RIO GRANDE'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0    AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003       None
# 1   RUA RIO ACIMA - 31_12_20 - PHANTOM - DJI_0009 ...       None
# 2   RUA ANTÃNIO CAPUTO - 31_12_20 - PHANTOM - DJI...       None
# 3   RUA ANTÃNIO CAPUTO - 31_12_20 - PHANTOM - DJI...       None
# 4   RUA JACIPORÃ - 31_12_20 - PHANTOM - DJI_0022 ...       None
# ..                                                ...        ...
# 94  ESTRADA SIMÃO PORTELA - 31_12_20 - PHANTOM - ...       None
# 95  RUA ÃNGELA GIANOTO - 31_12_20 - PHANTOM - DJI...       None
# 96  RUA AUGUSTO PAULINO - 31_12_20 - MAVIC - DJI_0171       None
# 97  RUA NOSSA SRA. DO CARMO - 31_12_20 - MAVIC - D...       None
# 98           RUA ROWENA - 31_12_20 - MAVIC - DJI_0168       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None          550  None
# 1   AcDbEntity:AcDb2dPolyline     None          55D  None
# 2   AcDbEntity:AcDb2dPolyline     None          562  None
# 3   AcDbEntity:AcDb2dPolyline     None          569  None
# 4   AcDbEntity:AcDb2dPolyline     None          580  None
# ..                        ...      ...          ...   ...
# 94    AcDbEntity:AcDbPolyline     None          A3A  None
# 95  AcDbEntity:AcDb2dPolyline     None          A3D  None
# 96  AcDbEntity:AcDb2dPolyline     None          A4D  None
# 97  AcDbEntity:AcDb2dPolyline     None          A58  None
# 98  AcDbEntity:AcDb2dPolyline     None          A5F  None
#
#                                              geometry
# 0   LINESTRING Z (344090.220 7369512.752 0.000, 34...
# 1   LINESTRING Z (343950.068 7369345.834 0.000, 34...
# 2   LINESTRING Z (343882.533 7369255.545 0.000, 34...
# 3   LINESTRING Z (344180.266 7369365.737 0.000, 34...
# 4   LINESTRING Z (344625.531 7368749.722 0.000, 34...
# ..                                                ...
# 94  LINESTRING (344635.432 7369571.680, 344644.737...
# 95  LINESTRING Z (343406.551 7369208.870 0.000, 34...
# 96  LINESTRING Z (343818.543 7369039.076 0.000, 34...
# 97  LINESTRING Z (344064.046 7369107.855 0.000, 34...
# 98  LINESTRING Z (344158.260 7369221.342 0.000, 34...
#
# [99 rows x 7 columns]

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
gdf_dxf.Layer.to_list()
# Out:
# ['AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003',
#  'RUA RIO ACIMA - 31_12_20 - PHANTOM - DJI_0009 - DJI_0010',
#  'RUA ANTÃ\x94NIO CAPUTO - 31_12_20 - PHANTOM - DJI_0008',
#  'RUA ANTÃ\x94NIO CAPUTO - 31_12_20 - PHANTOM - DJI_0008',
#  'RUA JACIPORÃ\x83 - 31_12_20 - PHANTOM - DJI_0022 - DJI_0019',
#  'AVENIDA AMAZONAS - 31_12_20 - PHANTOM - DJI_0001',
#  'AVENIDA DA PRAIA - 31_12_20  - PHANTOM - DJI_0007',
#  'AVENIDA DA PRAIA - 31_12_20  - PHANTOM - DJI_0007',
#  'AVENIDA IVAÃ\x8d  - 31_12_20 - PHANTOM - DJI_0004',
#  'AVENIDA IVAÃ\x8d  - 31_12_20 - PHANTOM - DJI_0004',
#  'AVENIDA IVAÃ\x8d  - 31_12_20 - PHANTOM - DJI_0004',
#  'AVENIDA IVAÃ\x8d  - 31_12_20 - PHANTOM - DJI_0004',
#  'AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003',
#  'AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003',
#  'AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003',
#  'AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003',
#  'AVENIDA TOCANTIS - 31_12_20 - PHANTOM - DJI_0002',
#  'AVENIDA TOCANTIS - 31_12_20 - PHANTOM - DJI_0002',
#  'AVENIDA TOCANTIS - 31_12_20 - PHANTOM - DJI_0002',
#  'AVENIDA TOCANTIS - 31_12_20 - PHANTOM - DJI_0002',
#  'RUA SANTANA MARIA - 31_12_20 - MAVIC - DJI_0166',
#  'RUA VICENTINA CAPUTO PELOSINI - 31_12_20 - MAVIC - DJI_0169',
#  'RUA JOSÃ\x89 GREGÃ\x93RIO DE MEDEIROS - 31_12_20 - MAVIC - DJI_0172',
#  'RUA CILEI JOSÃ\x89 TIAGO - 31_12_20 - MAVIC - DJI_0163',
#  'RUA ROLANDO MARQUES - 31_12_20 - MAVIC - DJI_0173',
#  'RUA DO PÃ\x94RTO - 31_12_20 - PHANTOM - DJI_0006',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'RUA ANA RUSSO VESTRI - 31_12_20 - PHANTOM - DJI_0016',
#  'RUA ANA RUSSO VESTRI - 31_12_20 - PHANTOM - DJI_0016',
#  'RUA ANA RUSSO VESTRI - 31_12_20 - PHANTOM - DJI_0016',
#  'RUA EMÃ\x8dLIA - 31_12_20 - PHANTOM - DJI_0017',
#  'RUA DONA LUÃ\x8dSA - 31_12_20 - PHANTOM - DJI_0013',
#  'RUA RIO ACIMA - 31_12_20 - PHANTOM - DJI_0009 - DJI_0010',
#  'RUA SEXTO GUAZELI - 31_12_20 - MAVIC - DJI_0170',
#  'RUA RIO ACIMA - 31_12_20 - PHANTOM - DJI_0009 - DJI_0010',
#  'ESTRADA SIMÃ\x83O PORTELA - 31_12_20 - PHANTOM - DJI_0042',
#  'RUA DAPHNIS - 31_12_20 - PHANTOM - DJI_0043',
#  'RUA TAMIRES - 31_12_20 - PHANTOM - DJI_0045',
#  'RUA ADÃ\x94NIS - 31_12_20 - PHANTOM - DJI_0044',
#  'RUA VISTA ALEGRE - 31_12_20 - PHANTOM - DJI_0020',
#  'RUA DAYANE DE SÃ\x81 SILVA - 31_12_20 - PHANTOM - DJI_0018',
#  'RUA LETICIA SALES - 31_12_20 - PHANTOM - DJI_0038',
#  'RUA RIO GRANDE - 31_12_20 - PHANTOM - DJI_0040',
#  'RUA RIO DAS PEDRAS - 31_12_20 - PHANTOM - DJI_0041',
#  'PASSAGEM ANÃ\x81POLIS - 31_12_20 - PHANTOM - DJI_0023',
#  'RUA DA QUADRA - 31_12_20 - PHANTOM - DJI_0029',
#  'RUA TROPICAL - 31_12_20 - PHANTOM - DJI_0028',
#  'RUA TROPICAL - 31_12_20 - PHANTOM - DJI_0028',
#  'RUA NOVA - 31_12_20 - PHANTOM - DJI_0027',
#  'PASSAGEM 14 DE ABRIL - 31_12_20 - PHANTOM - DJI_0030',
#  'RUA PASSAGEM DA CONQUISTA - 31_12_20 - PHANTOM - DJI_0026',
#  'RUA BECHELI - 31_12_20 - PHANTOM - DJI_0012',
#  'RUA MAFRA - 02_01_21 - PHANTOM - DJI_0010',
#  'MCT - RUA ALJUBARROTA',
#  'RUA CINTRA - 02_01_21 - PHANTOM - DJI_0012',
#  'MCT - RUA ALJUBARROTA',
#  'PRAÃ\x87A INFANTE - 02_01_21 - PHANTOM - DJI_0013',
#  'MCT - RUA ALJUBARROTA',
#  'MCT - RUA BUSACO',
#  'RUA PIRAQUARAS - 02_01_21 - MAVIC - DJI_0238',
#  'RUA LAMBARÃ\x8d - 02_01_21 - MAVIC - DJI_0237',
#  'RUA JOSÃ\x89FINA NANI GÃ\x89A - 02_01_21 - PHANTOM - DJI_0007',
#  'RUA MARIA CAPUTO PAGANO - 02_01_21 - PHANTOM - DJI_0008',
#  'RUA PORTUGAL - 02_01_21 - PHANTOM - DJI_0006',
#  'RUA JURITI - 02_01_21 - PHANTOM - DJI_0009',
#  'HEINRICH NORDOFF - 31_12_20 - PHANTOM - DJI_0005',
#  'HEINRICH NORDOFF - 31_12_20 - PHANTOM - DJI_0005',
#  'RUA ALBERTINO PINOTI - 31_12_20 - PHANTOM - DJI_0015 - DJI_0014',
#  'AVENIDA IVAÃ\x8d  - 31_12_20 - PHANTOM - DJI_0004',
#  'RUA RIO ACIMA - 31_12_20 - PHANTOM - DJI_0009 - DJI_0010',
#  'AVENIDA DA PRAIA - 31_12_20  - PHANTOM - DJI_0007',
#  "RUA SOFÃ\x8dA D'Ã\x82NGELO CAPUTO - 31_12_20 - MAVIC - DJI_0164 - DJI_0165",
#  'AVENIDA IVAÃ\x8d  - 31_12_20 - PHANTOM - DJI_0004',
#  'RUA MARCÃ\x8dLIO CONRADO - 31_12_20 - PHANTOM - DJI_0032',
#  'PASSAGEM ANÃ\x81POLIS - 31_12_20 - PHANTOM - DJI_0023',
#  'PASSAGEM TROPICAL - 31_12_20 - PHANTOM - DJI_0024',
#  'RUA HORIZONTE - 31_12_20 - PHANTOM - DJI_0025',
#  'RUA MARCÃ\x8dLIO CONRADO - 31_12_20 - PHANTOM - DJI_0032',
#  'RUA BELO MONTE - 31_12_20 - PHANTOM - DJI_0031',
#  'RUA JACIPORÃ\x83 - 31_12_20 - PHANTOM - DJI_0022 - DJI_0019',
#  'RUA SEM NOME - 31_12_20 - PHANTOM - DJI_0021',
#  'RUA AÃ\x87ORES - 02_01_21 - PHANTOM - DJI_0011',
#  'RUA MAFRA - 02_01_21 - PHANTOM - DJI_0010',
#  'ESTRADA SIMÃ\x83O PORTELA - 31_12_20 - PHANTOM - DJI_0042',
#  'RUA Ã\x82NGELA GIANOTO - 31_12_20 - PHANTOM - DJI_0011',
#  'RUA AUGUSTO PAULINO - 31_12_20 - MAVIC - DJI_0171',
#  'RUA NOSSA SRA. DO CARMO - 31_12_20 - MAVIC - DJI_0167 - DJI_0168',
#  'RUA ROWENA - 31_12_20 - MAVIC - DJI_0168']

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('MCT - ', '')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('DJI_[0-9]{4}')

# %%
gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer']
# Out:
# 64    RUA ALJUBARROTA
# 66    RUA ALJUBARROTA
# 68    RUA ALJUBARROTA
# 69         RUA BUSACO
# Name: Layer, dtype: object

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)
# Out:
#                              0         1     2              3     4         5  \
# 0          AVENIDA ARAGUAIA -   31_12_20  None   - PHANTOM -   None  DJI_0003
# 1             RUA RIO ACIMA -   31_12_20  None   - PHANTOM -   None  DJI_0009
# 2        RUA ANTÔNIO CAPUTO -   31_12_20  None   - PHANTOM -   None  DJI_0008
# 3        RUA ANTÔNIO CAPUTO -   31_12_20  None   - PHANTOM -   None  DJI_0008
# 4              RUA JACIPORÃ -   31_12_20  None   - PHANTOM -   None  DJI_0022
# ..                         ...       ...   ...            ...   ...       ...
# 94    ESTRADA SIMÃO PORTELA -   31_12_20  None   - PHANTOM -   None  DJI_0042
# 95       RUA ÂNGELA GIANOTO -   31_12_20  None   - PHANTOM -   None  DJI_0011
# 96      RUA AUGUSTO PAULINO -   31_12_20  None     - MAVIC -   None  DJI_0171
# 97  RUA NOSSA SRA. DO CARMO -   31_12_20  None     - MAVIC -   None  DJI_0167
# 98               RUA ROWENA -   31_12_20  None     - MAVIC -   None  DJI_0168
#
#       6     7         8     9
# 0        None      None  None
# 1    -   None  DJI_0010
# 2        None      None  None
# 3        None      None  None
# 4    -   None  DJI_0019
# ..  ...   ...       ...   ...
# 94       None      None  None
# 95       None      None  None
# 96       None      None  None
# 97   -   None  DJI_0168
# 98       None      None  None
#
# [99 rows x 10 columns]

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].unique()
# Out:
# array([' - PHANTOM - ', '  - PHANTOM - ', ' - MAVIC - ', None],
#       dtype=object)

# %%
pasta = {
    ' - PHANTOM - ':'PHANTOM',
    '  - PHANTOM - ':'PHANTOM',
    ' - MAVIC - ':'MAVIC'
}

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(pasta)
# Out:
# 0     PHANTOM
# 1     PHANTOM
# 2     PHANTOM
# 3     PHANTOM
# 4     PHANTOM
#        ...
# 94    PHANTOM
# 95    PHANTOM
# 96      MAVIC
# 97      MAVIC
# 98      MAVIC
# Name: 3, Length: 99, dtype: object

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0    AVENIDA ARAGUAIA - 31_12_20 - PHANTOM - DJI_0003       None
# 1   RUA RIO ACIMA - 31_12_20 - PHANTOM - DJI_0009 ...       None
# 2   RUA ANTÔNIO CAPUTO - 31_12_20 - PHANTOM - DJI_...       None
# 3   RUA ANTÔNIO CAPUTO - 31_12_20 - PHANTOM - DJI_...       None
# 4   RUA JACIPORÃ - 31_12_20 - PHANTOM - DJI_0022 -...       None
# ..                                                ...        ...
# 94  ESTRADA SIMÃO PORTELA - 31_12_20 - PHANTOM - D...       None
# 95  RUA ÂNGELA GIANOTO - 31_12_20 - PHANTOM - DJI_...       None
# 96  RUA AUGUSTO PAULINO - 31_12_20 - MAVIC - DJI_0171       None
# 97  RUA NOSSA SRA. DO CARMO - 31_12_20 - MAVIC - D...       None
# 98           RUA ROWENA - 31_12_20 - MAVIC - DJI_0168       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None          550  None
# 1   AcDbEntity:AcDb2dPolyline     None          55D  None
# 2   AcDbEntity:AcDb2dPolyline     None          562  None
# 3   AcDbEntity:AcDb2dPolyline     None          569  None
# 4   AcDbEntity:AcDb2dPolyline     None          580  None
# ..                        ...      ...          ...   ...
# 94    AcDbEntity:AcDbPolyline     None          A3A  None
# 95  AcDbEntity:AcDb2dPolyline     None          A3D  None
# 96  AcDbEntity:AcDb2dPolyline     None          A4D  None
# 97  AcDbEntity:AcDb2dPolyline     None          A58  None
# 98  AcDbEntity:AcDb2dPolyline     None          A5F  None
#
#                                              geometry  \
# 0   LINESTRING Z (344090.220 7369512.752 0.000, 34...
# 1   LINESTRING Z (343950.068 7369345.834 0.000, 34...
# 2   LINESTRING Z (343882.533 7369255.545 0.000, 34...
# 3   LINESTRING Z (344180.266 7369365.737 0.000, 34...
# 4   LINESTRING Z (344625.531 7368749.722 0.000, 34...
# ..                                                ...
# 94  LINESTRING (344635.432 7369571.680, 344644.737...
# 95  LINESTRING Z (343406.551 7369208.870 0.000, 34...
# 96  LINESTRING Z (343818.543 7369039.076 0.000, 34...
# 97  LINESTRING Z (344064.046 7369107.855 0.000, 34...
# 98  LINESTRING Z (344158.260 7369221.342 0.000, 34...
#
#                                                 lista                   DJI  \
# 0     [AVENIDA ARAGUAIA, 31_12_20, PHANTOM, DJI_0003]            [DJI_0003]
# 1   [RUA RIO ACIMA, 31_12_20, PHANTOM, DJI_0009, D...  [DJI_0009, DJI_0010]
# 2   [RUA ANTÔNIO CAPUTO, 31_12_20, PHANTOM, DJI_0008]            [DJI_0008]
# 3   [RUA ANTÔNIO CAPUTO, 31_12_20, PHANTOM, DJI_0008]            [DJI_0008]
# 4   [RUA JACIPORÃ, 31_12_20, PHANTOM, DJI_0022, DJ...  [DJI_0022, DJI_0019]
# ..                                                ...                   ...
# 94  [ESTRADA SIMÃO PORTELA, 31_12_20, PHANTOM, DJI...            [DJI_0042]
# 95  [RUA ÂNGELA GIANOTO, 31_12_20, PHANTOM, DJI_0011]            [DJI_0011]
# 96   [RUA AUGUSTO PAULINO, 31_12_20, MAVIC, DJI_0171]            [DJI_0171]
# 97  [RUA NOSSA SRA. DO CARMO, 31_12_20, MAVIC, DJI...  [DJI_0167, DJI_0168]
# 98            [RUA ROWENA, 31_12_20, MAVIC, DJI_0168]            [DJI_0168]
#
#    etapa  data_voo               logradouro
# 0    NaN  31_12_20         AVENIDA ARAGUAIA
# 1    NaN  31_12_20            RUA RIO ACIMA
# 2    NaN  31_12_20       RUA ANTÔNIO CAPUTO
# 3    NaN  31_12_20       RUA ANTÔNIO CAPUTO
# 4    NaN  31_12_20             RUA JACIPORÃ
# ..   ...       ...                      ...
# 94   NaN  31_12_20    ESTRADA SIMÃO PORTELA
# 95   NaN  31_12_20       RUA ÂNGELA GIANOTO
# 96   NaN  31_12_20      RUA AUGUSTO PAULINO
# 97   NaN  31_12_20  RUA NOSSA SRA. DO CARMO
# 98   NaN  31_12_20               RUA ROWENA
#
# [99 rows x 12 columns]

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#          Video_0       Video_1
# 0   DJI_0003.MOV          None
# 1   DJI_0009.MOV  DJI_0010.MOV
# 2   DJI_0008.MOV          None
# 3   DJI_0008.MOV          None
# 4   DJI_0022.MOV  DJI_0019.MOV
# ..           ...           ...
# 94  DJI_0042.MOV          None
# 95  DJI_0011.MOV          None
# 96  DJI_0171.MOV          None
# 97  DJI_0167.MOV  DJI_0168.MOV
# 98  DJI_0168.MOV          None
#
# [99 rows x 2 columns]

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'etapa', 'data_voo', 'logradouro',
#        'Video_0', 'Video_1'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + gdf_dxf.data_voo + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                                Layer  \
# 0            AVENIDA BALNEÁRIA - 29_12_20 - DJI_0032
# 1  ESTRADA MARTIM AFONSO DE SOUZA - 29_12_20 - DJ...
# 2  RUA JOHAN DE ALCÂNTARA SILVA - 29_12_20 - DJI_...
# 3                  RUA MUTUÍPE - 29_12_20 - DJI_0030
#
#                                             geometry PaperSpace  \
# 0  LINESTRING Z (342823.761 7370822.653 0.000, 34...       None
# 1  LINESTRING Z (342021.277 7369702.265 0.000, 34...       None
# 2  LINESTRING Z (342729.170 7370805.590 0.000, 34...       None
# 3  LINESTRING Z (342065.913 7370104.198 0.000, 34...       None
#
#                   SubClasses Linetype EntityHandle  Text  \
# 0  AcDbEntity:AcDb2dPolyline     None           6F  None
# 1  AcDbEntity:AcDb2dPolyline     None           F5  None
# 2  AcDbEntity:AcDb2dPolyline     None           74  None
# 3  AcDbEntity:AcDb2dPolyline     None           F0  None
#
#                                                lista                   DJI  \
# 0            [AVENIDA BALNEÁRIA, 29_12_20, DJI_0032]            [DJI_0032]
# 1  [ESTRADA MARTIM AFONSO DE SOUZA, 29_12_20, DJI...  [DJI_0028, DJI_0029]
# 2  [RUA JOHAN DE ALCÂNTARA SILVA, 29_12_20, DJI_0...            [DJI_0031]
# 3                  [RUA MUTUÍPE, 29_12_20, DJI_0030]            [DJI_0030]
#
#   etapa   data_voo                      logradouro       Video_0  \
# 0        29_12_20/               AVENIDA BALNEÁRIA  DJI_0032.MOV
# 1        29_12_20/  ESTRADA MARTIM AFONSO DE SOUZA  DJI_0028.MOV
# 2        29_12_20/    RUA JOHAN DE ALCÂNTARA SILVA  DJI_0031.MOV
# 3        29_12_20/                     RUA MUTUÍPE  DJI_0030.MOV
#
#         Video_1                  Video_0_path                  Video_1_path
# 0          None  videos/29_12_20/DJI_0032.MOV                           NaN
# 1  DJI_0029.MOV  videos/29_12_20/DJI_0028.MOV  videos/29_12_20/DJI_0029.MOV
# 2          None  videos/29_12_20/DJI_0031.MOV                           NaN
# 3          None  videos/29_12_20/DJI_0030.MOV                           NaN

# %%
gdf_dxf.Layer
# Out:
# 0              AVENIDA BALNEÁRIA - 29_12_20 - DJI_0032
# 1    ESTRADA MARTIM AFONSO DE SOUZA - 29_12_20 - DJ...
# 2    RUA JOHAN DE ALCÂNTARA SILVA - 29_12_20 - DJI_...
# 3                    RUA MUTUÍPE - 29_12_20 - DJI_0030
# Name: Layer, dtype: object

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB.gpkg', driver='GPKG')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# etapa             object
# data_voo          object
# logradouro        object
# Video_0           object
# Video_1           object
# Video_2           object
# Video_3           object
# Video_0_path      object
# Video_1_path      object
# Video_2_path      object
# Video_3_path      object
# dtype: object
