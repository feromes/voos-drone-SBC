# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_dxf = gpd.read_file('GIS/bases-DXF/BOTUJURU EIXOS COM CONFLITO.dxf', encoding='ANSI_1252')

# %%
bairro = 'BOTUJURU'

# %%
# gdf_dxf2 = gpd.read_file('GIS/bases-DXF/Bairro dos Casa.dxf', encoding='ANSI_1252')

# %%
# gdf_dxf2.loc[gdf_dxf2.Layer == 'MCT - PASSAGEM SANTOS DIAS DA SILVA', 'Layer'] = 'PASSAGEM SANTOS DIAS DA SILVA - DJI_0042'

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0   RUA GIUSEPPE SABATINI - 28_12_20 - PASTA ÃNIC...       None
# 1   RUA PASTOR TITO RODRIGUES LINHARES - 28_12_20 ...       None
# 2   RUA ANTONIO MENEGHETTI - 28_12_20 - PASTA ÃNI...       None
# 3   RUA ALBINA SILVA - 28_12_20 - PASTA ÃNICA - D...       None
# 4   RUA AGOSTINHO MASINI - 28_12_20 - PASTA ÃNICA...       None
# 5   RUA EMÃLIO STUCHI - 28_12_20 - PASTA ÃNICA -...       None
# 6   RUA JOÃO TURBAY - 28_12_20 - PASTA ÃNICA - D...       None
# 7   RUA LUIZ DALMOLIN - 28_12_20 - PASTA ÃNICA - ...       None
# 8   RUA JULIO BARAZAL SALGADO - 28_12_20 - PASTA Ã...       None
# 9   RUA JACINTO SIMIONATO FILHO - 28_12_20 - PASTA...       None
# 10  RUA EMA CIPRIANI BRUNI - 28_12_20 - PASTA ÃNI...       None
# 11  RUA OMAR DAIBERT - 28_12_20 - PASTA ÃNICA - D...       None
# 12                    RUA ANTONIO FRANCISCO ZANELLATO       None
# 13  RUA SALIM MAHFOUD - 28_12_20 - PASTA ÃNICA - ...       None
# 14                    MCT - RUA AUGUSTO ROSA DA SILVA       None
# 15  RUA NICOLA FELTRIN - 28_12_20 - PASTA ÃNICA -...       None
# 16  RUA JOSÃ GOMES MORENO - 28_12_20 - PASTA ÃNI...       None
# 17  RUA SEBASTIÃO BRUNI - 28_12_20 - PASTA ÃNICA...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None           6F  None
# 1   AcDbEntity:AcDb2dPolyline     None           74  None
# 2   AcDbEntity:AcDb2dPolyline     None           7A  None
# 3   AcDbEntity:AcDb2dPolyline     None           80  None
# 4   AcDbEntity:AcDb2dPolyline     None           88  None
# 5   AcDbEntity:AcDb2dPolyline     None           8D  None
# 6   AcDbEntity:AcDb2dPolyline     None           92  None
# 7   AcDbEntity:AcDb2dPolyline     None           97  None
# 8   AcDbEntity:AcDb2dPolyline     None           A1  None
# 9   AcDbEntity:AcDb2dPolyline     None           AA  None
# 10  AcDbEntity:AcDb2dPolyline     None           BC  None
# 11  AcDbEntity:AcDb2dPolyline     None           C2  None
# 12  AcDbEntity:AcDb2dPolyline     None           C9  None
# 13  AcDbEntity:AcDb2dPolyline     None           D8  None
# 14  AcDbEntity:AcDb2dPolyline     None          116  None
# 15  AcDbEntity:AcDb2dPolyline     None          11B  None
# 16  AcDbEntity:AcDb2dPolyline     None          131  None
# 17  AcDbEntity:AcDb2dPolyline     None          139  None
#
#                                              geometry
# 0   LINESTRING Z (342313.930 7372941.918 0.000, 34...
# 1   LINESTRING Z (342063.298 7373024.858 0.000, 34...
# 2   LINESTRING Z (341886.024 7373047.351 0.000, 34...
# 3   LINESTRING Z (341930.503 7372634.315 0.000, 34...
# 4   LINESTRING Z (342008.593 7372826.017 0.000, 34...
# 5   LINESTRING Z (342011.959 7373025.303 0.000, 34...
# 6   LINESTRING Z (341948.466 7373025.854 0.000, 34...
# 7   LINESTRING Z (341825.596 7373038.612 0.000, 34...
# 8   LINESTRING Z (341757.403 7372620.670 0.000, 34...
# 9   LINESTRING Z (342367.978 7373010.505 0.000, 34...
# 10  LINESTRING Z (341757.920 7372695.645 0.000, 34...
# 11  LINESTRING Z (341649.761 7372819.086 0.000, 34...
# 12  LINESTRING Z (342922.549 7373190.548 0.000, 34...
# 13  LINESTRING Z (342484.700 7373025.887 0.000, 34...
# 14  LINESTRING Z (342257.448 7372567.699 0.000, 34...
# 15  LINESTRING Z (342277.900 7372620.215 0.000, 34...
# 16  LINESTRING Z (341694.087 7372829.407 0.000, 34...
# 17  LINESTRING Z (342070.491 7372629.011 0.000, 34...

# %%
# gdf_dxf = gpd.GeoDataFrame(pd.concat([gdf_dxf, gdf_dxf2]).reset_index().drop('index', axis=1))

# %%
# gdf_dxf.Layer.to_list()

# %%
gdf_dxf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.encode(encoding='raw_unicode_escape').str.decode(encoding='utf-8').str.replace('MCT - ', '')

# %%
gdf_dxf['Layer'] = gdf_dxf.Layer.str.replace('MCT -', '')

# %%
gdf_dxf['lista'] = gdf_dxf.Layer.str.split(' - ')

# %%
gdf_dxf['DJI'] = gdf_dxf.Layer.str.findall('DJI_[0-9]{4}')

# %%
# gdf_dxf['etapa'] = gdf_dxf.Layer.str.extract('(ETAPA [0-9]{1,2})')

# %%
gdf_dxf['data_voo'] = gdf_dxf.Layer.str.extract('([0-9]{1,2}_[0-9]{2}_[0-9]{2})')

# %%
gdf_dxf['logradouro'] = gdf_dxf.lista.apply(lambda x: x[0])

# %%
gdf_dxf.loc[gdf_dxf['data_voo'].isna(), 'Layer']
# Out:
# 12    RUA ANTONIO FRANCISCO ZANELLATO
# 14          RUA AUGUSTO ROSA DA SILVA
# Name: Layer, dtype: object

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)
# Out:
#                                         0         1     2                  3  \
# 0                RUA GIUSEPPE SABATINI -   28_12_20  None   - PASTA ÚNICA -
# 1   RUA PASTOR TITO RODRIGUES LINHARES -   28_12_20  None   - PASTA ÚNICA -
# 2               RUA ANTONIO MENEGHETTI -   28_12_20  None   - PASTA ÚNICA -
# 3                     RUA ALBINA SILVA -   28_12_20  None   - PASTA ÚNICA -
# 4                 RUA AGOSTINHO MASINI -   28_12_20  None   - PASTA ÚNICA -
# 5                    RUA EMÍLIO STUCHI -   28_12_20  None   - PASTA ÚNICA -
# 6                      RUA JOÃO TURBAY -   28_12_20  None   - PASTA ÚNICA -
# 7                    RUA LUIZ DALMOLIN -   28_12_20  None   - PASTA ÚNICA -
# 8            RUA JULIO BARAZAL SALGADO -   28_12_20  None   - PASTA ÚNICA -
# 9          RUA JACINTO SIMIONATO FILHO -   28_12_20  None   - PASTA ÚNICA -
# 10              RUA EMA CIPRIANI BRUNI -   28_12_20  None   - PASTA ÚNICA -
# 11                    RUA OMAR DAIBERT -   28_12_20  None   - PASTA ÚNICA -
# 12        RUA ANTONIO FRANCISCO ZANELLATO      None  None               None
# 13                   RUA SALIM MAHFOUD -   28_12_20  None   - PASTA ÚNICA -
# 14              RUA AUGUSTO ROSA DA SILVA      None  None               None
# 15                  RUA NICOLA FELTRIN -   28_12_20  None   - PASTA ÚNICA -
# 16               RUA JOSÉ GOMES MORENO -   28_12_20  None   - PASTA ÚNICA -
# 17                 RUA SEBASTIÃO BRUNI -   28_12_20  None   - PASTA ÚNICA -
#
#        4         5     6     7         8     9
# 0   None  DJI_0038        None      None  None
# 1   None  DJI_0007        None      None  None
# 2   None  DJI_0162        None      None  None
# 3   None  DJI_0161        None      None  None
# 4   None  DJI_0160        None      None  None
# 5   None  DJI_0008        None      None  None
# 6   None  DJI_0009        None      None  None
# 7   None  DJI_0163        None      None  None
# 8   None  DJI_0164        None      None  None
# 9   None  DJI_0035        None      None  None
# 10  None  DJI_0001        None      None  None
# 11  None  DJI_0004        None      None  None
# 12  None      None  None  None      None  None
# 13  None  DJI_0036        None      None  None
# 14  None      None  None  None      None  None
# 15  None  DJI_0039        None      None  None
# 16  None  DJI_0006    -   None  DJI_0165
# 17  None  DJI_0159        None      None  None

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].unique()
# Out:
# array([' - PASTA ÚNICA - ', None], dtype=object)

# %%
etapas = { 
    ' - PASTA ÚNICA - ':'etapa_00'
}

# %%
gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(etapas)
# Out:
# 0     etapa_00
# 1     etapa_00
# 2     etapa_00
# 3     etapa_00
# 4     etapa_00
# 5     etapa_00
# 6     etapa_00
# 7     etapa_00
# 8     etapa_00
# 9     etapa_00
# 10    etapa_00
# 11    etapa_00
# 12         NaN
# 13    etapa_00
# 14         NaN
# 15    etapa_00
# 16    etapa_00
# 17    etapa_00
# Name: 3, dtype: object

# %%
gdf_dxf.loc[:, 'etapa'] = gdf_dxf.Layer.str.split('([0-9]{1,2}_[0-9]{2}_[0-9]{2})|(DJI_[0-9]{4})', expand=True)[3].map(etapas)

# %%
gdf_dxf.loc[:, 'etapa']
# Out:
# 0     etapa_00
# 1     etapa_00
# 2     etapa_00
# 3     etapa_00
# 4     etapa_00
# 5     etapa_00
# 6     etapa_00
# 7     etapa_00
# 8     etapa_00
# 9     etapa_00
# 10    etapa_00
# 11    etapa_00
# 12         NaN
# 13    etapa_00
# 14         NaN
# 15    etapa_00
# 16    etapa_00
# 17    etapa_00
# Name: etapa, dtype: object

# %%
gdf_dxf
# Out:
#                                                 Layer PaperSpace  \
# 0   RUA GIUSEPPE SABATINI - 28_12_20 - PASTA ÚNICA...       None
# 1   RUA PASTOR TITO RODRIGUES LINHARES - 28_12_20 ...       None
# 2   RUA ANTONIO MENEGHETTI - 28_12_20 - PASTA ÚNIC...       None
# 3   RUA ALBINA SILVA - 28_12_20 - PASTA ÚNICA - DJ...       None
# 4   RUA AGOSTINHO MASINI - 28_12_20 - PASTA ÚNICA ...       None
# 5   RUA EMÍLIO STUCHI - 28_12_20 - PASTA ÚNICA - D...       None
# 16  28_12_20               RUA JOSÉ GOMES MORENO  etapa_00
# 17  28_12_20                 RUA SEBASTIÃO BRUNI  etapa_00

# %%
pd_videos = pd.DataFrame(list(map(lambda x: 
         list(map(lambda y: y + '.MOV', x))
         , gdf_dxf.DJI))).add_prefix('Video_')

# %%
pd_videos
# Out:
#          Video_0       Video_1
# 0   DJI_0038.MOV          None
# 1   DJI_0007.MOV          None
# 2   DJI_0162.MOV          None
# 3   DJI_0161.MOV          None
# 4   DJI_0160.MOV          None
# 5   DJI_0008.MOV          None
# 6   DJI_0009.MOV          None
# 7   DJI_0163.MOV          None
# 8   DJI_0164.MOV          None
# 9   DJI_0035.MOV          None
# 10  DJI_0001.MOV          None
# 11  DJI_0004.MOV          None
# 12          None          None
# 13  DJI_0036.MOV          None
# 14          None          None
# 15  DJI_0039.MOV          None
# 16  DJI_0006.MOV  DJI_0165.MOV
# 17  DJI_0159.MOV          None

# %%
gdf_dxf = gdf_dxf.merge(pd_videos, left_index=True, right_index=True)

# %%
gdf_dxf.columns
# Out:
# Index(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text',
#        'geometry', 'lista', 'DJI', 'data_voo', 'logradouro', 'etapa',
#        'Video_0', 'Video_1'],
#       dtype='object')

# %%
gdf_dxf.loc[gdf_dxf.etapa.isna(), 'etapa'] = ''

# %%
gdf_dxf.etapa = gdf_dxf.etapa.str.replace(' ', '_')

# %%
gdf_dxf.loc[gdf_dxf.etapa != '', 'etapa'] += '/'

# %%
gdf_dxf.loc[~gdf_dxf.data_voo.isna(), 'data_voo'] += '/'

# %%
for c in gdf_dxf.loc[:, gdf_dxf.columns.str.startswith('Video')].columns:
    gdf_dxf[c + '_path'] = 'videos/' + bairro.lower().replace('-', '_') + '/' + gdf_dxf.data_voo + gdf_dxf.etapa + gdf_dxf[c]

# %%
gdf_dxf = gdf_dxf.dissolve(by=['Layer'], aggfunc='first').reset_index()

# %%
gdf_dxf.crs = 'epsg:31983'

# %%
gdf_dxf
# Out:
#                                                 Layer  \
# 0   RUA AGOSTINHO MASINI - 28_12_20 - PASTA ÚNICA ...
# 1   RUA ALBINA SILVA - 28_12_20 - PASTA ÚNICA - DJ...
# 2                     RUA ANTONIO FRANCISCO ZANELLATO
# 3   RUA ANTONIO MENEGHETTI - 28_12_20 - PASTA ÚNIC...
# 4                           RUA AUGUSTO ROSA DA SILVA
# 5   RUA EMA CIPRIANI BRUNI - 28_12_20 - PASTA ÚNIC...
# 6   RUA EMÍLIO STUCHI - 28_12_20 - PASTA ÚNICA - D...
# 7   RUA GIUSEPPE SABATINI - 28_12_20 - PASTA ÚNICA...
# 8   RUA JACINTO SIMIONATO FILHO - 28_12_20 - PASTA...
# 9   RUA JOSÉ GOMES MORENO - 28_12_20 - PASTA ÚNICA...
# 10  RUA JOÃO TURBAY - 28_12_20 - PASTA ÚNICA - DJI...
# 11  RUA JULIO BARAZAL SALGADO - 28_12_20 - PASTA Ú...
# 12  RUA LUIZ DALMOLIN - 28_12_20 - PASTA ÚNICA - D...
# 13  RUA NICOLA FELTRIN - 28_12_20 - PASTA ÚNICA - ...
# 14  RUA OMAR DAIBERT - 28_12_20 - PASTA ÚNICA - DJ...
# 15  RUA PASTOR TITO RODRIGUES LINHARES - 28_12_20 ...
# 16  RUA SALIM MAHFOUD - 28_12_20 - PASTA ÚNICA - D...
# 17  RUA SEBASTIÃO BRUNI - 28_12_20 - PASTA ÚNICA -...
#
#                                              geometry PaperSpace  \
# 0   LINESTRING Z (342008.593 7372826.017 0.000, 34...       None
# 1   LINESTRING Z (341930.503 7372634.315 0.000, 34...       None
# 2   LINESTRING Z (342922.549 7373190.548 0.000, 34...       None
# 3   LINESTRING Z (341886.024 7373047.351 0.000, 34...       None
# 4   LINESTRING Z (342257.448 7372567.699 0.000, 34...       None
# 5   LINESTRING Z (341757.920 7372695.645 0.000, 34...       None
# 6   LINESTRING Z (342011.959 7373025.303 0.000, 34...       None
# 7   LINESTRING Z (342313.930 7372941.918 0.000, 34...       None
# 8   LINESTRING Z (342367.978 7373010.505 0.000, 34...       None
# 9   LINESTRING Z (341694.087 7372829.407 0.000, 34...       None
# 10  LINESTRING Z (341948.466 7373025.854 0.000, 34...       None
# 11  LINESTRING Z (341757.403 7372620.670 0.000, 34...       None
# 12  LINESTRING Z (341825.596 7373038.612 0.000, 34...       None
# 13  LINESTRING Z (342277.900 7372620.215 0.000, 34...       None
# 14  LINESTRING Z (341649.761 7372819.086 0.000, 34...       None
# 15  LINESTRING Z (342063.298 7373024.858 0.000, 34...       None
# 16  LINESTRING Z (342484.700 7373025.887 0.000, 34...       None
# 17  LINESTRING Z (342070.491 7372629.011 0.000, 34...       None
#
#                    SubClasses Linetype EntityHandle  Text  \
# 0   AcDbEntity:AcDb2dPolyline     None           88  None
# 1   AcDbEntity:AcDb2dPolyline     None           80  None
# 2   AcDbEntity:AcDb2dPolyline     None           C9  None
# 3   AcDbEntity:AcDb2dPolyline     None           7A  None
# 4   AcDbEntity:AcDb2dPolyline     None          116  None
# 5   AcDbEntity:AcDb2dPolyline     None           BC  None
# 6   AcDbEntity:AcDb2dPolyline     None           8D  None
# 7   AcDbEntity:AcDb2dPolyline     None           6F  None
# 8   AcDbEntity:AcDb2dPolyline     None           AA  None
# 9   AcDbEntity:AcDb2dPolyline     None          131  None
# 10  AcDbEntity:AcDb2dPolyline     None           92  None
# 11  AcDbEntity:AcDb2dPolyline     None           A1  None
# 12  AcDbEntity:AcDb2dPolyline     None           97  None
# 13  AcDbEntity:AcDb2dPolyline     None          11B  None
# 14  AcDbEntity:AcDb2dPolyline     None           C2  None
# 15  AcDbEntity:AcDb2dPolyline     None           74  None
# 16  AcDbEntity:AcDb2dPolyline     None           D8  None
# 17  AcDbEntity:AcDb2dPolyline     None          139  None
#
#                                                 lista                   DJI  \
# 0   [RUA AGOSTINHO MASINI, 28_12_20, PASTA ÚNICA, ...            [DJI_0160]
# 1   [RUA ALBINA SILVA, 28_12_20, PASTA ÚNICA, DJI_...            [DJI_0161]
# 2                   [RUA ANTONIO FRANCISCO ZANELLATO]                    []
# 3   [RUA ANTONIO MENEGHETTI, 28_12_20, PASTA ÚNICA...            [DJI_0162]
# 4                         [RUA AUGUSTO ROSA DA SILVA]                    []
# 5   [RUA EMA CIPRIANI BRUNI, 28_12_20, PASTA ÚNICA...            [DJI_0001]
# 6   [RUA EMÍLIO STUCHI, 28_12_20, PASTA ÚNICA, DJI...            [DJI_0008]
# 7   [RUA GIUSEPPE SABATINI, 28_12_20, PASTA ÚNICA,...            [DJI_0038]
# 8   [RUA JACINTO SIMIONATO FILHO, 28_12_20, PASTA ...            [DJI_0035]
# 9   [RUA JOSÉ GOMES MORENO, 28_12_20, PASTA ÚNICA,...  [DJI_0006, DJI_0165]
# 10  [RUA JOÃO TURBAY, 28_12_20, PASTA ÚNICA, DJI_0...            [DJI_0009]
# 11  [RUA JULIO BARAZAL SALGADO, 28_12_20, PASTA ÚN...            [DJI_0164]
# 12  [RUA LUIZ DALMOLIN, 28_12_20, PASTA ÚNICA, DJI...            [DJI_0163]
# 13  [RUA NICOLA FELTRIN, 28_12_20, PASTA ÚNICA, DJ...            [DJI_0039]
# 14  [RUA OMAR DAIBERT, 28_12_20, PASTA ÚNICA, DJI_...            [DJI_0004]
# 15  [RUA PASTOR TITO RODRIGUES LINHARES, 28_12_20,...            [DJI_0007]
# 16  [RUA SALIM MAHFOUD, 28_12_20, PASTA ÚNICA, DJI...            [DJI_0036]
# 17  [RUA SEBASTIÃO BRUNI, 28_12_20, PASTA ÚNICA, D...            [DJI_0159]
#
#      data_voo                          logradouro      etapa       Video_0  \
# 0   28_12_20/                RUA AGOSTINHO MASINI  etapa_00/  DJI_0160.MOV
# 1   28_12_20/                    RUA ALBINA SILVA  etapa_00/  DJI_0161.MOV
# 2         NaN     RUA ANTONIO FRANCISCO ZANELLATO                     None
# 3   28_12_20/              RUA ANTONIO MENEGHETTI  etapa_00/  DJI_0162.MOV
# 4         NaN           RUA AUGUSTO ROSA DA SILVA                     None
# 5   28_12_20/              RUA EMA CIPRIANI BRUNI  etapa_00/  DJI_0001.MOV
# 6   28_12_20/                   RUA EMÍLIO STUCHI  etapa_00/  DJI_0008.MOV
# 7   28_12_20/               RUA GIUSEPPE SABATINI  etapa_00/  DJI_0038.MOV
# 8   28_12_20/         RUA JACINTO SIMIONATO FILHO  etapa_00/  DJI_0035.MOV
# 9   28_12_20/               RUA JOSÉ GOMES MORENO  etapa_00/  DJI_0006.MOV
# 10  28_12_20/                     RUA JOÃO TURBAY  etapa_00/  DJI_0009.MOV
# 11  28_12_20/           RUA JULIO BARAZAL SALGADO  etapa_00/  DJI_0164.MOV
# 12  28_12_20/                   RUA LUIZ DALMOLIN  etapa_00/  DJI_0163.MOV
# 13  28_12_20/                  RUA NICOLA FELTRIN  etapa_00/  DJI_0039.MOV
# 14  28_12_20/                    RUA OMAR DAIBERT  etapa_00/  DJI_0004.MOV
# 15  28_12_20/  RUA PASTOR TITO RODRIGUES LINHARES  etapa_00/  DJI_0007.MOV
# 16  28_12_20/                   RUA SALIM MAHFOUD  etapa_00/  DJI_0036.MOV
# 17  28_12_20/                 RUA SEBASTIÃO BRUNI  etapa_00/  DJI_0159.MOV
#
#          Video_1                                    Video_0_path  \
# 0           None  videos/botujuru/28_12_20/etapa_00/DJI_0160.MOV
# 1           None  videos/botujuru/28_12_20/etapa_00/DJI_0161.MOV
# 2           None                                             NaN
# 3           None  videos/botujuru/28_12_20/etapa_00/DJI_0162.MOV
# 4           None                                             NaN
# 5           None  videos/botujuru/28_12_20/etapa_00/DJI_0001.MOV
# 6           None  videos/botujuru/28_12_20/etapa_00/DJI_0008.MOV
# 7           None  videos/botujuru/28_12_20/etapa_00/DJI_0038.MOV
# 8           None  videos/botujuru/28_12_20/etapa_00/DJI_0035.MOV
# 9   DJI_0165.MOV  videos/botujuru/28_12_20/etapa_00/DJI_0006.MOV
# 10          None  videos/botujuru/28_12_20/etapa_00/DJI_0009.MOV
# 11          None  videos/botujuru/28_12_20/etapa_00/DJI_0164.MOV
# 12          None  videos/botujuru/28_12_20/etapa_00/DJI_0163.MOV
# 13          None  videos/botujuru/28_12_20/etapa_00/DJI_0039.MOV
# 14          None  videos/botujuru/28_12_20/etapa_00/DJI_0004.MOV
# 15          None  videos/botujuru/28_12_20/etapa_00/DJI_0007.MOV
# 16          None  videos/botujuru/28_12_20/etapa_00/DJI_0036.MOV
# 17          None  videos/botujuru/28_12_20/etapa_00/DJI_0159.MOV
#
#                                       Video_1_path
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9   videos/botujuru/28_12_20/etapa_00/DJI_0165.MOV
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1)
# Out:
#                                              geometry   data_voo  \
# 0   LINESTRING Z (342008.593 7372826.017 0.000, 34...  28_12_20/
# 1   LINESTRING Z (341930.503 7372634.315 0.000, 34...  28_12_20/
# 2   LINESTRING Z (342922.549 7373190.548 0.000, 34...        NaN
# 3   LINESTRING Z (341886.024 7373047.351 0.000, 34...  28_12_20/
# 4   LINESTRING Z (342257.448 7372567.699 0.000, 34...        NaN
# 5   LINESTRING Z (341757.920 7372695.645 0.000, 34...  28_12_20/
# 6   LINESTRING Z (342011.959 7373025.303 0.000, 34...  28_12_20/
# 7   LINESTRING Z (342313.930 7372941.918 0.000, 34...  28_12_20/
# 8   LINESTRING Z (342367.978 7373010.505 0.000, 34...  28_12_20/
# 9   LINESTRING Z (341694.087 7372829.407 0.000, 34...  28_12_20/
# 10  LINESTRING Z (341948.466 7373025.854 0.000, 34...  28_12_20/
# 11  LINESTRING Z (341757.403 7372620.670 0.000, 34...  28_12_20/
# 12  LINESTRING Z (341825.596 7373038.612 0.000, 34...  28_12_20/
# 13  LINESTRING Z (342277.900 7372620.215 0.000, 34...  28_12_20/
# 14  LINESTRING Z (341649.761 7372819.086 0.000, 34...  28_12_20/
# 15  LINESTRING Z (342063.298 7373024.858 0.000, 34...  28_12_20/
# 16  LINESTRING Z (342484.700 7373025.887 0.000, 34...  28_12_20/
# 17  LINESTRING Z (342070.491 7372629.011 0.000, 34...  28_12_20/
#
#                             logradouro      etapa       Video_0       Video_1  \
# 0                 RUA AGOSTINHO MASINI  etapa_00/  DJI_0160.MOV          None
# 1                     RUA ALBINA SILVA  etapa_00/  DJI_0161.MOV          None
# 2      RUA ANTONIO FRANCISCO ZANELLATO                     None          None
# 3               RUA ANTONIO MENEGHETTI  etapa_00/  DJI_0162.MOV          None
# 4            RUA AUGUSTO ROSA DA SILVA                     None          None
# 5               RUA EMA CIPRIANI BRUNI  etapa_00/  DJI_0001.MOV          None
# 6                    RUA EMÍLIO STUCHI  etapa_00/  DJI_0008.MOV          None
# 7                RUA GIUSEPPE SABATINI  etapa_00/  DJI_0038.MOV          None
# 8          RUA JACINTO SIMIONATO FILHO  etapa_00/  DJI_0035.MOV          None
# 9                RUA JOSÉ GOMES MORENO  etapa_00/  DJI_0006.MOV  DJI_0165.MOV
# 10                     RUA JOÃO TURBAY  etapa_00/  DJI_0009.MOV          None
# 11           RUA JULIO BARAZAL SALGADO  etapa_00/  DJI_0164.MOV          None
# 12                   RUA LUIZ DALMOLIN  etapa_00/  DJI_0163.MOV          None
# 13                  RUA NICOLA FELTRIN  etapa_00/  DJI_0039.MOV          None
# 14                    RUA OMAR DAIBERT  etapa_00/  DJI_0004.MOV          None
# 15  RUA PASTOR TITO RODRIGUES LINHARES  etapa_00/  DJI_0007.MOV          None
# 16                   RUA SALIM MAHFOUD  etapa_00/  DJI_0036.MOV          None
# 17                 RUA SEBASTIÃO BRUNI  etapa_00/  DJI_0159.MOV          None
#
#                                       Video_0_path  \
# 0   videos/botujuru/28_12_20/etapa_00/DJI_0160.MOV
# 1   videos/botujuru/28_12_20/etapa_00/DJI_0161.MOV
# 2                                              NaN
# 3   videos/botujuru/28_12_20/etapa_00/DJI_0162.MOV
# 4                                              NaN
# 5   videos/botujuru/28_12_20/etapa_00/DJI_0001.MOV
# 6   videos/botujuru/28_12_20/etapa_00/DJI_0008.MOV
# 7   videos/botujuru/28_12_20/etapa_00/DJI_0038.MOV
# 8   videos/botujuru/28_12_20/etapa_00/DJI_0035.MOV
# 9   videos/botujuru/28_12_20/etapa_00/DJI_0006.MOV
# 10  videos/botujuru/28_12_20/etapa_00/DJI_0009.MOV
# 11  videos/botujuru/28_12_20/etapa_00/DJI_0164.MOV
# 12  videos/botujuru/28_12_20/etapa_00/DJI_0163.MOV
# 13  videos/botujuru/28_12_20/etapa_00/DJI_0039.MOV
# 14  videos/botujuru/28_12_20/etapa_00/DJI_0004.MOV
# 15  videos/botujuru/28_12_20/etapa_00/DJI_0007.MOV
# 16  videos/botujuru/28_12_20/etapa_00/DJI_0036.MOV
# 17  videos/botujuru/28_12_20/etapa_00/DJI_0159.MOV
#
#                                       Video_1_path
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9   videos/botujuru/28_12_20/etapa_00/DJI_0165.MOV
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN

# %%
gdf_dxf.drop(['Layer', 'PaperSpace', 'SubClasses', 'Linetype', 'EntityHandle', 'Text', 'DJI', 'lista'], axis=1).to_file(f'./videos/ruas-videos-{bairro}-PROSAB-CONFLITO-DE-PROGRAMAS.gpkg', driver='GPKG')

# %%
gdf_dxf.dtypes
# Out:
# Layer             object
# geometry        geometry
# PaperSpace        object
# SubClasses        object
# Linetype          object
# EntityHandle      object
# Text              object
# lista             object
# DJI               object
# data_voo          object
# logradouro        object
# etapa             object
# Video_0           object
# Video_1           object
# Video_0_path      object
# Video_1_path      object
# dtype: object
